# %% [markdown]
# ## Парсинг шаблонов для эталонных записей

# %%
import os
import pandas as pd
from openpyxl import load_workbook

# Укажите путь к папке с файлами
folder_path = 'Данные'

# Итоговый датафрейм
result_df = pd.DataFrame(columns=['Файл', 'Значение Краткое наименование', 'Значение Полное наименование'])

# Список для хранения сообщений об ошибках
log_messages = []

for root, dirs, files in os.walk(folder_path):  # перебор всех подпапок
    for file in files:
        if file.endswith(('.xlsx', '.xlsm', '.xls')):
            file_path = os.path.join(root, file)
            try:
                wb = load_workbook(file_path, read_only=True, data_only=True)

                # Ищем лист с подстрокой "Эталонные записи" в названии
                sheet_name = None
                for sheet in wb.sheetnames:
                    if "Эталонные записи" in sheet:
                        sheet_name = sheet
                        break

                if sheet_name is None:
                    msg = f'В файле {file} лист с "Эталонные записи" не найден. Пропускаем.'
                    print(msg)
                    log_messages.append(msg)
                    continue

                ws = wb[sheet_name]

                # Находим строку с "Краткое наименование нормализованное" в 3-м столбце (столбец C)
                found_row = None
                for row in ws.iter_rows(min_col=3, max_col=3):
                    cell = row[0]
                    if cell.value == "Краткое наименование нормализованное":
                        found_row = cell.row
                        break

                if found_row is None:
                    msg = f'В листе {sheet_name} файла {file} не найдена ячейка с "Краткое наименование нормализованное". Пропускаем.'
                    print(msg)
                    log_messages.append(msg)
                    continue

                values = []
                current_row = found_row + 2
                while True:
                    cell_value = ws.cell(row=current_row, column=3).value
                    if cell_value is None:
                        if current_row == found_row + 2:
                            msg = f'В листе {sheet_name} файла {file} нет записей "Краткое наименование нормализованное".'
                            print(msg)
                            log_messages.append(msg)
                        break
                    values.append(cell_value)
                    current_row += 1

                # Находим строку с "Полное наименование нормализованное" в 5-м столбце (столбец E)
                found_row = None
                for row in ws.iter_rows(min_col=5, max_col=5):
                    cell = row[0]
                    if cell.value == "Полное наименование нормализованное":
                        found_row = cell.row
                        break

                if found_row is None:
                    msg = f'В листе {sheet_name} файла {file} не найдена ячейка с "Полное наименование нормализованное". Пропускаем.'
                    print(msg)
                    log_messages.append(msg)
                    continue

                values_full = []
                current_row = found_row + 2
                while True:
                    cell_value = ws.cell(row=current_row, column=5).value
                    if cell_value is None:
                        if current_row == found_row + 2:
                            msg = f'В листе {sheet_name} файла {file} нет записей "Полное наименование нормализованное".'
                            print(msg)
                            log_messages.append(msg)    
                        break
                    values_full.append(cell_value)
                    current_row += 1

                # Проверяем, чтобы длина списков совпадала
                min_len = min(len(values), len(values_full))
                if min_len == 0:
                    msg = f'В файле {file} нет данных для "Краткое наименование" или "Полное наименование". Пропускаем.'
                    print(msg)
                    log_messages.append(msg)
                    continue

                # Формируем итоговый датафрейм
                df_temp = pd.DataFrame({
                    'Файл': [file] * min_len,
                    'Значение Краткое наименование': values[:min_len],
                    'Значение Полное наименование': values_full[:min_len]
                })
                result_df = pd.concat([result_df, df_temp], ignore_index=True)

            except Exception as e:
                msg = f'Ошибка при обработке файла {file}: {e}'
                print(msg)
                log_messages.append(msg)

# Сохраняем итоговый датафрейм в Excel
output_path = os.path.join(folder_path, 'собранные_данные.xlsx')
result_df.to_excel(output_path, index=False)
print(f'Сбор данных завершён. Результат сохранён в {output_path}')

# Сохраняем логи в отдельный Excel файл
if log_messages:
    log_df = pd.DataFrame({'Сообщения': log_messages})
    log_path = os.path.join(folder_path, 'логи_обработки.xlsx')
    log_df.to_excel(log_path, index=False)
    print(f'Логи обработки сохранены в {log_path}')
else:
    print('Не обнаружено ошибок и предупреждений.')

# %% [markdown]
# ## Парсинг нормализованных записей

# %%
# Шаг 1: Импорт библиотек
import os
import pandas as pd
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# %%
# Шаг 2: Функция для поиска колонок
def find_columns_position(df_sheet, target_columns):
    """
    Ищет позиции целевых колонок в первых двух строках DataFrame
    """
    column_positions = {}
    missing_columns = []
    
    for col_name in target_columns:
        found = False
        for row_idx in range(2):  # Проверяем обе строки
            for col_idx in range(min(40, df_sheet.shape[1])):
                try:
                    cell_value = str(df_sheet.iloc[row_idx, col_idx]).strip()
                    # Для поля "Статус" используем точное сравнение, для остальных - подстроку
                    if col_name == "Статус":
                        if cell_value == "Статус":
                            column_positions[col_name] = col_idx
                            found = True
                            break
                    else:
                        if col_name in cell_value:
                            column_positions[col_name] = col_idx
                            found = True
                            break
                except:
                    continue
            if found:
                break
        
        if not found:
            missing_columns.append(col_name)
    
    return column_positions, missing_columns

# %%
# Шаг 3: Основная функция парсинга
def parse_excel_files(root_folder):
    df_parse = pd.DataFrame()
    logs = []
    
    target_columns = [
        "Код КССС/id", 
        "Краткое наименование нормализованное", 
        "Полное наименование нормализованное", 
        "Краткое наименование КССС (исх)",
        "Статус"
    ]
    
    for root, dirs, files in os.walk(root_folder):
        for file in files:
            if file.endswith(('.xlsx', '.xls')):
                file_path = os.path.join(root, file)
                folder_name = os.path.basename(root)
                
                try:
                    # Проверяем наличие листа
                    excel_file = pd.ExcelFile(file_path)
                    if "Нормализованные записи" not in excel_file.sheet_names:
                        log_msg = f"Лист 'Нормализованные записи' не найден в файле: {file}"
                        print(log_msg)
                        logs.append({
                            'Тип ошибки': 'Лист не найден',
                            'Файл': file,
                            'Папка': folder_name,
                            'Сообщение': log_msg
                        })
                        continue
                    
                    # Читаем заголовки
                    df_sheet = pd.read_excel(file_path, 
                                           sheet_name="Нормализованные записи", 
                                           header=None, 
                                           nrows=2)
                    
                    # Ищем колонки
                    column_positions, missing_columns = find_columns_position(df_sheet, target_columns)
                    
                    if missing_columns:
                        log_msg = f"Не найдены колонки в файле {file}: {', '.join(missing_columns)}"
                        print(log_msg)
                        logs.append({
                            'Тип ошибки': 'Колонки не найдены',
                            'Файл': file,
                            'Папка': folder_name,
                            'Сообщение': log_msg
                        })
                        continue
                    
                    # Читаем полные данные
                    df_full = pd.read_excel(file_path, 
                                          sheet_name="Нормализованные записи", 
                                          header=None,
                                          skiprows=2)
                    
                    # Собираем данные с проверкой на 5 последовательных пропусков
                    file_data = []
                    consecutive_empty = 0
                    code_col_index = column_positions["Код КССС/id"]
                    
                    for row_idx in range(len(df_full)):
                        try:
                            code_value = df_full.iloc[row_idx, code_col_index]
                            
                            # Проверяем, есть ли данные в ячейке "Код КССС/id"
                            if pd.notna(code_value) and str(code_value).strip() != '':
                                consecutive_empty = 0  # Сбрасываем счетчик пропусков
                                
                                # Преобразуем код в текст, убирая лишние пробелы
                                code_as_text = str(code_value).strip()
                                
                                row_data = {
                                    'Код КССС/id': code_as_text,  # Сохраняем как текст
                                    'Краткое наименование нормализованное': df_full.iloc[row_idx, column_positions["Краткое наименование нормализованное"]] if pd.notna(df_full.iloc[row_idx, column_positions["Краткое наименование нормализованное"]]) else '',
                                    'Полное наименование нормализованное': df_full.iloc[row_idx, column_positions["Полное наименование нормализованное"]] if pd.notna(df_full.iloc[row_idx, column_positions["Полное наименование нормализованное"]]) else '',
                                    'Краткое наименование КССС (исх)': df_full.iloc[row_idx, column_positions["Краткое наименование КССС (исх)"]] if pd.notna(df_full.iloc[row_idx, column_positions["Краткое наименование КССС (исх)"]]) else '',
                                    'Статус': df_full.iloc[row_idx, column_positions["Статус"]] if pd.notna(df_full.iloc[row_idx, column_positions["Статус"]]) else '',
                                    'Папка': folder_name,
                                    'Имя файла': file
                                }
                                file_data.append(row_data)
                            else:
                                consecutive_empty += 1
                                
                            # Если встретили 5 последовательных пропусков, прекращаем обработку этого файла
                            if consecutive_empty >= 5:
                                break
                                
                        except Exception as e:
                            # В случае ошибки чтения строки считаем это пропуском
                            consecutive_empty += 1
                            if consecutive_empty >= 5:
                                break
                            continue
                    
                    if file_data:
                        df_file = pd.DataFrame(file_data)
                        df_parse = pd.concat([df_parse, df_file], ignore_index=True)
                        print(f"✓ Файл {file} обработан, записей: {len(file_data)}")
                    
                except Exception as e:
                    log_msg = f"Ошибка в файле {file}: {str(e)}"
                    print(log_msg)
                    logs.append({
                        'Тип ошибки': 'Ошибка обработки',
                        'Файл': file,
                        'Папка': folder_name,
                        'Сообщение': str(e)
                    })
    
    return df_parse, logs

# %%
# Шаг 3: Основная функция парсинга (исправленная часть)
def parse_excel_files(root_folder):
    df_parse = pd.DataFrame()
    logs = []
    
    target_columns = [
        "Код КССС/id", 
        "Краткое наименование нормализованное", 
        "Полное наименование нормализованное", 
        "Краткое наименование КССС (исх)",
        "Статус"
    ]
    
    for root, dirs, files in os.walk(root_folder):
        for file in files:
            if file.endswith(('.xlsx', '.xls')):
                file_path = os.path.join(root, file)
                folder_name = os.path.basename(root)
                
                try:
                    # Проверяем наличие листа
                    excel_file = pd.ExcelFile(file_path)
                    if "Нормализованные записи" not in excel_file.sheet_names:
                        log_msg = f"Лист 'Нормализованные записи' не найден в файле: {file}"
                        print(log_msg)
                        logs.append({
                            'Тип ошибки': 'Лист не найден',
                            'Файл': file,
                            'Папка': folder_name,
                            'Сообщение': log_msg
                        })
                        continue
                    
                    # Читаем заголовки с явным указанием типов данных
                    df_sheet = pd.read_excel(file_path, 
                                           sheet_name="Нормализованные записи", 
                                           header=None, 
                                           nrows=2,
                                           dtype=str)  # Читаем все как строку
                    
                    # Ищем колонки
                    column_positions, missing_columns = find_columns_position(df_sheet, target_columns)
                    
                    if missing_columns:
                        log_msg = f"Не найдены колонки в файле {file}: {', '.join(missing_columns)}"
                        print(log_msg)
                        logs.append({
                            'Тип ошибки': 'Колонки не найдены',
                            'Файл': file,
                            'Папка': folder_name,
                            'Сообщение': log_msg
                        })
                        continue
                    
                    # Читаем полные данные как строки чтобы избежать проблем с типами
                    df_full = pd.read_excel(file_path, 
                                          sheet_name="Нормализованные записи", 
                                          header=None,
                                          skiprows=2,
                                          dtype=str)  # Читаем все как строку
                    
                    # Собираем данные с проверкой на 5 последовательных пропусков
                    file_data = []
                    consecutive_empty = 0
                    code_col_index = column_positions["Код КССС/id"]
                    
                    for row_idx in range(len(df_full)):
                        try:
                            # Проверяем что индекс в пределах данных
                            if row_idx >= len(df_full):
                                break
                                
                            # Безопасное получение значения
                            if code_col_index < len(df_full.columns):
                                code_value = df_full.iloc[row_idx, code_col_index]
                            else:
                                code_value = None
                            
                            # Проверяем, есть ли данные в ячейке "Код КССС/id"
                            if pd.notna(code_value) and str(code_value).strip() != '' and code_value is not None:
                                consecutive_empty = 0  # Сбрасываем счетчик пропусков
                                
                                # Безопасное получение остальных значений
                                def get_safe_value(col_name):
                                    if col_name in column_positions and column_positions[col_name] < len(df_full.columns):
                                        value = df_full.iloc[row_idx, column_positions[col_name]]
                                        return str(value).strip() if pd.notna(value) else ''
                                    return ''
                                
                                row_data = {
                                    'Код КССС/id': str(code_value).strip(),
                                    'Краткое наименование нормализованное': get_safe_value("Краткое наименование нормализованное"),
                                    'Полное наименование нормализованное': get_safe_value("Полное наименование нормализованное"),
                                    'Краткое наименование КССС (исх)': get_safe_value("Краткое наименование КССС (исх)"),
                                    'Статус': get_safe_value("Статус"),
                                    'Папка': folder_name,
                                    'Имя файла': file
                                }
                                file_data.append(row_data)
                            else:
                                consecutive_empty += 1
                                
                            # Если встретили 5 последовательных пропусков, прекращаем обработку этого файла
                            if consecutive_empty >= 5:
                                break
                                
                        except Exception as e:
                            # В случае ошибки чтения строки считаем это пропуском
                            consecutive_empty += 1
                            if consecutive_empty >= 5:
                                break
                            continue
                    
                    if file_data:
                        df_file = pd.DataFrame(file_data)
                        df_parse = pd.concat([df_parse, df_file], ignore_index=True)
                        print(f"✓ Файл {file} обработан, записей: {len(file_data)}")
                    
                except Exception as e:
                    log_msg = f"Ошибка в файле {file}: {str(e)}"
                    print(log_msg)
                    logs.append({
                        'Тип ошибки': 'Ошибка обработки',
                        'Файл': file,
                        'Папка': folder_name,
                        'Сообщение': str(e)
                    })
    
    return df_parse, logs

# %%
# Шаг 4: Запуск парсинга
root_folder = "шаблоны"  # замените на ваш путь
df_parse, logs = parse_excel_files(root_folder)

# Шаг 5: Сохранение логов
if logs:
    df_logs = pd.DataFrame(logs)
    df_logs.to_excel("Лог.xlsx", index=False)
    print("Логи сохранены в Лог.xlsx")

# Шаг 6: Сохранение результатов
if not df_parse.empty:
    df_parse.to_excel("результат парсинга.xlsx", index=False)
    print("Результат сохранен в 'результат парсинга.xlsx'")
    
    print("\nСтатистика:")
    print(f"Всего записей: {len(df_parse)}")
    print(f"Уникальных файлов: {df_parse['Имя файла'].nunique()}")
    print(f"Уникальных папок: {df_parse['Папка'].nunique()}")
    
    print("\nПервые 5 записей:")
    display(df_parse.head())
else:
    print("Данные не найдены")
# Out:
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Армат.xlsx
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Арматура_согласовано_к_загрузке.xlsx
# ✓ Файл Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx обработан, записей: 62
# ✓ Файл Арматура устьевая прочая_87.xlsx обработан, записей: 417
# ✓ Файл Блоки клапанов предохр. стальные_39.xlsx обработан, записей: 205
# ✓ Файл Блоки клапанов предохр. стальные_40.xlsx обработан, записей: 205
# ✓ Файл Блоки клапанов предохр_40.xlsx обработан, записей: 205
# ✓ Файл Задвижки дисковые, штуцерные_22.xlsx обработан, записей: 50
# ✓ Файл Задвижки дисковые, штуцерные_33.xlsx обработан, записей: 50
# ✓ Файл Задвижки дисковые_33.xlsx обработан, записей: 50
# Не найдены колонки в файле Задвижки клиновые_340_.xlsx: Код КССС/id
# ✓ Файл Задвижки прочие_11.xlsx обработан, записей: 374
# ✓ Файл Задвижки стальные_14.xlsx обработан, записей: 116
# ✓ Файл Задвижки стальные_801.xlsx обработан, записей: 1796
# ✓ Файл Задвижки шиберные_66.xlsx обработан, записей: 138
# ✓ Файл Затворы дисковые стальные_9.xlsx обработан, записей: 744
# ✓ Файл Затворы дисковые_223.xlsx обработан, записей: 744
# Не найдены колонки в файле ЗиП, части и детали арматуры прочие_105.xlsx: Код КССС/id, Краткое наименование КССС (исх)
# ✓ Файл Клапаны запорные прочие_9.xlsx обработан, записей: 9
# ✓ Файл Клапаны запорные стальные_193.xlsx обработан, записей: 814
# ✓ Файл Клапаны запорные стальные_62.xlsx обработан, записей: 805
# ✓ Файл Клапаны запорные, регулирующие прочие_4.xlsx обработан, записей: 1130
# ✓ Файл Клапаны обратные прочие_14.xlsx обработан, записей: 14
# ✓ Файл Клапаны обратные стальные_179.xlsx обработан, записей: 970
# ✓ Файл Клапаны обратные стальные_85.xlsx обработан, записей: 958
# Не найдены колонки в файле Клапаны пружинные пред_111.xlsx: Код КССС/id
# ✓ Файл Клапаны пружинные предохр. прочие_1.xlsx обработан, записей: 1
# ✓ Файл Клапаны пружинные предохр. стальные_108.xlsx обработан, записей: 701
# ✓ Файл Клапаны пружинные предохр. стальные_9.xlsx обработан, записей: 701
# ✓ Файл Клапаны распр.,устр.пер_30.xlsx обработан, записей: 77
# ✓ Файл Клапаны распределит., устр.переключающие_30.xlsx обработан, записей: 77
# ✓ Файл Клапаны регулирующие стальные_12.xlsx обработан, записей: 1560
# ✓ Файл Клапаны регулирующие стальные_204.xlsx обработан, записей: 1560
# ✓ Файл Клапаны регулирующие_536.xlsx обработан, записей: 3528
# ✓ Файл Краны шаровые прочие_1.xlsx обработан, записей: 133
# ✓ Файл Краны шаровые стальные_129.xlsx обработан, записей: 1767
# ✓ Файл Краны шаровые стальные_7.xlsx обработан, записей: 1767
# ✓ Файл Обвязки, головки колонные_38.xlsx обработан, записей: 167
# ✓ Файл Пневмоприводы для арматуры трубопров_1.xlsx обработан, записей: 2
# ✓ Файл Регуляторы давления_62.xlsx обработан, записей: 231
# ✓ Файл Узлы детали приводов арматуры трубопров_24.xlsx обработан, записей: 117
# Не найдены колонки в файле Узлы,детали приводов арматуры трубопров_397.xlsx: Код КССС/id, Краткое наименование КССС (исх)
# ✓ Файл Электроприводы для арматуры трубопров_112.xlsx обработан, записей: 179
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Двигатели.xlsx
# Ошибка в файле ~$Гидро- и пневмораспределители_59.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# Ошибка в файле ~$Насосы гидравл. дгидравл. оборудования_10.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# ✓ Файл Вариаторы_1.xlsx обработан, записей: 1
# ✓ Файл Гидро- и пневмораспределители_59.xlsx обработан, записей: 84
# ✓ Файл Двигатели внутреннего сгорания поршневые_6.xlsx обработан, записей: 12
# ✓ Файл Двигатели газотурбинные_6.xlsx обработан, записей: 18
# ✓ Файл Двигатели гидравлические_4.xlsx обработан, записей: 4
# ✓ Файл Механизмы исполнительные пневматические_1.xlsx обработан, записей: 3
# ✓ Файл Механизмы исполнительные электрические_17.xlsx обработан, записей: 36
# ✓ Файл Мотор-редукторы_18.xlsx обработан, записей: 84
# ✓ Файл Муфты механ. общепром. назначения_9.xlsx обработан, записей: 69
# ✓ Файл Насосы гидравл. дгидравл. оборудования_10.xlsx обработан, записей: 30
# ✓ Файл Приводы моторные_4.xlsx обработан, записей: 10
# ✓ Файл Приводы насосов прочие_26.xlsx обработан, записей: 39
# ✓ Файл Приводы насосов прочие_62.xlsx обработан, записей: 77
# ✓ Файл Приводы насосов_7.xlsx обработан, записей: 21
# ✓ Файл Приводы пневматические_3.xlsx обработан, записей: 45
# ✓ Файл Приводы, станции гидравлические_6.xlsx обработан, записей: 26
# ✓ Файл Редукторы механические_20.xlsx обработан, записей: 77
# ✓ Файл Станки-качалки_2.xlsx обработан, записей: 18
# ✓ Файл Станки-качалки_38.xlsx обработан, записей: 54
# ✓ Файл Толкатели_6.xlsx обработан, записей: 13
# ✓ Файл Части, дет. двигат., прив.,мех. прочие_489.xlsx обработан, записей: 933
# ✓ Файл Части, дет. двигат., прив.,мех. прочие_506.xlsx обработан, записей: 933
# ✓ Файл Электродвигатели асинхронные общ. назн_485.xlsx обработан, записей: 694
# ✓ Файл Электродвигатели дисполнит. механизмов_4.xlsx обработан, записей: 11
# ✓ Файл Электродвигатели крановые_12.xlsx обработан, записей: 12
# ✓ Файл Электродвигатели погружные вентильные_11.xlsx обработан, записей: 15
# ✓ Файл Электродвигатели синхронные общ. назн_3.xlsx обработан, записей: 6
# ✓ Файл Электродвигатели тяговые_1.xlsx обработан, записей: 2
# ✓ Файл Электромагниты_8.xlsx обработан, записей: 9
# ✓ Файл Вышки и мачты мобильные_17.xlsx обработан, записей: 28
# ✓ Файл Здания мобильные (инвентарные)_14.xlsx обработан, записей: 65
# ✓ Файл Здания назн. обустр. местор. моб_7.xlsx обработан, записей: 7
# ✓ Файл Сооружения назн. обустр. местор. стац_4.xlsx обработан, записей: 4
# ✓ Файл Сооружения назн. энерг. инфрастр. стац_15.xlsx обработан, записей: 30
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Инструменты (1).xlsx
# Ошибка в файле ~$Круги эльборовые шлифовальные_2.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# Ошибка в файле ~$Опрыскиватели садовые и воздуходувки_18.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# ✓ Файл Бородки_2.xlsx обработан, записей: 8
# ✓ Файл Бруски шлифовальные_5.xlsx обработан, записей: 5
# ✓ Файл Бумага шлифовальная_81.xlsx обработан, записей: 202
# ✓ Файл Валики и ролики малярные_11.xlsx обработан, записей: 107
# ✓ Файл Верстаки слесарные_8.xlsx обработан, записей: 50
# ✓ Файл Втулки переходные конусные_12.xlsx обработан, записей: 21
# ✓ Файл Газонокосилки, триммеры, мотокосы_141.xlsx обработан, записей: 167
# ✓ Файл Гайковерты_шуруповерты_дрели-шуруповерты_222.xlsx обработан, записей: 261
# ✓ Файл Гири_15.xlsx обработан, записей: 28
# ✓ Файл Головки для резаков и ножниц_16.xlsx обработан, записей: 21
# ✓ Файл Головки обрабатывающие_3.xlsx обработан, записей: 3
# ✓ Файл Дальномеры электронные_44.xlsx обработан, записей: 46
# ✓ Файл Детали, запч. и компл. инстр. и уст-в пр_296.xlsx обработан, записей: 593
# ✓ Файл Диски(круги) для дисковых пил_15.xlsx обработан, записей: 18
# ✓ Файл Долота и стамески_5.xlsx обработан, записей: 26
# ✓ Файл Дрели и перфораторы_117.xlsx обработан, записей: 130
# ✓ Файл Зубила_37.xlsx обработан, записей: 69
# ✓ Файл Инжекторы масла и масленки_16.xlsx обработан, записей: 24
# Не найдены колонки в файле Инструмент и оснастка кузнечно-штампов_3.xlsx: Краткое наименование КССС (исх)
# ✓ Файл Инструмент разметочный_281.xlsx обработан, записей: 575
# ✓ Файл Инструмент ручной рубящий_21.xlsx обработан, записей: 69
# ✓ Файл Инструмент ручной строгальный_5.xlsx обработан, записей: 7
# ✓ Файл Инструмент ручной ударный_113.xlsx обработан, записей: 245
# ✓ Файл Инструмент ручной ударный_118.xlsx обработан, записей: 245
# ✓ Файл Инструмент шарнирно-губцевый_63.xlsx обработан, записей: 208
# ✓ Файл Инструменты для вальцовки и компл-щие_7.xlsx обработан, записей: 20
# ✓ Файл Инструменты и оснастка  гибочные_32.xlsx обработан, записей: 46
# ✓ Файл Инструменты правящие(алмазные)_4.xlsx обработан, записей: 14
# ✓ Файл Инструменты штукатурные многофункц_4.xlsx обработан, записей: 4
# ✓ Файл Кернеры_8.xlsx обработан, записей: 15
# ✓ Файл Кисти малярные_35.xlsx обработан, записей: 214
# ✓ Файл Клейма_37.xlsx обработан, записей: 45
# ✓ Файл Клещи и инструмент для проводов и кабелей_57.xlsx обработан, записей: 81
# ✓ Файл Клины разжимные и расширители_8.xlsx обработан, записей: 14
# ✓ Файл Ключи гаечные и монтажные_290.xlsx обработан, записей: 1796
# ✓ Файл Косы_4.xlsx обработан, записей: 5
# ✓ Файл Краскопульты и краскораспылители_53.xlsx обработан, записей: 108
# ✓ Файл Круги диски сегменты алмазные отрезные_12.xlsx обработан, записей: 15
# ✓ Файл Круги и диски абразивные_95.xlsx обработан, записей: 387
# ✓ Файл Круги и диски алмазные шлифовальные_12.xlsx обработан, записей: 19
# ✓ Файл Круги эльборовые шлифовальные_2.xlsx обработан, записей: 3
# ✓ Файл Кусачки_26.xlsx обработан, записей: 67
# ✓ Файл Кусторезы_сучкорезы_секаторы_20.xlsx обработан, записей: 24
# ✓ Файл Лампы паяльные_11.xlsx обработан, записей: 13
# Не найдены колонки в файле Ленты и цепи для пил_58.xlsx: Краткое наименование КССС (исх)
# ✓ Файл Леса и вышки_21.xlsx обработан, записей: 45
# ✓ Файл Ломы, гвоздодеры, монтировки, монтажки_43.xlsx обработан, записей: 104
# ✓ Файл Мастерки (кельмы, лопатки и отрезовки)_2.xlsx обработан, записей: 4
# Не найдены колонки в файле Машинки резьбонарезные и клуппы_1.xlsx: Краткое наименование КССС (исх)
# ✓ Файл Машины шлифовальные и полировальные_209.xlsx обработан, записей: 251
# ✓ Файл Метчики ловильные_2.xlsx обработан, записей: 5
# ✓ Файл Метчики резьбонарезные_192.xlsx обработан, записей: 380
# ✓ Файл Молотки отбойные рубильные и бетоноломы_3.xlsx обработан, записей: 27
# ✓ Файл Мотыги, тяпки_15.xlsx обработан, записей: 27
# ✓ Файл Наборы и оснастки паяльные_11.xlsx обработан, записей: 14
# ✓ Файл Наборы инструментов обрабатывающих_488.xlsx обработан, записей: 775
# ✓ Файл Наборы инструментов слесарно-монтажные_358.xlsx обработан, записей: 563
# ✓ Файл Наборы строительные_6.xlsx обработан, записей: 7
# ✓ Файл Напильники_рашпили_надфили_146.xlsx обработан, записей: 220
# ✓ Файл Насадки, приспособл. к инструменту_183.xlsx обработан, записей: 539
# ✓ Файл Ножи, лески триммерные, общетехнич_67.xlsx обработан, записей: 178
# ✓ Файл Ножницы и резаки общетехнич_224.xlsx обработан, записей: 323
# ✓ Файл Опрыскиватели садовые и воздуходувки_18.xlsx обработан, записей: 52
# ✓ Файл Опрыскиватели садовые и воздуходувки_29.xlsx обработан, записей: 52
# ✓ Файл Оснастка для перфораторов_48.xlsx обработан, записей: 140
# ✓ Файл Отвертки_121.xlsx обработан, записей: 408
# ✓ Файл Патроны зажимные_25.xlsx обработан, записей: 45
# ✓ Файл Паяльники электрические_2.xlsx обработан, записей: 53
# ✓ Файл Пилы, ножовки, лобзики_208.xlsx обработан, записей: 309
# ✓ Файл Пистолеты (ручной инструмент)_55.xlsx обработан, записей: 82
# ✓ Файл Плашки резьбонарезные_136.xlsx обработан, записей: 285
# ✓ Файл Плиткорезы и стеклорезы_3.xlsx обработан, записей: 6
# ✓ Файл Пломбираторы_3.xlsx обработан, записей: 9
# ✓ Файл Полотна ножовочные_25.xlsx обработан, записей: 124
# ✓ Файл Развертки_33.xlsx обработан, записей: 94
# ✓ Файл Разгонщики_26.xlsx обработан, записей: 46
# Не найдены колонки в файле Резцы резьбовые_27.xlsx: Краткое наименование КССС (исх)
# ✓ Файл Резцы токарные (кроме резьбовых)_128.xlsx обработан, записей: 274
# ✓ Файл Сверла_548.xlsx обработан, записей: 861
# ✓ Файл Стусла_1.xlsx обработан, записей: 1
# ✓ Файл Сумки, футляры, кожухи, кобуры и кейсы_22.xlsx обработан, записей: 150
# ✓ Файл Съемники_60.xlsx обработан, записей: 101
# ✓ Файл Терки и полутерки_1.xlsx обработан, записей: 1
# ✓ Файл Техника вибрационного типа_4.xlsx обработан, записей: 4
# ✓ Файл Тиски и тисы_28.xlsx обработан, записей: 170
# ✓ Файл Уст-ва дврезки отводов в трубопроводы_8.xlsx обработан, записей: 10
# ✓ Файл Устройства для установки заклепок_12.xlsx обработан, записей: 44
# ✓ Файл Фрезы_129.xlsx обработан, записей: 479
# ✓ Файл Фрезы_222.xlsx обработан, записей: 479
# ✓ Файл Черенки и ручки к инструменту_12.xlsx обработан, записей: 40
# Не найдены колонки в файле Шаберы_1.xlsx: Краткое наименование КССС (исх)
# ✓ Файл Шпатели_10.xlsx обработан, записей: 15
# ✓ Файл Щетки д.зачистных, шлиф. и полир. машин_28.xlsx обработан, записей: 60
# ✓ Файл Щетки_17.xlsx обработан, записей: 70
# ✓ Файл Экстракторы_8.xlsx обработан, записей: 24
# ✓ Файл USB-Токены_8.xlsx обработан, записей: 10
# ✓ Файл Адаптеры компьютерные_17.xlsx обработан, записей: 20
# ✓ Файл Аксессуары компьютерные_211.xlsx обработан, записей: 246
# ✓ Файл Антенны_30.xlsx обработан, записей: 107
# ✓ Файл Аппараты телефонные (телефоны)_105.xlsx обработан, записей: 411
# ✓ Файл Блоки системные_22.xlsx обработан, записей: 102
# ✓ Файл Вентиляторы приборные (компьютерные)_61.xlsx обработан, записей: 68
# ✓ Файл Видеокарты_20.xlsx обработан, записей: 34
# ✓ Файл Дет. телеф., радио-, звук-, видеотехники_148.xlsx обработан, записей: 183
# ✓ Файл Дет. телеф., радио-, звук-, видеотехники_154.xlsx обработан, записей: 183
# ✓ Файл Детали АСУТП_312.xlsx обработан, записей: 489
# ✓ Файл Детали компьютерные и мультимедиа_31.xlsx обработан, записей: 68
# ✓ Файл Диски (CD и DVD)_13.xlsx обработан, записей: 35
# ✓ Файл Диски жесткие (накопители твердотельные)_54.xlsx обработан, записей: 239
# ✓ Файл Документация техническая_9.xlsx обработан, записей: 14
# ✓ Файл Документы нормативные_48.xlsx обработан, записей: 174
# ✓ Файл Знаки_193.xlsx обработан, записей: 467
# ✓ Файл Карты звуковые_4.xlsx обработан, записей: 5
# ✓ Файл Карты памяти_27.xlsx обработан, записей: 48
# ✓ Файл Клавиатуры_26.xlsx обработан, записей: 35
# ✓ Файл Коммутаторы_36.xlsx обработан, записей: 395
# ✓ Файл Комплекты (Клавиатура и мышь)_17.xlsx обработан, записей: 19
# ✓ Файл Материалы информационные и платежные пр_15.xlsx обработан, записей: 15
# ✓ Файл Материалы справочные_3.xlsx обработан, записей: 3
# ✓ Файл Модемы, роутеры, маршрутизаторы_166.xlsx обработан, записей: 210
# ✓ Файл Модули оперативной памяти_31.xlsx обработан, записей: 65
# ✓ Файл Мониторы компьютерные_218.xlsx обработан, записей: 275
# ✓ Файл Мыши (манипуляторы)_48.xlsx обработан, записей: 66
# ✓ Файл Ноутбуки_16.xlsx обработан, записей: 161
# ✓ Файл Оборуд. диспетчер. и оператор. связи_53.xlsx обработан, записей: 98
# ✓ Файл Планшеты_43.xlsx обработан, записей: 66
# ✓ Файл Платы материнские_7.xlsx обработан, записей: 11
# ✓ Файл Приводы CD и DVD_16.xlsx обработан, записей: 23
# ✓ Файл Программаторы_6.xlsx обработан, записей: 14
# ✓ Файл Проектно-компонуемые АСУ технологическими процессами_86.xlsx обработан, записей: 86
# ✓ Файл Процессоры для АРМ_11.xlsx обработан, записей: 13
# ✓ Файл Процессоры дпром_систем (контроллеры)_43.xlsx обработан, записей: 49
# ✓ Файл ПС автоматизированного проектирования_1.xlsx обработан, записей: 1
# ✓ Файл ПС аудита действий пользователей_1.xlsx обработан, записей: 1
# ✓ Файл ПС ведения проектов_1.xlsx обработан, записей: 1
# ✓ Файл ПС для комплексных решений АСУТП_3.xlsx обработан, записей: 3
# ✓ Файл ПС для конфигурирования ПЛК и КИПиА_7.xlsx обработан, записей: 9
# ✓ Файл ПС для расчетов технолог. и конструк_2.xlsx обработан, записей: 2
# ✓ Файл ПС для создания чел.-машин. интерфейса_3.xlsx обработан, записей: 3
# ✓ Файл ПС документооборота технического_1.xlsx обработан, записей: 1
# ✓ Файл ПС защиты антивирусной_4.xlsx обработан, записей: 8
# ✓ Файл ПС защиты серверного оборудования_1.xlsx обработан, записей: 1
# ✓ Файл ПС защиты сетевой_1.xlsx обработан, записей: 1
# ✓ Файл ПС моделирования геологического_4.xlsx обработан, записей: 4
# ✓ Файл ПС мониторинга ресурсов инфраструктуры_2.xlsx обработан, записей: 2
# ✓ Файл ПС просмотра файлов_1.xlsx обработан, записей: 1
# ✓ Файл ПС работы с офисными документами_1.xlsx обработан, записей: 1
# ✓ Файл ПС расчета геолого-технолог. мероприятий_4.xlsx обработан, записей: 4
# ✓ Файл ПС Редакторы графические_1.xlsx обработан, записей: 1
# ✓ Файл ПС сканирования документов_1.xlsx обработан, записей: 1
# ✓ Файл ПС сканирования и распознавания док_1.xlsx обработан, записей: 1
# ✓ Файл ПС технологического видеонаблюдения_2.xlsx обработан, записей: 2
# ✓ Файл ПС управления оборудованием_5.xlsx обработан, записей: 6
# ✓ Файл ПС управления серверным оборудованием_1.xlsx обработан, записей: 1
# ✓ Файл ПС управления сетями_1.xlsx обработан, записей: 1
# ✓ Файл ПС управления средствами безопасности_2.xlsx обработан, записей: 2
# ✓ Файл ПС хранения сертификатов_1.xlsx обработан, записей: 1
# ✓ Файл Пульты управления (панели оператора)_70.xlsx обработан, записей: 107
# ✓ Файл Радиостанции_48.xlsx обработан, записей: 225
# ✓ Файл Радиоустройства (кроме антенн)_22.xlsx обработан, записей: 104
# ✓ Файл Серверы и рабочие станции_15.xlsx обработан, записей: 143
# ✓ Файл Системы видеонаблюдения_85.xlsx обработан, записей: 105
# ✓ Файл Системы контроля доступа_21.xlsx обработан, записей: 24
# ✓ Файл Системы хранения данных (СХД)_7.xlsx обработан, записей: 17
# ✓ Файл Смартфоны_25.xlsx обработан, записей: 57
# ✓ Файл Средства защиты информационные_91.xlsx обработан, записей: 125
# ✓ Файл Средства программные и технические проч_17.xlsx обработан, записей: 18
# ✓ Файл Станции (системы) связи оперативной_28.xlsx обработан, записей: 78
# ✓ Файл Таблички, вывески и наклейки_142.xlsx обработан, записей: 394
# ✓ Файл Узлы домофонов_6.xlsx обработан, записей: 8
# ✓ Файл Узлы и уст-ва связи, охр и сиг-ции пр_147.xlsx обработан, записей: 223
# ✓ Файл Узлы сетей и систем связи_150.xlsx обработан, записей: 316
# ✓ Файл Узлы сетей компьютерных_74.xlsx обработан, записей: 557
# ✓ Файл Устройства контроля доступа_30.xlsx обработан, записей: 44
# ✓ Файл Устройства предоставления информации (УПИ)_40.xlsx обработан, записей: 42
# ✓ Файл Факсы (телефаксы)_18.xlsx обработан, записей: 24
# ✓ Файл Флеш-накопители_80.xlsx обработан, записей: 122
# ✓ Файл Хранилища сетевые_2.xlsx обработан, записей: 4
# ✓ Файл Части и компл-щие охран оборуд_21.xlsx обработан, записей: 49
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_КИПиА (3).xlsx
# Ошибка в файле ~$Расходомеры массовые (кориолисовые)_117.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# ✓ Файл Арматура к приборам контроля давления_96.xlsx обработан, записей: 237
# ✓ Файл Вакуумметры (мановакуумметры)_107.xlsx обработан, записей: 180
# ✓ Файл Гильзы защитные (для датч. температур)_68.xlsx обработан, записей: 442
# ✓ Файл Датчики виброскорости_10.xlsx обработан, записей: 51
# ✓ Файл Датчики давления_357.xlsx обработан, записей: 1295
# ✓ Файл Датчики плотности_4.xlsx обработан, записей: 10
# ✓ Файл Диафрагмы_20.xlsx обработан, записей: 118
# ✓ Файл Извещатели и оповещатели_300.xlsx обработан, записей: 471
# ✓ Файл Измерители акустических величин_15.xlsx обработан, записей: 16
# ✓ Файл Измерители времени_24.xlsx обработан, записей: 39
# ✓ Файл Измерители и датчики механ. величин_127.xlsx обработан, записей: 326
# ✓ Файл Измерители и датчики оптич величин_63.xlsx обработан, записей: 123
# ✓ Файл Измерители и датчики силы, веса и массы_21.xlsx обработан, записей: 31
# ✓ Файл Измерители и датчики эл. и магн. величин_177.xlsx обработан, записей: 436
# ✓ Файл Измерители радиационных величин_38.xlsx обработан, записей: 41
# ✓ Файл Измерители термических харак-тик в-в_22.xlsx обработан, записей: 31
# ✓ Файл Измерители формы сигналов и спектра_7.xlsx обработан, записей: 8
# ✓ Файл Калибраторы и приборы поверки_18.xlsx обработан, записей: 38
# ✓ Файл Калибры (калибр-кольца, калибр-пробки)_157.xlsx обработан, записей: 175
# ✓ Файл Компл. приб., датч., изм. инстр. пр_89.xlsx обработан, записей: 2584
# ✓ Файл Компьютеры промышленные (индустриальные)_1.xlsx обработан, записей: 18
# ✓ Файл Манометры бэлектр. комп. прочие_10.xlsx обработан, записей: 37
# ✓ Файл Манометры показывающие_878.xlsx обработан, записей: 2888
# ✓ Файл Манометры сигнализ. (электроконтактные)_166.xlsx обработан, записей: 503
# ✓ Файл Манометры сигнализирующие_79.xlsx обработан, записей: 302
# ✓ Файл Манометры электроконтактные_115.xlsx обработан, записей: 196
# ✓ Файл Напоромеры_41.xlsx обработан, записей: 47
# ✓ Файл Преобразователи давления_250.xlsx обработан, записей: 930
# ✓ Файл Преобразователи сигналов_94.xlsx обработан, записей: 305
# ✓ Файл Приборы метеорологические_93.xlsx обработан, записей: 125
# ✓ Файл Расходомеры вихревые_68.xlsx обработан, записей: 343
# ✓ Файл Расходомеры массовые (кориолисовые)_117.xlsx обработан, записей: 225
# ✓ Файл Расходомеры прочие_271.xlsx обработан, записей: 440
# ✓ Файл Расходомеры термально-массовые_6.xlsx обработан, записей: 14
# ✓ Файл Расходомеры ультразвуковые_74.xlsx обработан, записей: 186
# ✓ Файл Расходомеры электромагнитные_59.xlsx обработан, записей: 98
# ✓ Файл Регистраторы и регуляторы_78.xlsx обработан, записей: 222
# ✓ Файл Сигнализаторы загазованности_4.xlsx обработан, записей: 15
# ✓ Файл Термометры показыв., вкл. лабораторные_96.xlsx обработан, записей: 627
# ✓ Файл Термометры показывающие_103.xlsx обработан, записей: 627
# ✓ Файл Термометры сигнализирующие_10.xlsx обработан, записей: 18
# ✓ Файл Термометры сопротивления и термопары многозонные_11.xlsx обработан, записей: 26
# ✓ Файл Термопреобразователи (термометры) сопротивления_62.xlsx обработан, записей: 1748
# ✓ Файл Термочехлы и чехлы защитные_5.xlsx обработан, записей: 107
# Не найдены колонки в файле Термоэлектрические преобразователи (термопары)_26.xlsx: Краткое наименование КССС (исх)
# ✓ Файл Трассоискатели_10.xlsx обработан, записей: 18
# ✓ Файл Узлы систем телеметрических_8.xlsx обработан, записей: 10
# ✓ Файл Уровнемеры_370.xlsx обработан, записей: 1780
# ✓ Файл Уст-ва охраны, контроля и сигнализ.проч_126.xlsx обработан, записей: 223
# ✓ Файл Устройства учета тепла_21.xlsx обработан, записей: 41
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Лабораторн.xlsx
# Ошибка в файле ~$Электроды для потенциометрич. анализа_68.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# ✓ Файл Анализаторы лабораторные_52.xlsx обработан, записей: 362
# ✓ Файл Бани лабораторные_37.xlsx обработан, записей: 50
# ✓ Файл Вискозиметры_54.xlsx обработан, записей: 66
# ✓ Файл Датчики химические_20.xlsx обработан, записей: 66
# ✓ Файл Дозаторы и диспенсеры лабораторные_107.xlsx обработан, записей: 174
# ✓ Файл Измерители и датчики влажности_71.xlsx обработан, записей: 85
# ✓ Файл Измерители концентрац. и хим состава в-в_113.xlsx обработан, записей: 520
# ✓ Файл Измерители механ. парам-ров жидк., газов_70.xlsx обработан, записей: 143
# ✓ Файл Инструменты захвата лабораторные_23.xlsx обработан, записей: 61
# ✓ Файл Колбонагреватели_43.xlsx обработан, записей: 50
# ✓ Файл Колонки, пластин. допред. хим.с-ва в-ва_59.xlsx обработан, записей: 117
# ✓ Файл Комплектующие лабораторного оборудования_812.xlsx обработан, записей: 1596
# ✓ Файл Мебель лабораторная и шкафы вытяжные_202.xlsx обработан, записей: 386
# ✓ Файл Мешалки лабораторные_34.xlsx обработан, записей: 55
# ✓ Файл Микроскопы_11.xlsx обработан, записей: 15
# ✓ Файл Печи и шкафы сушильные лабораторные_40.xlsx обработан, записей: 80
# ✓ Файл Посуда лабораторная мерная металлическая_1.xlsx обработан, записей: 2
# ✓ Файл Посуда лабораторная мерная пластиковая_27.xlsx обработан, записей: 42
# ✓ Файл Посуда лабораторная мерная прочая_2.xlsx обработан, записей: 32
# ✓ Файл Посуда лабораторная мерная стеклянная_350.xlsx обработан, записей: 451
# ✓ Файл Посуда лабораторная немерная металлич_24.xlsx обработан, записей: 42
# ✓ Файл Посуда лабораторная немерная пластиковая_75.xlsx обработан, записей: 117
# ✓ Файл Посуда лабораторная немерная прочая_32.xlsx обработан, записей: 251
# ✓ Файл Посуда лабораторная немерная стеклянная_452.xlsx обработан, записей: 702
# ✓ Файл Посуда лабораторная немерная фарфоровая_56.xlsx обработан, записей: 65
# ✓ Файл Пробоотборники и аспираторы_117.xlsx обработан, записей: 187
# ✓ Файл Сита лабораторные и комплектующие сит_12.xlsx обработан, записей: 42
# ✓ Файл Сосуды уравнит. конденс. разделит_1.xlsx обработан, записей: 4
# ✓ Файл Термостаты лабораторные_46.xlsx обработан, записей: 66
# ✓ Файл Устройства и оснастка лабораторные_77.xlsx обработан, записей: 408
# ✓ Файл Хроматографы_14.xlsx обработан, записей: 43
# ✓ Файл Штативы_28.xlsx обработан, записей: 60
# ✓ Файл Электроды для потенциометрич. анализа_68.xlsx обработан, записей: 163
# ✓ Файл Ячейки и кюветы измерительные_21.xlsx обработан, записей: 54
# ✓ Файл Абразивы_13.xlsx обработан, записей: 40
# ✓ Файл Бетоны_18.xlsx обработан, записей: 42
# ✓ Файл Брус, бруски_8.xlsx обработан, записей: 65
# ✓ Файл Ветошь_2.xlsx обработан, записей: 8
# ✓ Файл Вещества поверхностно-активные_4.xlsx обработан, записей: 64
# ✓ Файл Вода нескладируемая_4.xlsx обработан, записей: 10
# ✓ Файл Вода складируемая_1.xlsx обработан, записей: 4
# ✓ Файл Войлок технический_5.xlsx обработан, записей: 13
# ✓ Файл Волокна_2.xlsx обработан, записей: 3
# ✓ Файл Глинонаполнители (глины)_4.xlsx обработан, записей: 7
# ✓ Файл Графит_5.xlsx обработан, записей: 5
# ✓ Файл Деэмульгаторы для подготовки нефти_121.xlsx обработан, записей: 186
# ✓ Файл Деэмульгаторы прочие_3.xlsx обработан, записей: 3
# ✓ Файл Доска_13.xlsx обработан, записей: 65
# ✓ Файл Изделия дерев. плотничные и столярные_10.xlsx обработан, записей: 45
# ✓ Файл Изделия для колодцев трубопр_железоб_31.xlsx обработан, записей: 58
# ✓ Файл Ингибитор коррозии_17.xlsx обработан, записей: 209
# ✓ Файл Ингибиторы от солеотложений_14.xlsx обработан, записей: 49
# ✓ Файл Ингибиторы парафиноотложений_15.xlsx обработан, записей: 43
# ✓ Файл Ингибиторы химические прочие_18.xlsx обработан, записей: 97
# ✓ Файл Индикаторы химические_97.xlsx обработан, записей: 331
# ✓ Файл Картон технический_1.xlsx обработан, записей: 6
# ✓ Файл Катализаторы отработанные_44.xlsx обработан, записей: 206
# ✓ Файл Катализаторы прочие_104.xlsx обработан, записей: 594
# ✓ Файл Кирпич_4.xlsx обработан, записей: 31
# ✓ Файл Кислоты неорганические_39.xlsx обработан, записей: 72
# Не найдены колонки в файле Кислоты органические и их соли прочие_30.xlsx: Краткое наименование КССС (исх)
# ✓ Файл Клеи и герметики_18.xlsx обработан, записей: 427
# ✓ Файл Колеры, краски, грунтовки и покрытия_163.xlsx обработан, записей: 1333
# ✓ Файл Крошка и посыпка минеральная_2.xlsx обработан, записей: 3
# ✓ Файл Латексы и каучуки_1.xlsx обработан, записей: 1
# ✓ Файл Ленты и пленки монтажные, отделочные_11.xlsx обработан, записей: 127
# ✓ Файл Ленты уплотнительные_15.xlsx обработан, записей: 45
# ✓ Файл Линолеумы, покрытия для пола_20.xlsx обработан, записей: 100
# ✓ Файл Мастики_6.xlsx обработан, записей: 12
# ✓ Файл Материалы гидроизоляционные ленточные и рулонные_30.xlsx обработан, записей: 86
# ✓ Файл Материалы жив. и раст. происхож. прочие_1.xlsx обработан, записей: 3
# ✓ Файл Материалы из прессованных древесины частиц_20.xlsx обработан, записей: 28
# ✓ Файл Материалы нетканые_2.xlsx обработан, записей: 27
# ✓ Файл Материалы прокладочные асбестовые_103.xlsx обработан, записей: 158
# ✓ Файл Материалы прокладочные графитовые_27.xlsx обработан, записей: 27
# ✓ Файл Материалы слоистые на основе ткани_3.xlsx обработан, записей: 27
# ✓ Файл Материалы теплоиз. листовые и рулонные_45.xlsx обработан, записей: 160
# ✓ Файл Материалы теплоиз. прочие_8.xlsx обработан, записей: 48
# ✓ Файл Материалы теплоизоляционные волокнистые нетканые_8.xlsx обработан, записей: 73
# ✓ Файл Материалы теплоизоляционные вспененные_10.xlsx обработан, записей: 32
# ✓ Файл Материалы теплоизоляционные ленточные_6.xlsx обработан, записей: 22
# ✓ Файл Материалы теплоизоляционные цилиндрические_59.xlsx обработан, записей: 86
# ✓ Файл Материалы теплоизоляционные шнуровые_10.xlsx обработан, записей: 16
# ✓ Файл Материалы тканые_5.xlsx обработан, записей: 29
# ✓ Файл Материалы фильтрующие_7.xlsx обработан, записей: 74
# ✓ Файл Материалы электроиз. композиционные_5.xlsx обработан, записей: 9
# ✓ Файл Материалы электроиз. лент. и пленочные_6.xlsx обработан, записей: 181
# ✓ Файл Материалы электроиз. листовые и рулонные_1.xlsx обработан, записей: 4
# ✓ Файл Материалы электроиз. тканые_4.xlsx обработан, записей: 20
# ✓ Файл Материалы электроизоляционные трубчатые_32.xlsx обработан, записей: 100
# ✓ Файл Набивки сальниковые_218.xlsx обработан, записей: 342
# ✓ Файл Наполнители гранульные и кусковые прочие_13.xlsx обработан, записей: 34
# ✓ Файл Нити_1.xlsx обработан, записей: 2
# ✓ Файл Образцы стандартные_945.xlsx обработан, записей: 2945
# ✓ Файл Огнеупоры_19.xlsx обработан, записей: 169
# ✓ Файл Одоранты_1.xlsx обработан, записей: 2
# ✓ Файл Оксиды неорганич., пероксиды, озониды_21.xlsx обработан, записей: 51
# ✓ Файл Оксосоединения и их производные_8.xlsx обработан, записей: 18
# ✓ Файл Основания неорганические прочие_10.xlsx обработан, записей: 32
# ✓ Файл Основания органич., амины, их соли, ЦАС_17.xlsx обработан, записей: 47
# ✓ Файл Отвердители_4.xlsx обработан, записей: 7
# ✓ Файл Отходы_4.xlsx обработан, записей: 6
# ✓ Файл Панели, перегородки, плиты_61.xlsx обработан, записей: 113
# ✓ Файл Пены монтажные_1.xlsx обработан, записей: 69
# ✓ Файл Песок_3.xlsx обработан, записей: 32
# ✓ Файл Пигменты, красители_12.xlsx обработан, записей: 22
# ✓ Файл Пластики однородные_90.xlsx обработан, записей: 172
# ✓ Файл Плитки строительные_35.xlsx обработан, записей: 67
# ✓ Файл Полимеры поликонденсационные_17.xlsx обработан, записей: 20
# ✓ Файл Преобразователи ржавчины_13.xlsx обработан, записей: 20
# ✓ Файл Производные органических кислот_6.xlsx обработан, записей: 24
# ✓ Файл Растворители и разбавители_10.xlsx обработан, записей: 45
# ✓ Файл Реактивы готовые спец., наборы реактивов_147.xlsx обработан, записей: 407
# ✓ Файл Смеси и растворы строительные_28.xlsx обработан, записей: 166
# ✓ Файл Смолы ионообменные, иониты_5.xlsx обработан, записей: 26
# ✓ Файл Смывки_5.xlsx обработан, записей: 9
# ✓ Файл Соед. гетероатом., элементорган. прочие_2.xlsx обработан, записей: 3
# ✓ Файл Соединения металлов и неметаллов_1.xlsx обработан, записей: 1
# ✓ Файл Соли неорганич. кислот, гидраты прочие_191.xlsx обработан, записей: 295
# ✓ Файл Сополимеры_4.xlsx обработан, записей: 8
# ✓ Файл Сорбенты, поглотители прочие_80.xlsx обработан, записей: 250
# ✓ Файл Составы огнетушащие и огнезащитные_16.xlsx обработан, записей: 36
# ✓ Файл Спирты, фенолы, тиоспирты и их производ_28.xlsx обработан, записей: 92
# ✓ Файл Средства для хим. обработки поверхностей_8.xlsx обработан, записей: 38
# ✓ Файл Средства моющие,чист.,полир.,дизенф_42.xlsx обработан, записей: 128
# ✓ Файл Среды бактериологические_15.xlsx обработан, записей: 30
# ✓ Файл Стабилизаторы_1.xlsx обработан, записей: 6
# ✓ Файл Стекло жидкое, силикаты растворимые_2.xlsx обработан, записей: 7
# ✓ Файл Стекло_4.xlsx обработан, записей: 9
# ✓ Файл Стеклопластики_3.xlsx обработан, записей: 3
# ✓ Файл Стройматериалы облицовочные и обшивочные_14.xlsx обработан, записей: 49
# ✓ Файл Сырье полимер. и материалы полимеризации_2.xlsx обработан, записей: 41
# ✓ Файл Теплоносители_3.xlsx обработан, записей: 12
# ✓ Файл Углеводороды алиф.,аром.,конденс.,замещ_68.xlsx обработан, записей: 159
# ✓ Файл Углеводы и их производные_5.xlsx обработан, записей: 8
# ✓ Файл Уголь активированный для очистки воды_10.xlsx обработан, записей: 31
# ✓ Файл Удобрения (стимуляторы роста и развития)_16.xlsx обработан, записей: 25
# ✓ Файл Фанера_10.xlsx обработан, записей: 34
# ✓ Файл Хладон_3.xlsx обработан, записей: 9
# ✓ Файл Цементы_7.xlsx обработан, записей: 57
# ✓ Файл Шары керамические_37.xlsx обработан, записей: 124
# ✓ Файл Шифер_1.xlsx обработан, записей: 1
# ✓ Файл Шнуры и жгуты уплотнительные_53.xlsx обработан, записей: 86
# ✓ Файл Шпала_2.xlsx обработан, записей: 5
# ✓ Файл Щебень и гравий_14.xlsx обработан, записей: 58
# ✓ Файл Электролиты_4.xlsx обработан, записей: 7
# ✓ Файл Элементы, соединения простые неорганич_24.xlsx обработан, записей: 129
# ✓ Файл Эфиры простые, эпоксиды_2.xlsx обработан, записей: 13
# ✓ Файл Эфиры сложные, в том числе внутренние_5.xlsx обработан, записей: 7
# Лист 'Нормализованные записи' не найден в файле: 1_Класс_Металл.xlsx
# Ошибка в файле ~$Балки двутавр_143.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# Ошибка в файле ~$Винты самонар_63.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# Ошибка в файле ~$Изделия для инженерных сетей_21.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# Ошибка в файле ~$Контргайки_13.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# ✓ Файл Анкеры_9.xlsx обработан, записей: 92
# ✓ Файл Балки двутавр_135.xlsx обработан, записей: 176
# ✓ Файл Болты стан c_г_81.xlsx обработан, записей: 174
# ✓ Файл Болты стандар_241.xlsx обработан, записей: 841
# ✓ Файл Болты фундам_18.xlsx обработан, записей: 18
# ✓ Файл Винты самонар_63.xlsx обработан, записей: 283
# ✓ Файл Винты стандарт_37.xlsx обработан, записей: 270
# ✓ Файл Винты стандартные гайками_1.xlsx обработан, записей: 12
# ✓ Файл Гайки_502.xlsx обработан, записей: 1354
# ✓ Файл Гвозди_31.xlsx обработан, записей: 50
# ✓ Файл Дробь чуг_стал_1.xlsx обработан, записей: 2
# ✓ Файл Дюбели_20.xlsx обработан, записей: 85
# ✓ Файл Загот из ст_сп_12.xlsx обработан, записей: 18
# ✓ Файл Заклепки_24.xlsx обработан, записей: 51
# ✓ Файл Изделия для инженерных сетей_21.xlsx обработан, записей: 84
# ✓ Файл Канаты стальные_81.xlsx обработан, записей: 199
# ✓ Файл Комп д креплен_125.xlsx обработан, записей: 163
# ✓ Файл Констр стр мет_236.xlsx обработан, записей: 437
# ✓ Файл Контргайки_13.xlsx обработан, записей: 54
# ✓ Файл Костыли железн_1.xlsx обработан, записей: 3
# ✓ Файл Крепь и конструкции шахтные_5.xlsx обработан, записей: 8
# ✓ Файл Ленты горячекатаные_6.xlsx обработан, записей: 7
# ✓ Файл Ленты холоднокатаные_9.xlsx обработан, записей: 14
# ✓ Файл Листы горячекат углерод. и низколегир._253.xlsx обработан, записей: 661
# ✓ Файл Листы горячекатаные нержавеющие_108.xlsx обработан, записей: 189
# ✓ Файл Листы перфорированные_7.xlsx обработан, записей: 7
# ✓ Файл Листы просечно-вытяжные_42.xlsx обработан, записей: 71
# ✓ Файл Листы профилированные_18.xlsx обработан, записей: 124
# ✓ Файл Листы рифленые_8.xlsx обработан, записей: 15
# ✓ Файл Листы холодн. углерод_низколегир_легир_32.xlsx обработан, записей: 86
# ✓ Файл Листы холоднокатаные нержавеющие_4.xlsx обработан, записей: 12
# ✓ Файл Лом драг метал_3.xlsx обработан, записей: 5
# ✓ Файл Лом цв металл_24.xlsx обработан, записей: 84
# ✓ Файл Лом чер метал_17.xlsx обработан, записей: 93
# ✓ Файл Наклад рельс_6.xlsx обработан, записей: 8
# ✓ Файл Пластины из твердых сплавов_13.xlsx обработан, записей: 23
# ✓ Файл Пластины стальные_67.xlsx обработан, записей: 123
# ✓ Файл Подкладки рельсовые_5.xlsx обработан, записей: 6
# ✓ Файл Поковки из стали и сплавов_24.xlsx обработан, записей: 26
# ✓ Файл Полуф цв мет_3.xlsx обработан, записей: 3
# ✓ Файл Проволока из драгоценных металлов_1.xlsx обработан, записей: 2
# ✓ Файл Проволока из цветных металлов_4.xlsx обработан, записей: 12
# ✓ Файл Проволока канатная_18.xlsx обработан, записей: 21
# ✓ Файл Проволока колючая_3.xlsx обработан, записей: 5
# ✓ Файл Проволока стальная общего назначения_42.xlsx обработан, записей: 90
# ✓ Файл Прокат алюминиевый круглый_9.xlsx обработан, записей: 19
# ✓ Файл Прокат алюминиевый листовой_32.xlsx обработан, записей: 61
# ✓ Файл Прокат из меди и ее сплавов_121.xlsx обработан, записей: 183
# ✓ Файл Прокат свинцовый_4.xlsx обработан, записей: 7
# ✓ Файл Прокат стальной квадратный_1.xlsx обработан, записей: 8
# ✓ Файл Прокат стальной круглый_239.xlsx обработан, записей: 578
# ✓ Файл Прокат стальной полосовой_73.xlsx обработан, записей: 188
# ✓ Файл Прокат стальной шестигранный_53.xlsx обработан, записей: 98
# ✓ Файл Противоугоны пружинные к жд рельсам_1.xlsx обработан, записей: 2
# ✓ Файл Профили стальные_130.xlsx обработан, записей: 150
# ✓ Файл Пряж_скобы_21.xlsx обработан, записей: 66
# ✓ Файл Рельсы_9.xlsx обработан, записей: 20
# ✓ Файл Рукав металл_156.xlsx обработан, записей: 403
# ✓ Файл Сетки металлические_84.xlsx обработан, записей: 197
# ✓ Файл Слитки и отливки чугунные_11.xlsx обработан, записей: 14
# ✓ Файл Сталь арматурная_59.xlsx обработан, записей: 93
# ✓ Файл Сталь шпоночная_5.xlsx обработан, записей: 6
# ✓ Файл Уголки стальные_280.xlsx обработан, записей: 463
# ✓ Файл Хомуты_111.xlsx обработан, записей: 601
# ✓ Файл Части монтажн_14.xlsx обработан, записей: 156
# ✓ Файл Шайбы_177.xlsx обработан, записей: 651
# ✓ Файл Швеллеры гнутые_4.xlsx обработан, записей: 10
# ✓ Файл Швеллеры горячекатаные_123.xlsx обработан, записей: 205
# ✓ Файл Шпильки ст с г_1744.xlsx обработан, записей: 3257
# ✓ Файл Шпильки станд _1132.xlsx обработан, записей: 2240
# ✓ Файл Шплинты_12.xlsx обработан, записей: 26
# ✓ Файл Шпонки_7.xlsx обработан, записей: 77
# ✓ Файл Штифты_6.xlsx обработан, записей: 26
# ✓ Файл Шурупы_1.xlsx обработан, записей: 20
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Насос_об.xlsx
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Насос_об_исправление ИАС.xlsx
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Насос_об_новый (2).xlsx
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Насос_об_новый.xlsx
# ✓ Файл Компрессоры криоген хол.обор_14.xlsx обработан, записей: 15
# ✓ Файл Компрессоры нефтегазовые_5.xlsx обработан, записей: 24
# ✓ Файл Компрессоры прочие_20.xlsx обработан, записей: 20
# ✓ Файл Мотопомпы_92.xlsx обработан, записей: 100
# ✓ Файл Насосы агрегаты вакуумные_21.xlsx обработан, записей: 34
# ✓ Файл Насосы агрегаты винтовые_36.xlsx обработан, записей: 178
# ✓ Файл Насосы агрегаты вихревые_9.xlsx обработан, записей: 19
# ✓ Файл Насосы агрегаты поршневые_6.xlsx обработан, записей: 48
# ✓ Файл Насосы агрегаты прочие_87.xlsx обработан, записей: 433
# Не найдены колонки в файле Насосы агрегаты ц б скважин_119.xlsx: Код КССС/id
# ✓ Файл Насосы агрегаты Цб пов. прочие_249.xlsx обработан, записей: 997
# ✓ Файл Насосы агрегаты Цб пов. прочие_400.xlsx обработан, записей: 997
# ✓ Файл Насосы агрегаты цб поверх_389.xlsx обработан, записей: 975
# Не найдены колонки в файле Насосы агрегаты цб полупогружные_51.xlsx: Код КССС/id
# Не найдены колонки в файле Насосы агрегаты шестеренные_52.xlsx: Код КССС/id
# ✓ Файл Насосы бочковые для емкостей_14.xlsx обработан, записей: 93
# ✓ Файл Насосы скважин нефт винтовые эл приводн_61.xlsx обработан, записей: 193
# ✓ Файл Насосы скважин нефт центроб эл приводн_1530.xlsx обработан, записей: 6748
# ✓ Файл Насосы скважин.нефт. винтовые штанговые_14.xlsx обработан, записей: 71
# ✓ Файл Насосы скважин.нефт.штангов.возвр.-пост._52.xlsx обработан, записей: 570
# Не найдены колонки в файле Насосы струйные_4.xlsx: Код КССС/id
# ✓ Файл Насосы, агрегаты дозировочные_98.xlsx обработан, записей: 232
# ✓ Файл Насосы, агрегаты ц б герметич_21.xlsx обработан, записей: 37
# ✓ Файл Насосы, агрегаты ц б консоль_70.xlsx обработан, записей: 129
# Не найдены колонки в файле Насосы, агрегаты ц б скважин_119.xlsx: Код КССС/id
# ✓ Файл Насосы, агрегаты цб погружн_223.xlsx обработан, записей: 383
# ✓ Файл Насосы, агрегаты центробежно-вихревые_276.xlsx обработан, записей: 565
# ✓ Файл НасосыАгрегатыУстанОседиагон_5.xlsx обработан, записей: 10
# ✓ Файл НасосыАгрегатыЦб пов. герметич_21.xlsx обработан, записей: 37
# ✓ Файл НасосыАгрегатыЦб пов. герметич_41.xlsx обработан, записей: 67
# ✓ Файл НасосыАгрегатыЦб пов. двухопор_979.xlsx обработан, записей: 1753
# ✓ Файл НасосыАгрегатыЦб пов. консоль_114.xlsx обработан, записей: 201
# ✓ Файл НасосыАгрегатыЦб пов. консоль_70.xlsx обработан, записей: 129
# ✓ Файл Станц насосн насосы автом д воды бытов_22.xlsx обработан, записей: 38
# Не найдены колонки в файле Станции компрессорные_7.xlsx: Код КССС/id
# ✓ Файл Станции насосные кустовые блоч-модульн_2.xlsx обработан, записей: 6
# Не найдены колонки в файле Станции установки насосные прочие_24.xlsx: Код КССС/id
# ✓ Файл Узлы, детали оборуд. компрес. по чертежу_1027.xlsx обработан, записей: 1852
# ✓ Файл Узлы, детали оборуд. компрес. прочие_2470.xlsx обработан, записей: 4037
# ✓ Файл Узлы, детали оборуд. компрес. фирменные_58.xlsx обработан, записей: 114
# ✓ Файл Узлы, детали оборуд. насос. по чертежу_1924.xlsx обработан, записей: 2126
# ✓ Файл Узлы, детали оборуд. насос. прочие_4822.xlsx обработан, записей: 6940
# ✓ Файл Узлы, детали оборуд. насос. фирменные_253.xlsx обработан, записей: 304
# ✓ Файл Уст.насосн.скважин.нефт.винтовые эл_прив_6.xlsx обработан, записей: 23
# ✓ Файл Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx обработан, записей: 187
# ✓ Файл Установки дозирования реагентов (УДХ)_42.xlsx обработан, записей: 111
# ✓ Файл Установки насосные скв_нефт_141.xlsx обработан, записей: 210
# ✓ Файл Установки насосные скважинные артезианс_16.xlsx обработан, записей: 20
# Не найдены колонки в файле Эжекторы_6.xlsx: Код КССС/id
# Не найдены колонки в файле Эжекторы_9.xlsx: Код КССС/id
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Емкостное.xlsx
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Емкостное_согласовано.xlsx
# Ошибка в файле ~$Отстойники воды ОВМ_2.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# ✓ Файл Аппараты емкостные вертикал. ВПП_1.xlsx обработан, записей: 1
# ✓ Файл Аппараты емкостные вертикал. ВЭЭ 5+_4.xlsx обработан, записей: 5
# ✓ Файл Аппараты емкостные вертикал. прочие 2+_1.xlsx обработан, записей: 2
# ✓ Файл Аппараты емкостные горизонт. ГЭЭ 4+_3.xlsx обработан, записей: 4
# ✓ Файл Аппараты емкостные горизонт. прочие_11.xlsx обработан, записей: 12
# ✓ Файл Воздухосборники, ресиверы_12.xlsx обработан, записей: 17
# ✓ Файл Газосепараторы ГС_8.xlsx обработан, записей: 46
# ✓ Файл Газосепараторы прочие_18.xlsx обработан, записей: 23
# Ошибка в файле Емкости дренажные ЕП_25.xls: Missing optional dependency 'xlrd'. Install xlrd >= 2.0.1 for xls Excel support Use pip or conda to install xlrd.
# Ошибка в файле Емкости дренажные ЕПП_10.xls: Missing optional dependency 'xlrd'. Install xlrd >= 2.0.1 for xls Excel support Use pip or conda to install xlrd.
# Ошибка в файле Емкости дренажные прочие_6.xls: Missing optional dependency 'xlrd'. Install xlrd >= 2.0.1 for xls Excel support Use pip or conda to install xlrd.
# ✓ Файл Емкости прочие_54.xlsx обработан, записей: 219
# ✓ Файл Клапаны для резервуарного оборудования_67.xlsx обработан, записей: 107
# ✓ Файл Колонны_12.xlsx обработан, записей: 18
# ✓ Файл Люки емкостные_14.xlsx обработан, записей: 27
# ✓ Файл Муфты сливные_3.xlsx обработан, записей: 3
# ✓ Файл Нефтегазосепараторы НГС_17.xlsx обработан, записей: 23
# ✓ Файл Нефтегазосепараторы НГСВ_5.xlsx обработан, записей: 7
# ✓ Файл Нефтегазосепараторы прочие_11.xlsx обработан, записей: 39
# ✓ Файл Оборудование емкостное прочее_57.xlsx обработан, записей: 85
# ✓ Файл Отстойники воды ОВМ_2.xlsx обработан, записей: 2
# ✓ Файл Отстойники воды ОГЖФ_1.xlsx обработан, записей: 1
# ✓ Файл Отстойники воды прочие_2.xlsx обработан, записей: 2
# ✓ Файл Отстойники нефти ОГ_1.xlsx обработан, записей: 2
# ✓ Файл Отстойники нефти прочие_1.xlsx обработан, записей: 2
# ✓ Файл Понтоны и части_детали к ним_33.xlsx обработан, записей: 53
# ✓ Файл Реакторы_5.xlsx обработан, записей: 16
# ✓ Файл Резервуары вертикальные РВС_9.xlsx обработан, записей: 16
# ✓ Файл Резервуары горизонтальные прочие_5.xlsx обработан, записей: 8
# ✓ Файл Резервуары горизонтальные РГСд_1.xlsx обработан, записей: 1
# ✓ Файл Резервуары горизонтальные РГСн_6.xlsx обработан, записей: 6
# ✓ Файл Резервуары горизонтальные РГСп_7.xlsx обработан, записей: 7
# ✓ Файл Резервуары прочие_25.xlsx обработан, записей: 35
# ✓ Файл Сепараторы прочие_15.xlsx обработан, записей: 39
# ✓ Файл Сепараторы скважинные_2.xlsx обработан, записей: 3
# ✓ Файл Сепараторы трехфазные ТФС_2.xlsx обработан, записей: 3
# ✓ Файл Сепараторы факельные_2.xlsx обработан, записей: 12
# ✓ Файл Сепараторы центробежные СЦВ_1.xlsx обработан, записей: 5
# ✓ Файл Сосуды СУГ_1.xlsx обработан, записей: 1
# ✓ Файл Сосуды_БС_2.xlsx обработан, записей: 5
# ✓ Файл Узлы и детали оборуд. емкостного прочие_34.xlsx обработан, записей: 215
# ✓ Файл Устройства внутренние прочие_46.xlsx обработан, записей: 82
# ✓ Файл Устройства для размыва донных отложений_2.xlsx обработан, записей: 2
# ✓ Файл Устройства приемо-раздаточные_3.xlsx обработан, записей: 3
# ✓ Файл Хлопушки_1.xlsx обработан, записей: 2
# ✓ Файл Части и детали сепараторов_13.xlsx обработан, записей: 21
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Оборуд_свар.xlsx
# ✓ Файл Горелки и резаки для газопл. обраб_20.xlsx обработан, записей: 73
# ✓ Файл Дет. и компл-щие свар. и плазм. оборуд._46.xlsx обработан, записей: 353
# ✓ Файл Дет_части_теплотех_об_19.xlsx обработан, записей: 189
# ✓ Файл Копия Проволока сварочная_45.xlsx обработан, записей: 105
# ✓ Файл Маш_для_дуг_свар_метал_89.xlsx обработан, записей: 132
# ✓ Файл Маш_для_плазм_сварки, резки_метал_21.xlsx обработан, записей: 29
# ✓ Файл Припои и флюсы_6.xlsx обработан, записей: 88
# ✓ Файл Проволока сварочная_87.xlsx обработан, записей: 105
# ✓ Файл Узлы маш_для_газопл_обраб_76.xlsx обработан, записей: 97
# ✓ Файл Узлы_маш_для_дуг_св_мет_8.xlsx обработан, записей: 13
# ✓ Файл Электр_свар_412.xlsx обработан, записей: 331
# ✓ Файл Электроды сварочные_223.xlsx обработан, записей: 331
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Мед.xlsx
# Ошибка в файле ~$Уст апп рентг томогр_21.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# Ошибка в файле ~$Шприцы медицинские_6.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# ✓ Файл Инстр мед режущие_2.xlsx обработан, записей: 2
# ✓ Файл ИнстрИприн мед вспом_79.xlsx обработан, записей: 232
# ✓ Файл Наборы мед_14.xlsx обработан, записей: 28
# ✓ Файл Трубки медицинские_30.xlsx обработан, записей: 92
# ✓ Файл Уст апп рентг томогр_21.xlsx обработан, записей: 27
# ✓ Файл Уст-ва д стер и дез_32.xlsx обработан, записей: 55
# ✓ Файл Уст-ва приб анес реан_10.xlsx обработан, записей: 15
# ✓ Файл Уст-ва приб физиотер_32.xlsx обработан, записей: 78
# ✓ Файл Шприцы медицинские_6.xlsx обработан, записей: 22
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Нефтепром.xlsx
# Ошибка в файле ~$Вертлюги_8.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# Ошибка в файле ~$Захваты и подвески клин_спирал_цанг_23.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# Ошибка в файле ~$Прокладки д соед уст оборуд ГОСТ 28919_18.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# Ошибка в файле ~$Соед_быстроразъем_для цементир_скважин_2.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# Ошибка в файле ~$Центраторы и децентр_4.xlsx: Excel file format cannot be determined, you must specify an engine manually.
# ✓ Файл Аппаратура для контроля скважин_14.xlsx обработан, записей: 15
# ✓ Файл Башмаки колонные_29.xlsx обработан, записей: 42
# ✓ Файл Блоки напорных (распределит.) гребенок_56.xlsx обработан, записей: 57
# ✓ Файл Вертлюги_8.xlsx обработан, записей: 14
# ✓ Файл Вставки и фитинги д_оборуд. скваж_31.xlsx обработан, записей: 37
# ✓ Файл Дет запч.сист.контр упр.цем.комп_4.xlsx обработан, записей: 4
# ✓ Файл Дет и запч сист верх прив_397.xlsx обработан, записей: 403
# ✓ Файл Детали и запч блока глуш.и дроссел_56.xlsx обработан, записей: 56
# ✓ Файл Детали и запч вспом систем и оборуд_84.xlsx обработан, записей: 89
# ✓ Файл Детали и запч диверторной системы_41.xlsx обработан, записей: 41
# ✓ Файл Детали и запч превенторной сборки_54.xlsx обработан, записей: 65
# ✓ Файл Детали и запч сист.контр.,упр.устан_87.xlsx обработан, записей: 89
# ✓ Файл Детали и запч сист.очист.и дегаз. БР_154.xlsx обработан, записей: 154
# ✓ Файл Детали и запч сист.перем.превент.сбор_42.xlsx обработан, записей: 43
# ✓ Файл Детали и запч сист.упр.ствол.част.ПВО_60.xlsx обработан, записей: 60
# ✓ Файл Детали и запч цирк.сист.выс.давл_118.xlsx обработан, записей: 197
# ✓ Файл Детали и запч цирк.сист.низк.давл_118.xlsx обработан, записей: 130
# ✓ Файл Детали и запчасти блоков бур вышки_25.xlsx обработан, записей: 62
# ✓ Файл Детали и запчасти комплексов АСПО_292.xlsx обработан, записей: 295
# ✓ Файл Детали и запчасти ротор площад_29.xlsx обработан, записей: 29
# ✓ Файл Детали и запчасти сист перемещ БУ_78.xlsx обработан, записей: 78
# ✓ Файл Детали и запчасти сист. сжат. воздуха БК_3.xlsx обработан, записей: 3
# ✓ Файл Детали и запчасти сист. энергоснабж. БК_23.xlsx обработан, записей: 26
# ✓ Файл Детали и запчасти сист.бур.сточных вод_1.xlsx обработан, записей: 665
# ✓ Файл Детали и запчасти сист.приг., хран. БР_12.xlsx обработан, записей: 13
# ✓ Файл Детали и запчасти сист.хран. и перемещ_21.xlsx обработан, записей: 22
# ✓ Файл Детали и запчасти системы ОВКВ БК_1.xlsx обработан, записей: 1
# ✓ Файл Детали и запчасти талиевой системы_161.xlsx обработан, записей: 170
# ✓ Файл Детали и запчасти цирк.сист.выс.давл.ЦК_25.xlsx обработан, записей: 26
# ✓ Файл Детали и части горно-шахт. оборудования_74.xlsx обработан, записей: 85
# ✓ Файл Детали манифольда_3.xlsx обработан, записей: 14
# ✓ Файл Детали пакеров_20.xlsx обработан, записей: 42
# ✓ Файл Долота буровые_44.xlsx обработан, записей: 50
# ✓ Файл Захваты и подвески клин_спирал_цанг_23.xlsx обработан, записей: 53
# ✓ Файл Клапаны скважинные_29.xlsx обработан, записей: 74
# ...
# ✓ Файл Муфты соединительные трубопровод. фирм_32.xlsx обработан, записей: 414
# ✓ Файл Накладки трубопроводные_22.xlsx обработан, записей: 22
# ✓ Файл Ниппели трубопроводные по чертежу_8.xlsx обработан, записей: 11
# ✓ Файл Ниппели трубопроводные специальные_33.xlsx обработан, записей: 96
# ✓ Файл Ниппели трубопроводные стандартные_4.xlsx обработан, записей: 37
# ✓ Файл Ниппели трубопроводные стеклопластиковые_23.xlsx обработан, записей: 29
# ✓ Файл Опоры по чертежу_178.xlsx обработан, записей: 252
# ✓ Файл Опоры стандартные отечественные_228.xlsx обработан, записей: 692
# ✓ Файл Опоры фирменные_15.xlsx обработан, записей: 32
# ✓ Файл Отводы канализационные_39.xlsx обработан, записей: 66
# ✓ Файл Отводы стандартные импортные_18.xlsx обработан, записей: 229
# ✓ Файл Отводы стандартные отечественные_1012.xlsx обработан, записей: 6873
# ✓ Файл Патрубки НКТ, уст. ар-ры нестанд.оборуд_73.xlsx обработан, записей: 712
# ✓ Файл Переходы и переходники канализационные_1.xlsx обработан, записей: 10
# ✓ Файл Переходы по чертежу_9.xlsx обработан, записей: 23
# ✓ Файл Переходы стандартные импортные_57.xlsx обработан, записей: 171
# ✓ Файл Переходы стандартные отечественные_560.xlsx обработан, записей: 2134
# ✓ Файл Переходы фирменные_1.xlsx обработан, записей: 26
# ✓ Файл Подвески по чертежу_61.xlsx обработан, записей: 87
# ✓ Файл Подвески стандартные импортные_1.xlsx обработан, записей: 2
# ✓ Файл Подвески стандартные отечественные_15.xlsx обработан, записей: 20
# ✓ Файл Прокладки для соед. трубопр. имп. ст_48.xlsx обработан, записей: 499
# ✓ Файл Прокладки для соед. трубопр. отеч. ст_215.xlsx обработан, записей: 3776
# ✓ Файл Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx обработан, записей: 3776
# ✓ Файл Прокладки для соед. трубопр. по чертежу_39.xlsx обработан, записей: 63
# ✓ Файл Прокладки для соед. трубопр. фирменн_89.xlsx обработан, записей: 120
# ✓ Файл Прокладки фланц завальц(ПЗГФ)отеч стандарт_4.xlsx обработан, записей: 5
# ✓ Файл Ревизии канализационные_2.xlsx обработан, записей: 6
# ✓ Файл Сальники трубопроводные по чертежу_9.xlsx обработан, записей: 9
# ✓ Файл Сгоны, резьбы, футорки трубопр. по черт_29.xlsx обработан, записей: 32
# ✓ Файл Сгоны, резьбы, футорки трубопр. прочие_11.xlsx обработан, записей: 85
# ✓ Файл Соединения изолирующие_2.xlsx обработан, записей: 5
# ✓ Файл Соединения изолирующие_3.xlsx обработан, записей: 5
# ✓ Файл Соединения прямые трубопр. стандартные_16.xlsx обработан, записей: 67
# ✓ Файл Соединения прямые трубопр. фирменные_33.xlsx обработан, записей: 104
# ✓ Файл Соединения разъемные трубопр. по чертежу_12.xlsx обработан, записей: 12
# ✓ Файл Соединения разъемные трубопр. стандарт_6.xlsx обработан, записей: 44
# ✓ Файл Соединения разъемные трубопр. фирменные_25.xlsx обработан, записей: 129
# ✓ Файл Тройники канализационные_39.xlsx обработан, записей: 96
# ✓ Файл Тройники по чертежу_2.xlsx обработан, записей: 4
# ✓ Файл Тройники стандартные импортные_34.xlsx обработан, записей: 155
# ✓ Файл Тройники стандартные отечественные_341.xlsx обработан, записей: 1423
# ✓ Файл Тройники фирменные_46.xlsx обработан, записей: 180
# ✓ Файл Трубы алюминиевые отечественный стандарт.xlsx обработан, записей: 19
# ✓ Файл Трубы бурильные_12.xlsx обработан, записей: 53
# ✓ Файл Трубы бш гд без покрытия (кроме нерж)_434.xlsx обработан, записей: 1633
# ✓ Файл Трубы бш гд без покрытия нерж_165.xlsx обработан, записей: 290
# ✓ Файл Трубы бш гд с покрытием_162.xlsx обработан, записей: 941
# ✓ Файл Трубы бш гд с покрытием_183.xlsx обработан, записей: 941
# ✓ Файл Трубы бш хд без покрытия (кром.нерж)_229.xlsx обработан, записей: 321
# ✓ Файл Трубы бш хд без покрытия нерж_230.xlsx обработан, записей: 240
# ✓ Файл Трубы бш хд с покрытием_21.xlsx обработан, записей: 27
# ✓ Файл Трубы из цветных металлов имп.стандарт.xlsx обработан, записей: 25
# ✓ Файл Трубы из цветных металлов фирменные_1.xlsx обработан, записей: 1
# ✓ Файл Трубы медные и латунные отеч.стандарт.xlsx обработан, записей: 64
# ✓ Файл Трубы неметаллические прочие_6.xlsx обработан, записей: 153
# ✓ Файл Трубы нержавеющие имп. ст_25.xlsx обработан, записей: 115
# ✓ Файл Трубы НКТ бесшовные без покрытия_33.xlsx обработан, записей: 106
# ✓ Файл Трубы НКТ бесшовные с покрытием_7.xlsx обработан, записей: 16
# ✓ Файл Трубы НКТ электросварные без покрытия.xlsx обработан, записей: 5
# ✓ Файл Трубы обсадные бесшовные.xlsx обработан, записей: 676
# ✓ Файл Трубы обсадные теплоизолированные_9.xlsx обработан, записей: 18
# ✓ Файл Трубы обсадные электросварные_72.xlsx обработан, записей: 170
# ✓ Файл Трубы общего назначения фирменные_37.xlsx обработан, записей: 47
# ✓ Файл Трубы полимерные безнапорные фирменные_14.xlsx обработан, записей: 23
# ✓ Файл Трубы полимерные напорные станд прочие_3.xlsx обработан, записей: 8
# ✓ Файл Трубы полимерные напорные стандартные_33.xlsx обработан, записей: 155
# ✓ Файл Трубы полимерные напорные стандартные_33_нов.xlsx обработан, записей: 155
# ✓ Файл Трубы полимерные напорные фирменные_20.xlsx обработан, записей: 220
# ✓ Файл Трубы полипропиленовые стандарт_1.xlsx обработан, записей: 4
# ✓ Файл Трубы полиэтиленовые стандарт_50.xlsx обработан, записей: 84
# ✓ Файл Трубы стальные водогазопроводные_61.xlsx обработан, записей: 104
# ✓ Файл Трубы стальные круглые прочие_25.xlsx обработан, записей: 74
# ✓ Файл Трубы стальные профильные_77.xlsx обработан, записей: 148
# ✓ Файл Трубы стеклопластиковые стандарт_19.xlsx обработан, записей: 45
# ✓ Файл Трубы углеродистые и легир.имп.стандарт_204.xlsx обработан, записей: 279
# ✓ Файл Трубы чугунные стандартные.xlsx обработан, записей: 31
# ✓ Файл Трубы эс 530 и больш.без пок.(крм.нерж)_97.xlsx обработан, записей: 167
# ✓ Файл Трубы эс 530 и больш.без покрытия нерж_3.xlsx обработан, записей: 3
# ✓ Файл Трубы эс 530 и больше с покрытием_5.xlsx обработан, записей: 111
# ✓ Файл Трубы эс меньше 530 без покр. нерж_1.xlsx обработан, записей: 6
# ✓ Файл Трубы эс меньше 530 без покр.(крм.нерж)_305.xlsx обработан, записей: 400
# ✓ Файл Трубы эс меньше 530 с покрытием_93.xlsx обработан, записей: 430
# ✓ Файл Угольники (углы) трубопроводные_34.xlsx обработан, записей: 203
# ✓ Файл Уплотнения канализационные_3.xlsx обработан, записей: 3
# ✓ Файл Фитинги прочие_5.xlsx обработан, записей: 6
# ✓ Файл Фланцы стандартные импортные_174.xlsx обработан, записей: 549
# ✓ Файл Фланцы стандартные отечественные_299.xlsx обработан, записей: 1586
# ✓ Файл Фланцы фирменные_4.xlsx обработан, записей: 7
# ✓ Файл Хомуты, клипсы для труб_11.xlsx обработан, записей: 22
# ✓ Файл Штуцеры по чертежу_52.xlsx обработан, записей: 84
# ✓ Файл Штуцеры стандартные_8.xlsx обработан, записей: 290
# ✓ Файл Штуцеры фирменные_73.xlsx обработан, записей: 153
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Трубы_согласовано.xlsx
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Трубы_согласовано_для загрузки.xlsx
# ✓ Файл Втулки внутр. защиты сварных швов.xlsx обработан, записей: 298
# ✓ Файл Заглушки по чертежу.xlsx обработан, записей: 531
# ✓ Файл Заглушки стандартные импортные.xlsx обработан, записей: 194
# ✓ Файл Крестовины канализационные.xlsx обработан, записей: 3
# ✓ Файл Манжеты канализационные.xlsx обработан, записей: 5
# ✓ Файл Муфты ремонтные.xlsx обработан, записей: 57
# ✓ Файл Патрубки канализационные.xlsx обработан, записей: 10
# ✓ Файл Переходы фирменные.xlsx обработан, записей: 26
# ✓ Файл Прокладки для соед. трубопр. имп. ст..xlsx обработан, записей: 499
# ✓ Файл Тройники по чертежу.xlsx обработан, записей: 4
# ✓ Файл Тройники стандартные импортные.xlsx обработан, записей: 155
# ✓ Файл Штуцеры по чертежу.xlsx обработан, записей: 84
# ✓ Файл Штуцеры стандартные.xlsx обработан, записей: 290
# Лист 'Нормализованные записи' не найден в файле: 1_Класс-р_мэппинг_Электрооб.xlsx
# ✓ Файл DIN-рейки_9.xlsx обработан, записей: 38
# ✓ Файл Адаптеры для электросети_4.xlsx обработан, записей: 20
# ✓ Файл Арматура для ВЛ_3.xlsx обработан, записей: 5
# ✓ Файл Арматура линейная сцепная дЛЭП_2.xlsx обработан, записей: 3
# ✓ Файл Арматура светосигнальная_43.xlsx обработан, записей: 104
# ✓ Файл Барьеры искробезопасности и искрозащиты_33.xlsx обработан, записей: 91
# ✓ Файл Вилки электрические и телефонные_12.xlsx обработан, записей: 81
# ✓ Файл Выкл-ли автомат. управл. диф. током_24.xlsx обработан, записей: 32
# ✓ Файл Выкл-ли перекл-ли конц. пут. низковол_15.xlsx обработан, записей: 81
# ✓ Файл Выключ-ли, переключ-ли, силовые рубильники_12.xlsx обработан, записей: 101
# ✓ Файл Выключат, переключат, кнопки упр-ния_34.xlsx обработан, записей: 388
# ✓ Файл Выключатели автоматические_451.xlsx обработан, записей: 1123
# ✓ Файл Выключатели бесконтактные_12.xlsx обработан, записей: 22
# ✓ Файл Выключатели выс. напряж. 1000В и более_10.xlsx обработан, записей: 42
# Не найдены колонки в файле Выключатели высокого напряжения_10.xlsx: Код КССС/id
# ✓ Файл Генераторы излучений и полей_1.xlsx обработан, записей: 10
# ✓ Файл Генераторы электромашинные_8.xlsx обработан, записей: 23
# ✓ Файл Диоды полупроводниковые_9.xlsx обработан, записей: 29
# ✓ Файл Дроссели эл., катушки индуктивности_11.xlsx обработан, записей: 42
# ✓ Файл Закрытые распределительные устройства_6.xlsx обработан, записей: 126
# ✓ Файл Изоляторы_8.xlsx обработан, записей: 37
# ✓ Файл Индикаторы жидкокристаллические_2.xlsx обработан, записей: 4
# ✓ Файл Источники питания_33.xlsx обработан, записей: 971
# ✓ Файл Источники УФ_20.xlsx обработан, записей: 39
# ✓ Файл Комплектные распределительные устройства_337.xlsx обработан, записей: 1156
# ✓ Файл Конденсаторы и блоки конд.спец.наз_3.xlsx обработан, записей: 9
# ✓ Файл Конденсаторы общего назначения_25.xlsx обработан, записей: 89
# ✓ Файл Конструкции строит. дподстанций и ВЛ_16.xlsx обработан, записей: 17
# ✓ Файл Контакторы_24.xlsx обработан, записей: 386
# ✓ Файл Контакты для пускателей_6.xlsx обработан, записей: 16
# ✓ Файл Контроллеры_112.xlsx обработан, записей: 462
# ✓ Файл Корпуса оборудования электроэнерг_25.xlsx обработан, записей: 111
# ✓ Файл Лампы электрические_108.xlsx обработан, записей: 577
# ✓ Файл Микросхемы_18.xlsx обработан, записей: 28
# ✓ Файл Модули электронные_180.xlsx обработан, записей: 598
# ✓ Файл Ограничители перенапряжения_8.xlsx обработан, записей: 32
# ✓ Файл Оптопары_2.xlsx обработан, записей: 2
# ✓ Файл Открытые распределительные устройства_4.xlsx обработан, записей: 10
# ✓ Файл Патроны светотехнические_7.xlsx обработан, записей: 29
# ✓ Файл Подрозетники и рамки_3.xlsx обработан, записей: 24
# ✓ Файл Подстанции трансформаторные 35 кВ и выше_5.xlsx обработан, записей: 10
# ✓ Файл Подстанции трансформаторные_142.xlsx обработан, записей: 268
# ✓ Файл Посты кнопочные_88.xlsx обработан, записей: 282
# ✓ Файл Пояса крепл кабелей погруж элнасосов_2.xlsx обработан, записей: 8
# ✓ Файл Предохранители_44.xlsx обработан, записей: 340
# ✓ Файл Преобразователи электрические_243.xlsx обработан, записей: 425
# ✓ Файл Приспособл., инструм дработы с кабелем_22.xlsx обработан, записей: 69
# ✓ Файл Пульты и панели управления_60.xlsx обработан, записей: 163
# ✓ Файл Пускатели электромагнитные_77.xlsx обработан, записей: 166
# ✓ Файл Разрядники_11.xlsx обработан, записей: 21
# Не найдены колонки в файле Разъединит.,отделит.,короткозам.,заземл_7.xlsx: Код КССС/id
# ✓ Файл Разъемы силовые_16.xlsx обработан, записей: 60
# ✓ Файл Реле_99.xlsx обработан, записей: 672
# ✓ Файл Розетки электрические и телефонные_21.xlsx обработан, записей: 289
# ✓ Файл Светодиоды матрицы модули светодиод_3.xlsx обработан, записей: 12
# ✓ Файл Стабилизаторы напряжения_3.xlsx обработан, записей: 22
# ✓ Файл Станции управления_64.xlsx обработан, записей: 164
# ✓ Файл Стойки и шкафы телекоммуникационные_66.xlsx обработан, записей: 197
# ✓ Файл Тиристоры и динисторы_5.xlsx обработан, записей: 14
# ✓ Файл Транзисторы_8.xlsx обработан, записей: 9
# ✓ Файл Трансформаторы для погружных элнасосов_12.xlsx обработан, записей: 59
# ✓ Файл Трансформаторы малой мощности_6.xlsx обработан, записей: 43
# ✓ Файл Трансформаторы напряжения_.xlsx обработан, записей: 46
# ✓ Файл Трансформаторы тока_42.xlsx обработан, записей: 217
# ✓ Файл Узлы и запасные части приборов_49.xlsx обработан, записей: 219
# ✓ Файл Уст-ва автоматического ввода резерва_4.xlsx обработан, записей: 11
# ✓ Файл Уст-ва автоматического ввода резерва_5.xlsx обработан, записей: 11
# ✓ Файл Уст-ва компенсации реактивной мощ-ти_25.xlsx обработан, записей: 82
# ✓ Файл Уст-ва пусковые и зажигающие для ламп_26.xlsx обработан, записей: 92
# ✓ Файл Уст-ва РЗА элстанций, подстанций_8.xlsx обработан, записей: 16
# ✓ Файл Уст-ва управл автомат, коммуникации_3.xlsx обработан, записей: 82
# ✓ Файл Уст-ва управл и защиты элустановок_9.xlsx обработан, записей: 190
# ✓ Файл Уст-ва управл исполнит механизмами_10.xlsx обработан, записей: 37
# ✓ Файл Уст-ва управл. автомат. сигн. элстанций_5.xlsx обработан, записей: 18
# ✓ Файл Уст-ва управл. отопител. оборудованием_8.xlsx обработан, записей: 22
# ✓ Файл Уст-ва управления вент. оборудованием_1.xlsx обработан, записей: 7
# ✓ Файл Устройства заземления_60.xlsx обработан, записей: 102
# ✓ Файл Устройства защитного отключения_21.xlsx обработан, записей: 67
# ✓ Файл Устройства и блоки зарядные_119.xlsx обработан, записей: 183
# ✓ Файл Устройства управления насосами_8.xlsx обработан, записей: 28
# ✓ Файл Устройства управления освещением_18.xlsx обработан, записей: 136
# ✓ Файл Устройства управления эдв_7.xlsx обработан, записей: 52
# ✓ Файл Части и детали изд электроустановочных_36.xlsx обработан, записей: 263
# ✓ Файл Части и детали контакторов_23.xlsx обработан, записей: 30
# ✓ Файл Части и детали трансформаторов_3.xlsx обработан, записей: 6
# ✓ Файл Части и комплектующие распределит уст-в_26.xlsx обработан, записей: 45
# ✓ Файл Части и комплектующие уст-в управл_49.xlsx обработан, записей: 70
# ✓ Файл Части компл-щие выкл разъед отделит_79.xlsx обработан, записей: 163
# ✓ Файл Части компл-щие генераторов электромаш_54.xlsx обработан, записей: 504
# ✓ Файл Части компл-щие привод коммутац апп_33.xlsx обработан, записей: 60
# Лист 'Нормализованные записи' не найден в файле: ШАБЛОН исходник.xlsx
# ✓ Файл Шины электрические и мосты шинные_7.xlsx обработан, записей: 24
# ✓ Файл Щетки и щеткодержатели для элмашин_17.xlsx обработан, записей: 38
# ✓ Файл Эл агрегаты и эл станции с дизельн_27.xlsx обработан, записей: 50
# ✓ Файл Элагрегаты и элстанции с бензинов ДВС_28.xlsx обработан, записей: 79
# ✓ Файл Элагрегаты и элстанции с газовыми ДВС_3.xlsx обработан, записей: 9
# ✓ Файл Электронагреватели прочие_28.xlsx обработан, записей: 289
# ✓ Файл Электроприводы_55.xlsx обработан, записей: 101
# ✓ Файл Элементы сопротивления_16.xlsx обработан, записей: 39
# ✓ Файл Воздух сжатый_5.xlsx обработан, записей: 12
# ✓ Файл Пар_7.xlsx обработан, записей: 8
# ✓ Файл Теплоэнергия_2.xlsx обработан, записей: 7
# ✓ Файл Электроэнергия_2.xlsx обработан, записей: 7
# Лист 'Нормализованные записи' не найден в файле: Загрузка_эталонных_записей.xlsx
# Логи сохранены в Лог.xlsx
# Результат сохранен в 'результат парсинга.xlsx'
#
# Статистика:
# Всего записей: 267929
# Уникальных файлов: 1647
# Уникальных папок: 39
#
# Первые 5 записей:
#   Код КССС/id Краткое наименование нормализованное  \
# 0      347753
# 1      347756
# 2      347757
# 3      873596
# 4      878944
#
#   Полное наименование нормализованное Краткое наименование КССС (исх)  \
# 0                                                Арматура АУШГН-50х14
# 1                                             Арматура АУЭЦН-50х14 ХЛ
# 2                                          Арматура АУЭЦН-ЛЗ-50х14 ХЛ
# 3                                          Арматура АШК-65х14К1М2-5КУ
# 4                                          Арматура АУЭЦН-50х14 К1 ХЛ
#
#             Статус                         Папка  \
# 0  На блокирование  Арматура трубопроводная, ЗиП
# 1  На блокирование  Арматура трубопроводная, ЗиП
# 2  На блокирование  Арматура трубопроводная, ЗиП
# 3  На блокирование  Арматура трубопроводная, ЗиП
# 4  На блокирование  Арматура трубопроводная, ЗиП
#
#                                      Имя файла
# 0  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
# 1  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
# 2  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
# 3  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
# 4  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx

# %%
#df_parse = pd.read_excel('результат парсинга.xlsx')

# %%
# Шаг 1: Замена пустых значений в колонке "Статус" на "На блокирование"
df_parse['Статус'] = df_parse['Статус'].fillna('На блокирование')
# Также заменяем пустые строки
df_parse['Статус'] = df_parse['Статус'].replace(['', ' ','Блокировка','На блокировку','на блшокирование','на блакирование','На блокировку: не указаны обязательные характеристики','Юлокировка','На болкирование','Боокировка','блокирование','Бокировка','на блокирование','На блокировку','на блокировку','На Блокирование','на блокировке','на Блокировку','на блокировании','Заблокировать','Запись на блокирование','блокировка','На блокировку','На Блокировку','Блокировка -другой класс','Блокирована','На блокирование.','на блокирование, недостаточно данных','на блокирование(не указаны обязательные характеристики)','на Блокировку, недостаточно данных','Блокирование','Блокирока','Блоктровка','на блокирование-дубль','Блоикровка','Блокировка - другой класс','на блокирование, дубль','На блокировку','на блокироваие','Блокироваа','На блокировании','на блокоровку','Блоировка'], 'На блокирование')
df_parse['Статус'] = df_parse['Статус'].replace(['эталон','эталонная запись','Записи готовых к загрузке в КССС(Эталонные)'], 'Эталон')
df_parse['Статус'] = df_parse['Статус'].replace(['Дубль','На блокировку: дубль','дубль','Дубль к 3170224','Дубль к 3448870','Дубль к 3175286','Дубль к 3576448','Дубль к 3356468','Дубль к 3448871','Дубль к 3283880','Дубль к 3283895','Дубль к 3283936','Дубль к 3405545','Дубль к 3283894','Дубль к 3525503','Дубликат'], 'Дубликат')
df_parse['Статус'] = df_parse['Статус'].replace(['Записи, не корректно отнесенные в класс','Перенос записи в другой класс','Перенос в другой класс','Записи перенесенные с другого класса'], 'Рекласс')
df_parse['Статус'] = df_parse['Статус'].replace(['калибровочная','03-корпоративная','Комплект','запись поставщика','Не удалось подтвердить НТД','3482607','3455927','Ю'], 'Прочее')

print("=== ОБРАБОТКА ДАТАФРЕЙМА ===")
print(f"Всего строк в датафрейме: {len(df_parse)}")
# Out:
# === ОБРАБОТКА ДАТАФРЕЙМА ===
# Всего строк в датафрейме: 267929

# %%
# Шаг 2: Отчет по значениям в столбце "Статус"
print("\n=== ОТЧЕТ ПО СТАТУСАМ ===")
status_counts = df_parse['Статус'].value_counts()
print("Распределение значений в столбце 'Статус':")
for status, count in status_counts.items():
    percentage = (count / len(df_parse)) * 100
    print(f"  {status}: {count} записей ({percentage:.1f}%)")
# Out:
# === ОТЧЕТ ПО СТАТУСАМ ===
# Распределение значений в столбце 'Статус':
#   На блокирование: 155656 записей (58.1%)
#   Эталон: 111371 записей (41.6%)
#   Дубликат: 799 записей (0.3%)
#   Рекласс: 61 записей (0.0%)
#   Прочее: 42 записей (0.0%)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Альтернативная версия графиков с seaborn
plt.figure(figsize=(15, 5))
# График 2: Круговая диаграмма
plt.subplot(1, 3, 2)
plt.pie(status_counts.values, labels=status_counts.index, autopct='%1.1f%%', 
        startangle=90, colors=sns.color_palette('viridis', len(status_counts)))
plt.title('Доля статусов')
# Out:
# Text(0.5, 1.0, 'Доля статусов')

# %%
# Шаг 4: Отчет по записям со статусом "Эталон"
print("\n=== ОТЧЕТ ПО СТАТУСУ 'ЭТАЛОН' ===")
etalon_df = df_parse[df_parse['Статус'] == 'Эталон']
print(f"Всего записей со статусом 'Эталон': {len(etalon_df)}")

# Записи с пустыми значениями в колонках наименований
empty_short_name = etalon_df['Краткое наименование нормализованное'].isna() | (etalon_df['Краткое наименование нормализованное'] == '')
empty_full_name = etalon_df['Полное наименование нормализованное'].isna() | (etalon_df['Полное наименование нормализованное'] == '')

empty_both = empty_short_name & empty_full_name
empty_either = empty_short_name | empty_full_name

print(f"Записей с пустым 'Краткое наименование нормализованное': {empty_short_name.sum()}")
print(f"Записей с пустым 'Полное наименование нормализованное': {empty_full_name.sum()}")
print(f"Записей с пустыми обоими наименованиями: {empty_both.sum()}")
print(f"Записей с хотя бы одним пустым наименованием: {empty_either.sum()}")
# Out:
# === ОТЧЕТ ПО СТАТУСУ 'ЭТАЛОН' ===
# Всего записей со статусом 'Эталон': 111371
# Записей с пустым 'Краткое наименование нормализованное': 6783
# Записей с пустым 'Полное наименование нормализованное': 11974
# Записей с пустыми обоими наименованиями: 4093
# Записей с хотя бы одним пустым наименованием: 14664

# %%
# Детальный отчет
if empty_either.sum() > 0:
    print("\nДетальная информация о записях с пустыми наименованиями:")
    problematic_records = etalon_df[empty_either]
    
    for idx, row in problematic_records.head(10).iterrows():  # Показываем первые 10 записей
        short_empty = "ПУСТО" if empty_short_name[idx] else "заполнено"
        full_empty = "ПУСТО" if empty_full_name[idx] else "заполнено"
        print(f"  Код: {row['Код КССС/id']} | Краткое: {short_empty} | Полное: {full_empty} | Файл: {row['Имя файла']}")
    
    if len(problematic_records) > 10:
        print(f"  ... и еще {len(problematic_records) - 10} записей")

# Дополнительная статистика
print(f"\n=== ДОПОЛНИТЕЛЬНАЯ СТАТИСТИКА ===")
print(f"Всего уникальных файлов: {df_parse['Имя файла'].nunique()}")
print(f"Всего уникальных папок: {df_parse['Папка'].nunique()}")
print(f"Всего уникальных кодов: {df_parse['Код КССС/id'].nunique()}")

# Сохранение обработанного датафрейма
df_parse.to_excel("результат парсинга с обработкой.xlsx", index=False)
print(f"\nОбработанный датафрейм сохранен в файл: 'результат парсинга с обработкой.xlsx'")
# Out:
# Детальная информация о записях с пустыми наименованиями:
#   Код: 1783878 | Краткое: ПУСТО | Полное: ПУСТО | Файл: Блоки клапанов предохр. стальные_39.xlsx
#   Код: 1743713 | Краткое: ПУСТО | Полное: ПУСТО | Файл: Блоки клапанов предохр. стальные_39.xlsx
#   Код: 3297002 | Краткое: ПУСТО | Полное: ПУСТО | Файл: Блоки клапанов предохр. стальные_39.xlsx
#   Код: 3444911 | Краткое: ПУСТО | Полное: ПУСТО | Файл: Задвижки прочие_11.xlsx
#   Код: 505939 | Краткое: ПУСТО | Полное: ПУСТО | Файл: Задвижки прочие_11.xlsx
#   Код: 512503 | Краткое: ПУСТО | Полное: ПУСТО | Файл: Задвижки прочие_11.xlsx
#   Код: 512504 | Краткое: ПУСТО | Полное: ПУСТО | Файл: Задвижки прочие_11.xlsx
#   Код: 3631188 | Краткое: ПУСТО | Полное: ПУСТО | Файл: Задвижки прочие_11.xlsx
#   Код: 3631196 | Краткое: ПУСТО | Полное: ПУСТО | Файл: Задвижки прочие_11.xlsx
#   Код: 3636136 | Краткое: ПУСТО | Полное: ПУСТО | Файл: Задвижки прочие_11.xlsx
#   ... и еще 14654 записей
#
# === ДОПОЛНИТЕЛЬНАЯ СТАТИСТИКА ===
# Всего уникальных файлов: 1647
# Всего уникальных папок: 39
# Всего уникальных кодов: 234342
#
# Обработанный датафрейм сохранен в файл: 'результат парсинга с обработкой.xlsx'

# %%
# Анализ записей со статусом "Эталон"
print("=== АНАЛИЗ ЗАПИСЕЙ СО СТАТУСОМ 'ЭТАЛОН' ===")

# Фильтруем записи со статусом "Эталон"
etalon_df = df_parse[df_parse['Статус'] == 'Эталон'].copy()

print(f"Всего записей со статусом 'Эталон': {len(etalon_df)}")
print(f"Уникальных кодов 'Код КССС/id': {etalon_df['Код КССС/id'].nunique()}")

# Анализ неуникальных записей
print("\n=== АНАЛИЗ НЕУНИКАЛЬНЫХ ЗАПИСЕЙ ===")

# Группируем по коду и считаем количество уникальных значений в каждой колонке
duplicate_analysis = etalon_df.groupby('Код КССС/id').agg({
    'Краткое наименование нормализованное': 'nunique',
    'Полное наименование нормализованное': 'nunique', 
    'Имя файла': 'nunique',
    'Папка': 'nunique',
    'Статус': 'count'  # общее количество записей с этим кодом
}).reset_index()

# Переименовываем колонки для понятности
duplicate_analysis.columns = [
    'Код КССС/id', 
    'Уникальных_кратких_наименований', 
    'Уникальных_полных_наименований',
    'Уникальных_файлов',
    'Уникальных_папок', 
    'Всего_записей'
]

# Находим коды с дубликатами (больше 1 записи)
duplicate_codes = duplicate_analysis[duplicate_analysis['Всего_записей'] > 1]
print(f"Кодов с дубликатами (больше 1 записи): {len(duplicate_codes)}")

# Детальный анализ дубликатов
if len(duplicate_codes) > 0:
    print("\nДетальная информация по дубликатам:")
    for _, row in duplicate_codes.iterrows():
        code = row['Код КССС/id']
        code_records = etalon_df[etalon_df['Код КССС/id'] == code]
        
        #print(f"\nКод: {code}")
        #print(f"  Всего записей: {row['Всего_записей']}")
        #print(f"  Уникальных кратких наименований: {row['Уникальных_кратких_наименований']}")
        #print(f"  Уникальных полных наименований: {row['Уникальных_полных_наименований']}")
        #print(f"  Уникальных файлов: {row['Уникальных_файлов']}")
        #print(f"  Уникальных папок: {row['Уникальных_папок']}")
        
        # Выводим различные значения для этого кода
        unique_short_names = code_records['Краткое наименование нормализованное'].unique()
        unique_full_names = code_records['Полное наименование нормализованное'].unique()
        unique_files = code_records['Имя файла'].unique()
        
        if len(unique_short_names) > 1:
            print(f"  Различные краткие наименования: {list(unique_short_names)}")
        if len(unique_full_names) > 1:
            print(f"  Различные полные наименования: {list(unique_full_names)}")
        if len(unique_files) > 1:
            print(f"  Различные файлы: {list(unique_files)}")

# Создаем датафрейм с детальной информацией о дубликатах
detailed_duplicates = []

for code in duplicate_codes['Код КССС/id']:
    code_records = etalon_df[etalon_df['Код КССС/id'] == code]
    
    for idx, record in code_records.iterrows():
        detailed_duplicates.append({
            'Код КССС/id': code,
            'Краткое наименование нормализованное': record['Краткое наименование нормализованное'],
            'Полное наименование нормализованное': record['Полное наименование нормализованное'],
            'Имя файла': record['Имя файла'],
            'Папка': record['Папка'],
            'Всего_дубликатов_по_коду': len(code_records),
            'Уникальных_кратких_наименований': code_records['Краткое наименование нормализованное'].nunique(),
            'Уникальных_полных_наименований': code_records['Полное наименование нормализованное'].nunique(),
            'Уникальных_файлов': code_records['Имя файла'].nunique()
        })

# Создаем итоговый датафрейм с дубликатами
df_duplicates = pd.DataFrame(detailed_duplicates)

# Сохраняем в Excel
if len(df_duplicates) > 0:
    df_duplicates.to_excel('дубликаты_эталон.xlsx', index=False)
    print(f"\nДанные о дубликатах сохранены в файл: 'дубликаты_эталон.xlsx'")
    print(f"Всего записей в файле дубликатов: {len(df_duplicates)}")
else:
    print("\nДубликаты не найдены")

# Сводная статистика по дубликатам
if len(duplicate_codes) > 0:
    print("\n=== СВОДНАЯ СТАТИСТИКА ПО ДУБЛИКАТАМ ЭТАЛОННЫХ ЗАПИСЕЙ В ШАБЛОНАХ===")
    print(f"Всего проблемных кодов: {len(duplicate_codes)}")
    print(f"Общее количество записей с дубликатами: {duplicate_codes['Всего_записей'].sum()}")
    
    # Анализ конфликтов в наименованиях
    conflicts_short = duplicate_codes[duplicate_codes['Уникальных_кратких_наименований'] > 1]
    conflicts_full = duplicate_codes[duplicate_codes['Уникальных_полных_наименований'] > 1]
    conflicts_both = duplicate_codes[
        (duplicate_codes['Уникальных_кратких_наименований'] > 1) & 
        (duplicate_codes['Уникальных_полных_наименований'] > 1)
    ]
    
    print(f"Кодов с разными краткими наименованиями: {len(conflicts_short)}")
    print(f"Кодов с разными полными наименованиями: {len(conflicts_full)}")
    print(f"Кодов с разными обоими наименованиями: {len(conflicts_both)}")
    
    # Визуализация статистики дубликатов
    plt.figure(figsize=(12, 8))
    
    # График 1: Распределение количества дубликатов по кодам
    plt.subplot(2, 2, 1)
    duplicate_counts = duplicate_codes['Всего_записей'].value_counts().sort_index()
    duplicate_counts.plot(kind='bar', color='lightcoral', edgecolor='black')
    plt.title('Распределение количества дубликатов по кодам')
    plt.xlabel('Количество записей на код')
    plt.ylabel('Количество кодов')
    plt.grid(axis='y', alpha=0.3)
    
    # График 2: Типы конфликтов в дубликатах
    plt.subplot(2, 2, 2)
    conflict_types = {
        'Разные краткие\nнаименования': len(conflicts_short),
        'Разные полные\nнаименования': len(conflicts_full),
        'Разные оба\nнаименования': len(conflicts_both),
        'Дубликаты без\nконфликта наименований': len(duplicate_codes) - len(conflicts_short) - len(conflicts_full) + len(conflicts_both)
    }
    plt.bar(conflict_types.keys(), conflict_types.values(), color=['red', 'orange', 'darkred', 'lightblue'])
    plt.title('Типы конфликтов в дубликатах')
    plt.xticks(rotation=45, ha='right')
    plt.ylabel('Количество кодов')
    
    

print("\nАнализ завершен!")
# Out:
# === АНАЛИЗ ЗАПИСЕЙ СО СТАТУСОМ 'ЭТАЛОН' ===
# Всего записей со статусом 'Эталон': 111371
# Уникальных кодов 'Код КССС/id': 103556
#
# === АНАЛИЗ НЕУНИКАЛЬНЫХ ЗАПИСЕЙ ===
# Кодов с дубликатами (больше 1 записи): 5424
#
# Детальная информация по дубликатам:
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Тройники стандартные импортные_34.xlsx', 'Тройники стандартные импортные.xlsx']
#   Различные файлы: ['Части, дет. двигат., прив.,мех. прочие_489.xlsx', 'Части, дет. двигат., прив.,мех. прочие_506.xlsx']
#   Различные файлы: ['Клапаны регулирующие стальные_204.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Трубы бш гд с покрытием_162.xlsx', 'Трубы бш гд с покрытием_183.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Клапаны регулирующие стальные_204.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Кабели сил для погр эл насосов_42.xlsx', 'Кабели силовые погр.эл_насосов темп.120_18.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные краткие наименования: ['Агр.насос ц/б секц. 38м3/ч 66м э/д', 'Агр. насос. ц/б 38м3/ч 66м э/д']
#   Различные полные наименования: ['Агрегат насосный центробежный секционный 38м3/ч 66м электродвигатель', 'Агрегат насосный центробежный 38м3/ч 66м электродвигатель']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_249.xlsx', 'Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные файлы: ['Клапаны запорные стальные_193.xlsx', 'Клапаны запорные стальные_62.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 88-92/146-152 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 88-92/146-152 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 80-84/158-164 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 80-84/158-164 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 120-124/158-164 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 120-124/158-164 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 80-84/170-176 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 80-84/170-176 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 136-140/170-176 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 136-140/170-176 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 136-140/182-188 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 136-140/182-188 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 88-92/194-200 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 88-92/194-200 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 96-100/194-200 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 96-100/194-200 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 104-108/194-200 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 104-108/194-200 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 112-116/194-200 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 112-116/194-200 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 120-124/194-200 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 120-124/194-200 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 128-132/194-200 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 128-132/194-200 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные полные наименования: ['Жилет сигнальный демисезонный 2 класс защиты 136-140/194-200 ТР ТС 019/2011', 'Жилет сигнальный 2 класс защиты р-р 136-140/194-200 ТР ТС 019/2011']
#   Различные файлы: ['Жилеты дем. сигнал. 2 класс_41.xlsx', 'Жилеты сигнальные класс защиты 2_41.xlsx']
#   Различные файлы: ['Манометры сигнализ. (электроконтактные)_166.xlsx', 'Манометры электроконтактные_115.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Задвижки стальные_14.xlsx', 'Задвижки стальные_801.xlsx']
#   Различные файлы: ['Манометры сигнализ. (электроконтактные)_166.xlsx', 'Манометры электроконтактные_115.xlsx']
#   Различные файлы: ['Манометры сигнализ. (электроконтактные)_166.xlsx', 'Манометры электроконтактные_115.xlsx']
#   Различные файлы: ['Штуцеры по чертежу_52.xlsx', 'Штуцеры по чертежу.xlsx']
#   Различные файлы: ['Манометры сигнализ. (электроконтактные)_166.xlsx', 'Манометры сигнализирующие_79.xlsx']
#   Различные файлы: ['Тройники стандартные импортные_34.xlsx', 'Тройники стандартные импортные.xlsx']
#   Различные файлы: ['Тройники стандартные импортные_34.xlsx', 'Тройники стандартные импортные.xlsx']
#   Различные файлы: ['Тройники стандартные импортные_34.xlsx', 'Тройники стандартные импортные.xlsx']
#   Различные файлы: ['Тройники стандартные импортные_34.xlsx', 'Тройники стандартные импортные.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Клапаны регулирующие стальные_204.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Клапаны регулирующие стальные_204.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Фрезы_129.xlsx', 'Фрезы_222.xlsx']
#   Различные файлы: ['Фрезы_129.xlsx', 'Фрезы_222.xlsx']
#   Различные краткие наименования: ['Термометр биметаллический ТБ-2', 'Термометр ТБ-2']
#   Различные файлы: ['Термометры показыв., вкл. лабораторные_96.xlsx', 'Термометры показывающие_103.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные краткие наименования: ['Агр.насос ц/б цирк. 1,5м3/ч 8м э/д', 'Агр. насос. ц/б 1,5м3/ч 8м э/д']
#   Различные полные наименования: ['Агрегат насосный центробежный циркуляционный 1,5м3/ч 8м электродвигатель', 'Агрегат насосный центробежный 1,5м3/ч 8м электродвигатель']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_249.xlsx', 'Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные файлы: ['Дет. телеф., радио-, звук-, видеотехники_148.xlsx', 'Дет. телеф., радио-, звук-, видеотехники_154.xlsx']
#   Различные файлы: ['Компенсаторы для трубопроводов по чертежу_68.xlsx', 'Компенсаторы по чертежу_68.xlsx']
#   Различные краткие наименования: ['Днище железобетонное ПН 15', 'Днище колодца железобетонное ПН 15']
#   Различные полные наименования: ['Днище железобетонное ПН 15', 'Днище колодца железобетонное ПН 15']
#   Различные файлы: ['Изделия для колодцев трубопр_железоб_31.xlsx', 'Изделия для колодцев трубопроводов железобетонные_31.xlsx']
#   Различные файлы: ['Штуцеры по чертежу_52.xlsx', 'Штуцеры по чертежу.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные краткие наименования: ['Клапан(затвор) обрат. DN250 PN1,6 КОФ', 'Клапан обратный 19с76нж DN250 PN1,6 КОФ']
#   Различные полные наименования: ['Клапан (затвор) обратный DN250 PN1,6 КОФ', 'Клапан обратный 19с76нж DN250 PN1,6 КОФ']
#   Различные файлы: ['Клапаны обратные стальные_179.xlsx', 'Клапаны обратные стальные_85.xlsx']
#   Различные файлы: ['Клапаны распр.,устр.пер_30.xlsx', 'Клапаны распределит., устр.переключающие_30.xlsx']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные краткие наименования: ['Клапан(затвор) обрат. DN25 PN6,3 КОФ', 'Клапан обратный 16лс48нж DN25 PN6,3 КОФ']
#   Различные полные наименования: ['Клапан (затвор) обратный DN25 PN6,3 КОФ', 'Клапан обратный 16лс48нж DN25 PN6,3 КОФ']
#   Различные файлы: ['Клапаны обратные стальные_179.xlsx', 'Клапаны обратные стальные_85.xlsx']
#   Различные файлы: ['Заглушки стандартные импортные_80.xlsx', 'Заглушки стандартные импортные.xlsx']
#   Различные краткие наименования: ['Агр.насос. ц/б кон. 7,2-26 э/д', 'Агр.насос. ц/б кон. 7,2м3/ч 26м э/д']
#   Различные файлы: ['Насосы, агрегаты ц б консоль_70.xlsx', 'НасосыАгрегатыЦб пов. консоль_114.xlsx', 'НасосыАгрегатыЦб пов. консоль_70.xlsx']
#   Различные файлы: ['Манометры сигнализ. (электроконтактные)_166.xlsx', 'Манометры сигнализирующие_79.xlsx']
#   Различные файлы: ['Манометры сигнализ. (электроконтактные)_166.xlsx', 'Манометры сигнализирующие_79.xlsx']
#   Различные файлы: ['Части, дет. двигат., прив.,мех. прочие_489.xlsx', 'Части, дет. двигат., прив.,мех. прочие_506.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. имп. ст_48.xlsx', 'Прокладки для соед. трубопр. имп. ст..xlsx']
#   Различные краткие наименования: ['Термометр электроконтактный ТКП-100-М2', 'Термометр ТКП-100/М2']
#   Различные полные наименования: ['Термометр электроконтактный ТКП-100-М2', 'Термометр электроконтактный ТКП-100/М2']
#   Различные файлы: ['Термометры показыв., вкл. лабораторные_96.xlsx', 'Термометры показывающие_103.xlsx']
#   Различные файлы: ['Копия Проволока сварочная_45.xlsx', 'Проволока сварочная_87.xlsx']
#   Различные краткие наименования: ['Агр.насос ц/б секц. 105м3/ч 147м э/д', 'Агр. насос. ц/б 105м3/ч 147м э/д']
#   Различные полные наименования: ['Агрегат насосный центробежный секционный 105м3/ч 147м электродвигатель', 'Агрегат насосный центробежный 105м3/ч 147м электродвигатель']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_249.xlsx', 'Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные полные наименования: ['Прибор приемно-контрольный охранно-пожарный Яхонт-1И-01 Спецприбор', 'Прибор приемно-контрольный охранно-пожарный взрывозащищенный Яхонт-1И-01 Спецприбор']
#   Различные файлы: ['Узлы и уст-ва связи, охр и сиг-ции пр_147.xlsx', 'Уст-ва охраны, контроля и сигнализ.проч_126.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Опрыскиватели садовые и воздуходувки_18.xlsx', 'Опрыскиватели садовые и воздуходувки_29.xlsx']
#   Различные файлы: ['Блоки клапанов предохр. стальные_40.xlsx', 'Блоки клапанов предохр_40.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные краткие наименования: ['Агр.насос ц/б самовсас. 3,2м3/ч 48м э/д', 'Агр. насос. ц/б 3,2м3/ч 48м э/д']
#   Различные полные наименования: ['Агрегат насосный центробежный самовсасывающий 3,2м3/ч 48м электродвигатель', 'Агрегат насосный центробежный 3,2м3/ч 48м электродвигатель']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_249.xlsx', 'Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные краткие наименования: ['Клапан предохр. DN50 PN1,6', 'Клапан предохр. 17лс6нж DN50 PN1,6']
#   Различные полные наименования: ['Клапан предохранительный сбросной DN50 PN1,6', 'Клапан предохранительный сбросной 17лс6нж DN50 PN1,6']
#   Различные файлы: ['Клапаны пружинные предохр. стальные_108.xlsx', 'Клапаны пружинные предохр. стальные_9.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные краткие наименования: ['Шприц смаз. Groz арт.GR42900', 'Шприц смазочный Super Value GR42900']
#   Различные полные наименования: ['Шприц смазочный Groz артикул GR42900', 'Шприц смазочный Super Value GR42900']
#   Различные файлы: ['Ин-ты и у-ва для обслуж. тран. средств_58.xlsx', 'Шприцы для транспортных средств_30.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Части, дет. двигат., прив.,мех. прочие_489.xlsx', 'Части, дет. двигат., прив.,мех. прочие_506.xlsx']
#   Различные краткие наименования: ['Насос ц/б герм. 200-80', 'Насос ц/б герм. 200м3/ч 80м б/д']
#   Различные полные наименования: ['Насос центробежный герметичный 200м3/ч 80м', 'Насос центробежный герметичный 200м3/ч 80м без электродвигателя']
#   Различные файлы: ['Насосы, агрегаты ц б герметич_21.xlsx', 'НасосыАгрегатыЦб пов. герметич_21.xlsx', 'НасосыАгрегатыЦб пов. герметич_41.xlsx']
#   Различные файлы: ['Брус, бруски_8.xlsx', 'Доска_13.xlsx']
#   Различные краткие наименования: ['Агр. насос. ц/б 200м3/ч 20м э/д', 'Агр.насос. ц/б кон. 200-20 э/д', 'Агр.насос. ц/б кон. 200м3/ч 20м э/д']
#   Различные полные наименования: ['Агрегат насосный центробежный 200м3/ч 20м электродвигатель', 'Агрегат насосный центробежный консольный 200м3/ч 20м электродвигатель']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx', 'Насосы, агрегаты ц б консоль_70.xlsx', 'НасосыАгрегатыЦб пов. консоль_114.xlsx', 'НасосыАгрегатыЦб пов. консоль_70.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные краткие наименования: ['Агр.насос ц/б одност. 118,2м3/ч 48м э/д', 'Агр. насос. ц/б 118,2м3/ч 48м э/д']
#   Различные полные наименования: ['Агрегат насосный центробежный одноступенчатый 118,2м3/ч 48м электродвигатель', 'Агрегат насосный центробежный 118,2м3/ч 48м электродвигатель']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_249.xlsx', 'Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные файлы: ['Брус, бруски_8.xlsx', 'Доска_13.xlsx']
#   Различные краткие наименования: ['Труба ПАТ ПЭ80 275х4мм (м)', 'Труба ПАТ ПЭ80 275х4 ТУ2248-005-54112451']
#   Различные полные наименования: ['Труба ПАТ ПЭ80 275х4мм (м)', 'Труба ПАТ ПЭ80 275х4 техническая ТУ 2248-005-54112451-2004 (м)']
#   Различные файлы: ['Трубы полимерные напорные стандартные_33.xlsx', 'Трубы полимерные напорные стандартные_33_нов.xlsx', 'Трубы полиэтиленовые стандарт_50.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Штуцеры по чертежу_52.xlsx', 'Штуцеры по чертежу.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Ниппели трубопроводные по чертежу_8.xlsx', 'Ниппели трубопроводные специальные_33.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные краткие наименования: ['Насос ц/б секц. 38м3/ч 132м б/д', 'Насос ц/б 38м3/ч 132м']
#   Различные полные наименования: ['Насос центробежный секционный 38м3/ч 132м без электродвигателя', 'Насос центробежный 38м3/ч 132м']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_249.xlsx', 'Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные файлы: ['Клапаны запорные стальные_193.xlsx', 'Клапаны запорные стальные_62.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Клапаны регулирующие стальные_204.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные краткие наименования: ['Агр.насос ц/б секц. 300м3/ч 600м э/д', 'Агр. насос. ц/б 300м3/ч 600м э/д']
#   Различные полные наименования: ['Агрегат насосный центробежный секционный 300м3/ч 600м электродвигатель', 'Агрегат насосный центробежный 300м3/ч 600м электродвигатель']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_249.xlsx', 'Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные файлы: ['Станки-качалки_2.xlsx', 'Станки-качалки_38.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Станки-качалки_2.xlsx', 'Станки-качалки_38.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные краткие наименования: ['Клапан(затвор) обрат. DN300 PN1,6 КОФ', 'Клапан обратный 19с76нж DN300 PN1,6 КОФ']
#   Различные полные наименования: ['Клапан (затвор) обратный DN300 PN1,6 КОФ', 'Клапан обратный 19с76нж DN300 PN1,6 КОФ']
#   Различные файлы: ['Клапаны обратные стальные_179.xlsx', 'Клапаны обратные стальные_85.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Клапаны запорные стальные_193.xlsx', 'Клапаны запорные стальные_62.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Копия Проволока сварочная_45.xlsx', 'Проволока сварочная_87.xlsx']
#   Различные файлы: ['Каналы кабельные (кабель-каналы)_38.xlsx', 'Каналы кабельные (кабель-каналы)_40.xlsx']
#   Различные файлы: ['Клапаны регулирующие стальные_204.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Клапаны запорные стальные_193.xlsx', 'Клапаны запорные стальные_62.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Дет. телеф., радио-, звук-, видеотехники_148.xlsx', 'Дет. телеф., радио-, звук-, видеотехники_154.xlsx']
#   Различные краткие наименования: ['Задвижка дисковая паралл. DN80 PN1,6', 'Задвижка диск.пар. DN80 PN1,6']
#   Различные файлы: ['Задвижки дисковые, штуцерные_33.xlsx', 'Задвижки дисковые_33.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные краткие наименования: ['Термометр биметаллический ТБ-2СД', 'Термометр ТБ-2СД']
#   Различные файлы: ['Термометры показыв., вкл. лабораторные_96.xlsx', 'Термометры показывающие_103.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные краткие наименования: ['Труба ПАТ ПЭ80 140х4мм (м)', 'Труба ПАТ ПЭ80 140х4 ТУ2248-005-54112451']
#   Различные полные наименования: ['Труба ПАТ ПЭ80 140х4мм (м)', 'Труба ПАТ ПЭ80 140х4 техническая ТУ 2248-005-54112451-2004 (м)']
#   Различные файлы: ['Трубы полимерные напорные стандартные_33.xlsx', 'Трубы полимерные напорные стандартные_33_нов.xlsx', 'Трубы полиэтиленовые стандарт_50.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные файлы: ['Клапаны запорные стальные_193.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Заглушки стандартные импортные_80.xlsx', 'Заглушки стандартные импортные.xlsx']
#   Различные файлы: ['Дет. телеф., радио-, звук-, видеотехники_148.xlsx', 'Дет. телеф., радио-, звук-, видеотехники_154.xlsx']
#   Различные файлы: ['Клапаны запорные прочие_9.xlsx', 'Клапаны запорные стальные_193.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Трубы бш гд с покрытием_162.xlsx', 'Трубы бш гд с покрытием_183.xlsx']
#   Различные файлы: ['Опрыскиватели садовые и воздуходувки_18.xlsx', 'Опрыскиватели садовые и воздуходувки_29.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Манометры сигнализ. (электроконтактные)_166.xlsx', 'Манометры сигнализирующие_79.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные краткие наименования: ['Прокладка 1190х1160х4мм -', 'Прокладка ПЗГФ Г-Н-01-1190х1160х4 ТУ']
#   Различные полные наименования: [nan, 'Прокладка ПЗГФ Г-Н-01-1190х1160х4 ТУ 5728-014-13267785-99']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx', 'Прокладки фланц завальц(ПЗГФ)отеч стандарт_4.xlsx']
#   Различные файлы: ['Части, дет. двигат., прив.,мех. прочие_489.xlsx', 'Части, дет. двигат., прив.,мех. прочие_506.xlsx']
#   Различные файлы: ['Части, дет. двигат., прив.,мех. прочие_489.xlsx', 'Части, дет. двигат., прив.,мех. прочие_506.xlsx']
#   Различные файлы: ['Клапаны регулирующие стальные_204.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Части, дет. двигат., прив.,мех. прочие_489.xlsx', 'Части, дет. двигат., прив.,мех. прочие_506.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Манометры сигнализ. (электроконтактные)_166.xlsx', 'Манометры сигнализирующие_79.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные файлы: ['Манометры сигнализ. (электроконтактные)_166.xlsx', 'Манометры сигнализирующие_79.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Клапаны регулирующие стальные_204.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Клапаны распр.,устр.пер_30.xlsx', 'Клапаны распределит., устр.переключающие_30.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Клапаны запорные стальные_193.xlsx', 'Клапаны запорные стальные_62.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Клапаны запорные стальные_193.xlsx', 'Клапаны запорные стальные_62.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные краткие наименования: ['Провод ПТВВГЭ-ХА 2х1,5', 'Провод ПТВВГЭ-ХА (м)', 'Провод ПТВВГЭ-ХА 2х1,5 (м)']
#   Различные полные наименования: ['Провод термоэлектродный ПТВВГЭ-ХА 2х1,5', 'Провод термоэлектродный ПТВВГЭ-ХА (м)', 'Провод термоэлектродный ПТВВГЭ-ХА 2х1,5 (м)']
#   Различные файлы: ['Кабели и провода термоэлектродные_47.xlsx', 'Кабели, провода, шнуры прочие_83.xlsx', 'Кабели, провода, шнуры прочие_97.xlsx']
#   Различные краткие наименования: ['Клапан(затвор) обрат. DN500 PN1,6 КОФ', 'Клапан обратный 19с53нж DN500 PN1,6 КОФ']
#   Различные полные наименования: ['Клапан (затвор) обратный DN500 PN1,6 КОФ', 'Клапан обратный 19с53нж DN500 PN1,6 КОФ']
#   Различные файлы: ['Клапаны обратные стальные_179.xlsx', 'Клапаны обратные стальные_85.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Части, дет. двигат., прив.,мех. прочие_489.xlsx', 'Части, дет. двигат., прив.,мех. прочие_506.xlsx']
#   Различные файлы: ['Трубы бш гд с покрытием_162.xlsx', 'Трубы бш гд с покрытием_183.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные краткие наименования: ['Блок С2000-КПБ вер.1.09 Bolid', 'Блок С2000-КПБ версия 1.09 Bolid']
#   Различные файлы: ['Узлы и уст-ва связи, охр и сиг-ции пр_147.xlsx', 'Уст-ва охраны, контроля и сигнализ.проч_126.xlsx']
#   Различные файлы: ['Трубы бш гд с покрытием_162.xlsx', 'Трубы бш гд с покрытием_183.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Части, дет. двигат., прив.,мех. прочие_489.xlsx', 'Части, дет. двигат., прив.,мех. прочие_506.xlsx']
#   Различные файлы: ['Трубы бш гд с покрытием_162.xlsx', 'Трубы бш гд с покрытием_183.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные краткие наименования: ['Термометр биметаллический TBiChG 160rmGel L270', 'Термометр Manotherm TBiChG L270']
#   Различные полные наименования: ['Термометр биметаллический TBiChG 160rmGel L270', 'Термометр биметаллический Manotherm TBiChG L270']
#   Различные файлы: ['Термометры показыв., вкл. лабораторные_96.xlsx', 'Термометры показывающие_103.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные краткие наименования: ['Агр. насос. ц/б 100м3/ч 25м э/д', 'Насос ц/б кон. 100-25', 'Насос ц/б кон. 100м3/ч 25м б/д']
#   Различные полные наименования: ['Агрегат насосный центробежный 100м3/ч 25м электродвигатель', 'Насос центробежный консольный 100м3/ч 25м', 'Насос центробежный консольный 100м3/ч 25м без электродвигателя']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx', 'Насосы, агрегаты ц б консоль_70.xlsx', 'НасосыАгрегатыЦб пов. консоль_114.xlsx', 'НасосыАгрегатыЦб пов. консоль_70.xlsx']
#   Различные файлы: ['Копия Проволока сварочная_45.xlsx', 'Проволока сварочная_87.xlsx']
#   Различные файлы: ['Электр_свар_412.xlsx', 'Электроды сварочные_223.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Клапаны регулирующие стальные_204.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Уст.насосн.скважин.нефт.центроб.эл_прив_135.xlsx', 'Установки насосные скв_нефт_141.xlsx']
#   Различные краткие наименования: ['Башмак черт.8739.00СБ', 'Башмак 8739.00СБ']
#   Различные файлы: ['Ин-ты и у-ва для обслуж. тран. средств_58.xlsx', 'Уст-ва дремонта и обслуж. транспорта_30.xlsx']
#   Различные краткие наименования: ['Насос ц/б секц. 60м3/ч 66м б/д', 'Насос ц/б 60м3/ч 66м']
#   Различные полные наименования: ['Насос центробежный секционный 60м3/ч 66м без электродвигателя', 'Насос центробежный 60м3/ч 66м']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_249.xlsx', 'Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные файлы: ['Части, дет. двигат., прив.,мех. прочие_489.xlsx', 'Части, дет. двигат., прив.,мех. прочие_506.xlsx']
#   Различные файлы: ['Дет. телеф., радио-, звук-, видеотехники_148.xlsx', 'Дет. телеф., радио-, звук-, видеотехники_154.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Прокладки для соед. трубопр. отеч. ст_215.xlsx', 'Прокладки для соед. трубопр. отеч. ст_215_нов.xlsx']
#   Различные краткие наименования: ['Прибор ВЭРС-ПК4 вер.3.1 ВЭРС', 'Прибор ВЭРС-ПК4 версия 3.1 ВЭРС']
#   Различные файлы: ['Узлы и уст-ва связи, охр и сиг-ции пр_147.xlsx', 'Уст-ва охраны, контроля и сигнализ.проч_126.xlsx']
#   Различные файлы: ['Наборы инструментов обрабатывающих_488.xlsx', 'Наборы инструментов слесарно-монтажные_358.xlsx']
#   Различные файлы: ['Уст-ки заправ., раздаточные, ЗИП пр_12.xlsx', 'Установки заправочные и раздат_15.xlsx']
#   Различные краткие наименования: ['Агр.насос ц/б самовсас. 40м3/ч 20м э/д', 'Агр. насос. ц/б 40м3/ч 20м э/д']
#   Различные полные наименования: ['Агрегат насосный центробежный самовсасывающий 40м3/ч 20м электродвигатель', 'Агрегат насосный центробежный 40м3/ч 20м электродвигатель']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_249.xlsx', 'Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные файлы: ['Трубы бш гд с покрытием_162.xlsx', 'Трубы бш гд с покрытием_183.xlsx']
#   Различные файлы: ['Трубы бш гд с покрытием_162.xlsx', 'Трубы бш гд с покрытием_183.xlsx']
#   Различные файлы: ['Трубы бш гд с покрытием_162.xlsx', 'Трубы бш гд с покрытием_183.xlsx']
#   Различные файлы: ['Штуцеры по чертежу_52.xlsx', 'Штуцеры по чертежу.xlsx']
#   Различные файлы: ['Клапаны запорные стальные_193.xlsx', 'Клапаны запорные стальные_62.xlsx', 'Клапаны регулирующие_536.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
#   Различные файлы: ['Насосы агрегаты Цб пов. прочие_400.xlsx', 'Насосы агрегаты цб поверх_389.xlsx']
#   Различные файлы: ['Кабели силовые общего назн_905.xlsx', 'Кабели силовые прочие_658.xlsx', 'Кабели силовые прочие_662.xlsx']
# ...
#   Различные полные наименования: ['Вода дистиллированная ГОСТ Р 58144-2018 еврокуб на поддоне с обрешеткой 1000л', 'Противоугон пружинный 1П65 ГОСТ 32409-2013 (кг)', 'Альфаметилстирол 1 сорт ТУ 2414-018-47773778-2006', nan, 'Крем защитный для рук гидрофильного действия Norman Oil 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Unitro Derm Oil 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Серволин 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Серволин 0,2л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Серволин 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия M Solo Profi 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия GECO 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия GECO 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия НАНОЦЕТРА 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия KONNER TECHNO 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия KONNER TECHNO 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия KONNER TECHNO 2л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Технология защиты 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Garda Premium OLIO STOP 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Garda Premium OLIO STOP 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Garda Standard 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Garda Standard 2л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Garda Premium AQUA STOP 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Solo Profi 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Primaterra Oil 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Primaterra Oil 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Primaterra Oil 2л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия ЭклИптика Strong protect 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Safe and Care Oil 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Safe and Care Oil 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Safe and Care Oil 2л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Gazual Стопойл 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Eco-Line 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Eco-Line 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Eco-Line 2л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Алиранта 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Алиранта 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Алиранта 2л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Альфа Защита 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Альфа Защита 0,2л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Альфа Защита 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия Альфа Защита 2л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия 0,2л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофильного действия 2л ТР ТС 019/2011', 'Крем защитный для рук гидрофобного действия Серволин Протект 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофобного действия Серволин Протект 0,2л ТР ТС 019/2011', 'Крем защитный для рук гидрофобного действия Серволин Протект 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофобного действия M Solo Aqua 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидрофобного действия M Solo Aqua 1л ТР ТС 019/2011', 'Крем защитный для рук гидрофобного действия Unitro Derm Aqua 0,1л ТР ТС 019/2011', 'Крем защитный для рук гидроф ...
#   Различные файлы: ['Вода складируемая_1.xlsx', 'Противоугоны пружинные к жд рельсам_1.xlsx', 'Альфаметилстиролы_1.xlsx', 'Топливо печное бытовое_5.xlsx', 'Крем защ.для рук гидрофильного действия_41.xlsx', 'Крем защ.для рук гидрофобного действия_35.xlsx', 'Крем защ.для рук комб. универ. д-я_38.xlsx', 'Средства дзащиты от УФ излучений крема_20.xlsx', 'Средства для дочищ. от\xa0неуст. загр_16.xlsx', 'Средства для защиты от обморожения крема_19.xlsx', 'Средства для очищ. от\xa0уст. загр. гели_11.xlsx', 'Средства для очищ. от\xa0уст. загр. пасты_39.xlsx', 'Средства дочищ от\xa0особо уст.загр.пасты_20.xlsx', 'Средства регенер., восстанав.крема друк_50.xlsx', 'Средство акариц.репел. от укусов клещей_16.xlsx', 'Средство дзащ. кожи обеззараж. от бакт_16.xlsx', 'Средство дзащ. кожи от потоотделения_5.xlsx', 'Средство дзащ. от кр. нас. репел. ср-во_11.xlsx', 'Средство дзащ.кожи от бактерий и грибов_8.xlsx', 'Средство дзащиты кожи гриб. заболеваний_12.xlsx', 'Средство после укусов_12.xlsx', 'Одежда форменная_20.xlsx', 'Кепки летние_2.xlsx', 'Подшлемники под каску термостойкие утепл_2.xlsx', 'Подшлемники под каску термостойкие_2.xlsx', 'Подшлемники под каску утепленные_2.xlsx', 'Шапки трикотажные_2.xlsx', 'Шапки-ушанки из искусственного меха_2.xlsx', 'Маски из изол материала со смен фильтр.xlsx', 'Маски из изол материала со смен фильтр_8.xlsx', 'Полумаски из изол материала смен фильтр).xlsx', 'Полумаски из изол материала смен фильтр)_10.xlsx', 'Полумаски фильтр для защиты от аэрозолей_27.xlsx', 'Противогазы_26.xlsx', 'Респираторы изолирующие_3.xlsx', 'Самоспасатели_12.xlsx', 'Фильтры сменные_18.xlsx', 'Шлем-маски_13.xlsx', 'Привязи страховочные_14.xlsx', 'Привязи удерживающие_12.xlsx', 'Стропы страховочные_31.xlsx', 'Устройства блокирующие_9.xlsx', 'Перчатки нефтемор с утепл вкл дгруб р-т_18.xlsx', 'Перчатки от конвективной теплоты_6.xlsx', 'Вкладыши (беруши) противошумные_10.xlsx', 'Наушники противошумные_19.xlsx', 'Жилеты дем. сигнал. 1 класс_2.xlsx', 'Жилеты дем. сигнал. 3 класс_2.xlsx', 'Жилеты рабоче-страховочные_2.xlsx', 'Комбинезоны аварийно-спасательные_44.xlsx', 'Костюмы дем. сигнал. 1 класс_2.xlsx', 'Костюмы дем. сигнал. 2 класс_2.xlsx', 'Костюмы спасательные_64.xlsx', 'Фартуки прорезиненные_2.xlsx', 'Сапоги пол. м. дем. жен. бол. В,р.н.вещ_2.xlsx', 'Сапоги пол. м. дем. муж. бол. В,р.н.вещ_4.xlsx', 'Тапочки дем.жен_2.xlsx', 'Тапочки дем.муж_2.xlsx', 'Туфли дем.жен_2.xlsx', 'Туфли-сабо дем.жен_2.xlsx', 'Туфли-сабо дем.муж_2.xlsx', 'Унты меховые зим.жен_2.xlsx', 'Унты меховые зим.муж_2.xlsx', 'Брюки дем жен ДМ02-01_2.xlsx', 'Брюки дем жен ДМ02-02_2.xlsx', 'Брюки дем муж ДМ07-01 (Шельф)_2.xlsx', 'Брюки зим муж ЗМ01-01_2.xlsx', 'Брюки зим муж ЗМ01-02_2.xlsx', 'Брюки зим муж ЗМ01-03_2.xlsx', 'Брюки зим муж ЗМ01-04.xlsx', 'Брюки зим муж ЗМ05-01_2.xlsx', 'Брюки зим муж ЗМ05-02_2.xlsx', 'Брюки зим муж ЗМ07-01 (Шельф)_2.xlsx', 'Брюки зим муж ЗМ08-01 (Шельф)_2.xlsx', 'Брюки зим муж ЗМ09-01_2.xlsx', 'Брюки зим муж ЗМ10-01_2.xlsx', 'Брюки лет жен ЛМ02-02_2.xlsx', 'Брюки лет муж ЛМ07-01 (Шельф)_2.xlsx', 'Брюки лет муж ЛМ08-01 (Шельф)_2.xlsx', 'Брюки лет муж ЛМ13-01_2.xlsx', 'Жакеты муж трикотажные ТМ19-01_2.xlsx', 'Жилеты утеп жен ЗМ15-02_2.xlsx', 'Жилеты утеп муж ЗМ15-01_2.xlsx', 'Комплекты зим жен ЗМ02-01.xlsx', 'Комплекты зим жен ЗМ02-01ИТР_2.xlsx', 'Комплекты зим жен ЗМ04-01.xlsx', 'Комплекты зим жен ЗМ06-01_2.xlsx', 'Комплекты зим жен ЗМ06-02_2.xlsx', 'Комплекты зим муж ЗМ01-01.xlsx', 'Комплекты зим муж ЗМ01-03.xlsx', 'Комплекты зим муж ЗМ01-04.xlsx', 'Комплекты зим муж ЗМ03-01_2.xlsx', 'Комплекты зим муж ЗМ03-01ИТР_2.xlsx', 'Комплекты зим муж ЗМ05-01_2.xlsx', 'Комплекты зим муж ЗМ05-02_2.xlsx', 'Комплекты зим муж ЗМ07-01 (Шельф).xlsx', 'Комплекты зим муж ЗМ07-01 ИТР(Шельф)_2.xlsx', 'Комплекты зим муж ЗМ08-01 (Шельф)_2.xlsx', 'Комплекты зим муж ЗМ09-01_2.xlsx', 'Комплекты зим муж ЗМ10-01_2.xlsx', 'Комплекты зим муж ЗМ10-01ИТР_2.xlsx', 'Комплекты лет жен ЛМ12-01_2.xlsx', 'Комплекты лет жен ЛМ12-02_2.xlsx', 'Комплекты лет муж ЛМ09-01_2.xl ...
#   Различные краткие наименования: ['Вертлюг ВП-80', 'Вертлюг ВЭ-80ПР1', 'Вертлюг ВЭ-80МЛ', 'Втулка подшипника HDB-2H', 'Втулка подшипника H319', 'Втулка подшипника H318', 'Втулка подшипника H2315', 'Втулка подшипника H311', 'Втулка подшипника H2308', 'Втулка подшипника H3124', 'Втулка подшипника H3128', 'Втулка подшипника H2317', 'Втулка подшипника H313', 'Втулка подшипника H320', 'Втулка подшипника H2307', 'Ботинки ДМ кож кп Рк Неогард-Л 5.593 р40', 'Ботинки ДЖ ком мп Рк Неогард-Л 5.594 р40', 'Полуботинки ДМ кп Р Неогард-Л 5.595 р40', 'Ботинки ДМ кож кп Р Неогард-2 50.028 р40', 'Пар (т)']
#   Различные полные наименования: ['Вертлюг промывочный ВП-80', 'Вертлюг эксплуатационный ВЭ-80ПР1', 'Вертлюг эксплуатационный ВЭ-80МЛ', 'Втулка подшипника HDB-2H', 'Втулка подшипника H319', 'Втулка подшипника H318', 'Втулка подшипника H2315', 'Втулка подшипника H311', 'Втулка подшипника H2308', 'Втулка подшипника H3124', 'Втулка подшипника H3128', 'Втулка подшипника H2317', 'Втулка подшипника H313', 'Втулка подшипника H320', 'Втулка подшипника H2307', 'Ботинки демисезонные мужские комбинированные З Ми Мп Нс Нм Сж См Эс У Мун200 композитные подноски с антипрокольными кевларовыми стельками модель Неогард-Лайт Антистат артикул 5.593 р40 ТР ТС 019/2011', 'Ботинки демисезонные женские комбинированные З Ми Мп Нс Нм Сж См Эс У Мун200 металлические подноски с антипрокольными кевларовыми стельками модель Неогард-Лайт Антистат артикул 5.594 р40 ТР ТС 019/2011', 'Полуботинки демисезонные мужские комбинированные З Ми Мп Нм Сж См Эс У Мун200 композитные подноски с антипрокольными композитными стельками модель Неогард-Лайт Антистат артикул 5.595 р40 ТР ТС 019/2011', 'Ботинки демисезонные мужские кожаные З Ми Мп Нс Нм Сж См Тп300 У Мун200 композитные подноски с антипрокольными композитными стельками модель Неогард-2 артикул 50.028 р40 ТР ТС 019/2011', 'Пар (Тонна метрическая)']
#   Различные файлы: ['Вертлюги_8.xlsx', 'Втулки подшип_13.xlsx', '3001020401000000_Ботинки дем. муж. НсНмСжСмЭс_2.xlsx', '3001020402000000_Ботинки дем. жен. НсНмСжСмЭс_2.xlsx', '3001020403000000_Полуботинки дем. муж. НмСжСмЭс_2.xlsx', '3001020405000000_Ботинки дем. муж. НсНмСжСм_2.xlsx', 'Пар_7.xlsx']
#   Различные краткие наименования: ['Аппарат вертикальный АЕВ', 'Гидроэлеватор Г-600 У1', 'Костюм Со з(1-2)м 1кл куртка, п/комб.', 'К-м з(1-2)м 1кл к.,п. 104-108/182-188', 'Костюм Со з(3)м 2кл куртка, п/комб.', 'К-м з(3)м 2кл к.,п. 104-108/182-188', 'Костюм Со зим(4) муж Спектр2 3кл оранж', 'К-м з(4)м Спектр2 3кл ор 104-108/182-188']
#   Различные полные наименования: ['Аппарат вертикальный АЕВ', 'Гидроэлеватор пожарный Г-600 У1 ГОСТ Р 50398-92', 'Костюм сигнальный зимний (1-2 климатические пояса) мужской повышенной видимости 2 класс защиты (куртка, полукомбинезон) З Со Тн1 ТР ТС 019/2011', 'Костюм сигнальный зимний (1-2 климатические пояса) мужской повышенной видимости 2 класс защиты (куртка, полукомбинезон) З Со Тн1 р-р 104-108/182-188 ТР ТС 019/2011', 'Костюм сигнальный зимний (3 климатический пояс) мужской повышенной видимости 2 класс защиты (куртка, полукомбинезон) З Со Тн2 ТР ТС 019/2011', 'Костюм сигнальный зимний (3 климатический пояс) мужской повышенной видимости 2 класс защиты (куртка, полукомбинезон) З Со Тн2 р-р 104-108/182-188 ТР ТС 019/2011', 'Костюм сигнальный зимний (4 климатический пояс) мужской повышенной видимости 3 класс защиты (куртка, полукомбинезон) З Ми Со Тн3 оранжевый, синий модель Спектр 2 ТР ТС 019/2011', 'Костюм сигнальный зимний (4 климатический пояс) мужской повышенной видимости 3 класс защиты (куртка, полукомбинезон) З Ми Со Тн3 оранжевый, синий модель Спектр 2 р-р 104-108/182-188 ТР ТС 019/2011']
#   Различные файлы: ['Аппараты емкостные вертикал. прочие 2+_1.xlsx', 'Гидроэлеваторы пожарные_1.xlsx', 'Костюмы зим. сигнал. 1 класс_2.xlsx', 'Костюмы зим. сигнал. 2 класс_2.xlsx', 'Костюмы зим. сигнал. 3 класс_2.xlsx']
#   Различные краткие наименования: ['Труба ТЛТ 114-73 (т)', 'Труба ТК 114-89 (т)', 'Труба ТК 73-48 (т)', 'Труба ТК 89-60 (т)']
#   Различные полные наименования: ['Труба обсадная теплоизолированная ТЛТ 114-73 (т)', 'Труба обсадная теплоизолированная ТК 114-89 (т)', 'Труба обсадная теплоизолированная ТК 73-48 (т)', 'Труба обсадная теплоизолированная ТК 89-60 (т)']
#
# Данные о дубликатах сохранены в файл: 'дубликаты_эталон.xlsx'
# Всего записей в файле дубликатов: 13239
#
# === СВОДНАЯ СТАТИСТИКА ПО ДУБЛИКАТАМ ===
# Всего проблемных кодов: 5424
# Общее количество записей с дубликатами: 13239
# Кодов с разными краткими наименованиями: 1007
# Кодов с разными полными наименованиями: 928
# Кодов с разными обоими наименованиями: 818
#
# Анализ завершен!

# %%
import pandas as pd
import os

def load_and_process_excel_file(file_path):
    """
    Загружает и обрабатывает Excel файл с указанной структурой
    """
    try:
        # Читаем файл
        df = pd.read_excel(file_path)
        
        # Сохраняем имя файла
        file_name = os.path.basename(file_path)
        
        # Удаляем вторую строку (индекс 0)
        df = df.drop(0, errors='ignore').reset_index(drop=True)
        
        # Список колонок для сохранения
        target_columns = [
            'Hierarchy_MTR_Class',
            'Hierarchy_MTR_Name', 
            'CSCD_ID',
            'SHORT_NAME/ru_RU',
            'FULL_NAME/ru_RU',
            'TMC_Stat',
            'TMC_Type',
            'COMMENT',
            'AUTO_SHORT_NAME',
            'AUTO_FULL_NAME'
        ]
        
        # Оставляем только нужные колонки (если они существуют)
        existing_columns = [col for col in target_columns if col in df.columns]
        df = df[existing_columns]
        
        # Добавляем колонку с именем файла
        df['source_file'] = file_name
        
        print(f"Файл '{file_name}' успешно загружен. Колонки: {list(df.columns)}")
        return df
        
    except Exception as e:
        print(f"Ошибка при загрузке файла {file_path}: {str(e)}")
        return None

def add_excel_files_to_dataframe(initial_df=None):
    """
    Функция для добавления Excel файлов к датафрейму
    """
    if initial_df is None:
        df_combined = pd.DataFrame()
    else:
        df_combined = initial_df.copy()
    
    while True:
        print("\n" + "="*50)
        print("ДОБАВЛЕНИЕ EXCEL ФАЙЛОВ")
        print("="*50)
        print("1 - Добавить файл")
        print("2 - Завершить добавление и показать результат")
        
        choice = input("Выберите действие (1 или 2): ").strip()
        
        if choice == '1':
            file_path = input("Введите путь к Excel файлу: ").strip()
            
            if not os.path.exists(file_path):
                print("Файл не существует!")
                continue
                
            new_df = load_and_process_excel_file(file_path)
            
            if new_df is not None:
                if df_combined.empty:
                    df_combined = new_df
                else:
                    # Проверяем совпадение структуры колонок
                    if set(df_combined.columns) == set(new_df.columns):
                        df_combined = pd.concat([df_combined, new_df], ignore_index=True)
                        print(f"Файл добавлен. Всего записей: {len(df_combined)}")
                    else:
                        print("Ошибка: структура колонок не совпадает с основным датафреймом!")
                        print(f"Ожидаемые колонки: {list(df_combined.columns)}")
                        print(f"Фактические колонки: {list(new_df.columns)}")
                        
        elif choice == '2':
            break
        else:
            print("Неверный выбор!")
    
    return df_combined

# Основной блок выполнения
print("=== ЗАГРУЗКА ВТОРОГО ДАТАФРЕЙМА ===")
# Out:
# === ЗАГРУЗКА ВТОРОГО ДАТАФРЕЙМА ===

# %%
# Вариант 1: Загрузка одного файла
file_path = input("TMCclean.xlsx").strip()
#file_path = "Движки.xlsx"

if os.path.exists(file_path):
    df_second = load_and_process_excel_file(file_path)
    
    if df_second is not None:
        # Вариант 2: Добавление дополнительных файлов
        df_second = add_excel_files_to_dataframe(df_second)
        
        # Вывод информации о датафрейме
        print("\n" + "="*50)
        print("ИТОГОВЫЙ ДАТАФРЕЙМ")
        print("="*50)
        print(f"Размер датафрейма: {df_second.shape}")
        print(f"Колонки: {list(df_second.columns)}")
        print(f"Уникальных файлов-источников: {df_second['source_file'].nunique()}")
        
        # Статистика по файлам-источникам
        if not df_second.empty:
            print("\nРаспределение по файлам-источникам:")
            file_stats = df_second['source_file'].value_counts()
            for file, count in file_stats.items():
                print(f"  {file}: {count} записей")
            
            # Показываем первые строки
            print("\nПервые 5 строк датафрейма:")
            display(df_second.head())
            
            # Сохранение объединенного датафрейма (опционально)
            save_choice = input("\nСохранить объединенный датафрейм в файл? (y/n): ").strip().lower()
            if save_choice == 'y':
                output_file = "объединенный_датафрейм.xlsx"
                df_second.to_excel(output_file, index=False)
                print(f"Датафрейм сохранен в файл: {output_file}")
else:
    print("Указанный файл не существует!")
    df_second = None
# Out:
# Файл 'TMCclean.xlsx' успешно загружен. Колонки: ['Hierarchy_MTR_Class', 'Hierarchy_MTR_Name', 'CSCD_ID', 'SHORT_NAME/ru_RU', 'FULL_NAME/ru_RU', 'TMC_Stat', 'TMC_Type', 'COMMENT', 'AUTO_SHORT_NAME', 'AUTO_FULL_NAME', 'source_file']
#
# ==================================================
# ДОБАВЛЕНИЕ EXCEL ФАЙЛОВ
# ==================================================
# 1 - Добавить файл
# 2 - Завершить добавление и показать результат
# Файл 'SUP.xlsx' успешно загружен. Колонки: ['Hierarchy_MTR_Class', 'Hierarchy_MTR_Name', 'CSCD_ID', 'SHORT_NAME/ru_RU', 'FULL_NAME/ru_RU', 'TMC_Stat', 'TMC_Type', 'COMMENT', 'AUTO_SHORT_NAME', 'AUTO_FULL_NAME', 'source_file']
# Файл добавлен. Всего записей: 1370962
#
# ==================================================
# ДОБАВЛЕНИЕ EXCEL ФАЙЛОВ
# ==================================================
# 1 - Добавить файл
# 2 - Завершить добавление и показать результат
#
# ==================================================
# ИТОГОВЫЙ ДАТАФРЕЙМ
# ==================================================
# Размер датафрейма: (1370962, 11)
# Колонки: ['Hierarchy_MTR_Class', 'Hierarchy_MTR_Name', 'CSCD_ID', 'SHORT_NAME/ru_RU', 'FULL_NAME/ru_RU', 'TMC_Stat', 'TMC_Type', 'COMMENT', 'AUTO_SHORT_NAME', 'AUTO_FULL_NAME', 'source_file']
# Уникальных файлов-источников: 2
#
# Распределение по файлам-источникам:
#   SUP.xlsx: 775834 записей
#   TMCclean.xlsx: 595128 записей
#
# Первые 5 строк датафрейма:
#    Hierarchy_MTR_Class                        Hierarchy_MTR_Name  CSCD_ID  \
# 0         7.011105e+14                       Канцелярские товары  3703093
# 1         7.010909e+14               Мебель и предметы интерьера  2227673
# 2         7.010909e+14               Мебель и предметы интерьера  2227684
# 3         7.010907e+14                      Хозяйственные товары  2331818
# 4         6.020111e+14  Масла трансп фирм Премиум неподакц фасов  3648365
#
#                           SHORT_NAME/ru_RU  \
# 0    Обложка Brauberg картонная арт.530947
# 1                    Витрина табачная 2400
# 2                    Витрина табачная 2600
# 3  Органайзер д/раковины, диспенсер д/мыла
# 4      Масло L GEAR GL-4 SYNTH 75W85 нк.4л
#
#                                      FULL_NAME/ru_RU  TMC_Stat  TMC_Type  \
# 0  Обложка Brauberg картонная для переплета, арти...         0         4
# 1                              Витрина табачная 2400         0         3
# 2                              Витрина табачная 2600         0         3
# 3        Органайзер для раковины, диспенсер для мыла         0         4
# 4  Масло трансмиссионное LUKOIL GEAR GL-4 SYNTH 7...         0         3
#
#                                              COMMENT AUTO_SHORT_NAME  \
# 0                                                NaN             NaN
# 1                                          стр 57 МК             NaN
# 2                                         стр. 57 МК             NaN
# 3                                                NaN             NaN
# 4  Внесены изменения по заявке от ЛЛК CRQ00000098...             NaN
#
#   AUTO_FULL_NAME    source_file
# 0            NaN  TMCclean.xlsx
# 1            NaN  TMCclean.xlsx
# 2            NaN  TMCclean.xlsx
# 3            NaN  TMCclean.xlsx
# 4            NaN  TMCclean.xlsx

# %%
# Фильтрация записей с подстрокой "Эталон" или "эталон" в поле COMMENT
print("=== ФИЛЬТРАЦИЯ ЗАПИСЕЙ С 'ЭТАЛОН' В COMMENT ===")

if df_second is not None and not df_second.empty:
    # Проверяем наличие колонки COMMENT в датафрейме
    if 'COMMENT' in df_second.columns:
        # Создаем маску для фильтрации
        mask = df_second['COMMENT'].notna() & (
            df_second['COMMENT'].str.contains('Эталон', case=False, na=False) |
            df_second['COMMENT'].str.contains('эталон', case=False, na=False)
        )
        
        # Альтернативный более простой вариант (учитывает регистр):
        # mask = df_second['COMMENT'].notna() & df_second['COMMENT'].str.contains('эталон', case=False, na=False)
        
        # Применяем фильтр
        df_ksss_etalon = df_second[mask].copy()
        
        print(f"Всего записей в исходном датафрейме: {len(df_second)}")
        print(f"Найдено Эталонных записей: {len(df_ksss_etalon)}")
        
        if not df_ksss_etalon.empty:
            print(f"\nКолонки в df_ksss_etalon: {list(df_ksss_etalon.columns)}")
            
            # Показываем примеры найденных комментариев
            print("\nПримеры найденных комментариев:")
            for idx, comment in enumerate(df_ksss_etalon['COMMENT'].head(5)):
                print(f"  {idx+1}. {comment}")
            
            # Статистика по источникам
            print(f"\nРаспределение по файлам-источникам:")
            source_stats = df_ksss_etalon['source_file'].value_counts()
            for file, count in source_stats.items():
                print(f"  {file}: {count} записей")
            
            # Дополнительная информация о найденных записях
            print(f"\nДополнительная статистика:")
            print(f"Уникальных CSCD_ID: {df_ksss_etalon['CSCD_ID'].nunique()}")
            print(f"Уникальных файлов-источников: {df_ksss_etalon['source_file'].nunique()}")
            
            # Показываем первые строки отфильтрованного датафрейма
            print("\nПервые 5 строк df_ksss_etalon:")
            display(df_ksss_etalon.head())
            
            # Сохраняем в Excel файл (опционально)
            save_choice = input("\nСохранить df_ksss_etalon в файл? (y/n): ").strip().lower()
            if save_choice == 'y':
                output_file = "df_ksss_etalon.xlsx"
                df_ksss_etalon.to_excel(output_file, index=False)
                print(f"Датафрейм сохранен в файл: {output_file}")
        else:
            print("Записей с 'Эталон' в COMMENT не найдено!")
            df_ksss_etalon = pd.DataFrame()
    else:
        print("Колонка 'COMMENT' не найдена в датафрейме!")
        print(f"Доступные колонки: {list(df_second.columns)}")
        df_ksss_etalon = pd.DataFrame()
else:
    print("Исходный датафрейм пуст или не загружен!")
    df_ksss_etalon = pd.DataFrame()
# Out:
# === ФИЛЬТРАЦИЯ ЗАПИСЕЙ С 'ЭТАЛОН' В COMMENT ===
# Всего записей в исходном датафрейме: 1370962
# Найдено записей с 'Эталон' в COMMENT: 105169
#
# Колонки в df_ksss_etalon: ['Hierarchy_MTR_Class', 'Hierarchy_MTR_Name', 'CSCD_ID', 'SHORT_NAME/ru_RU', 'FULL_NAME/ru_RU', 'TMC_Stat', 'TMC_Type', 'COMMENT', 'AUTO_SHORT_NAME', 'AUTO_FULL_NAME', 'source_file']
#
# Примеры найденных комментариев:
#   1. Эталонная запись
#   2. Эталонная запись
#   3. Эталонная запись
#   4. Эталонная запись
#   5. Эталонная запись
#
# Распределение по файлам-источникам:
#   TMCclean.xlsx: 104060 записей
#   SUP.xlsx: 1109 записей
#
# Дополнительная статистика:
# Уникальных CSCD_ID: 105169
# Уникальных файлов-источников: 2
#
# Первые 5 строк df_ksss_etalon:
#      Hierarchy_MTR_Class                   Hierarchy_MTR_Name  CSCD_ID  \
# 56          3.001010e+15               Куртки лет муж ЛМ01-01  6087431
# 57          3.001010e+15               Куртки лет муж ЛМ01-01  6087428
# 58          3.001010e+15               Куртки лет муж ЛМ01-01  6087429
# 59          3.001010e+15               Куртки лет муж ЛМ01-01  6087430
# 102         2.013050e+15  Трубы полимерные напорные фирменные  6064143
#
#                      SHORT_NAME/ru_RU  \
# 56                   Куртка ЛМ01-01 2
# 57   Куртка ЛМ01-01 2 104-108/158-164
# 58    Куртка ЛМ01-01 2 96-100/170-176
# 59     Куртка ЛМ01-01 2 88-92/170-176
# 102   Труба PPR-C 30х3,4 0-29-0220(м)
#
#                                        FULL_NAME/ru_RU  TMC_Stat  TMC_Type  \
# 56   Куртка летняя мужская для защиты от нефти и не...         0         2
# 57   Куртка летняя мужская для защиты от нефти и не...         0         3
# 58   Куртка летняя мужская для защиты от нефти и не...         0         3
# 59   Куртка летняя мужская для защиты от нефти и не...         0         3
# 102  Труба PPR-C 30х3,4 артикул 0-29-0220 Aquasfera...         0         3
#
#               COMMENT                                    AUTO_SHORT_NAME  \
# 56   Эталонная запись  Куртка ЛМ01-01 2[Размер одежды(обхват) ?][Рост ?]
# 57   Эталонная запись                   Куртка ЛМ01-01 2 104-108/158-164
# 58   Эталонная запись                    Куртка ЛМ01-01 2 96-100/170-176
# 59   Эталонная запись                     Куртка ЛМ01-01 2 88-92/170-176
# 102  Эталонная запись                    Труба PPR-C 30х3,4 0-29-0220(м)
#
#                                         AUTO_FULL_NAME    source_file
# 56   Куртка летняя мужская для защиты от нефти и не...  TMCclean.xlsx
# 57   Куртка летняя мужская для защиты от нефти и не...  TMCclean.xlsx
# 58   Куртка летняя мужская для защиты от нефти и не...  TMCclean.xlsx
# 59   Куртка летняя мужская для защиты от нефти и не...  TMCclean.xlsx
# 102  Труба PPR-C 30х3,4 артикул 0-29-0220 Aquasfera...  TMCclean.xlsx
# Датафрейм сохранен в файл: df_ksss_etalon.xlsx

# %%
# Сравнение датафреймов etalon_df и df_ksss_etalon
print("=== СРАВНЕНИЕ ДАТАФРЕЙМОВ ===")
print(f"Размер etalon_df: {etalon_df.shape if etalon_df is not None else 'не загружен'}")
print(f"Размер df_ksss_etalon: {df_ksss_etalon.shape if df_ksss_etalon is not None else 'не загружен'}")

# Проверяем, что оба датафрейма загружены и не пусты
if etalon_df is not None and not etalon_df.empty and df_ksss_etalon is not None and not df_ksss_etalon.empty:
    
    # Создаем копии для безопасной работы
    etalon_clean = etalon_df.copy()
    ksss_clean = df_ksss_etalon.copy()
    
    # Предварительная обработка данных - удаляем пробелы и приводим к строковому типу
    # Для etalon_df
    etalon_clean['Полное наименование нормализованное'] = etalon_clean['Полное наименование нормализованное'].astype(str).str.strip()
    etalon_clean['Краткое наименование нормализованное'] = etalon_clean['Краткое наименование нормализованное'].astype(str).str.strip()
    etalon_clean['Код КССС/id'] = etalon_clean['Код КССС/id'].astype(str).str.strip()
    
    # Для df_ksss_etalon
    ksss_clean['FULL_NAME/ru_RU'] = ksss_clean['FULL_NAME/ru_RU'].astype(str).str.strip()
    ksss_clean['SHORT_NAME/ru_RU'] = ksss_clean['SHORT_NAME/ru_RU'].astype(str).str.strip()
    if 'CSCD_ID' in ksss_clean.columns:
        ksss_clean['CSCD_ID'] = ksss_clean['CSCD_ID'].astype(str).str.strip()
    
    # Создаем список для совпавших записей
    matched_records = []
    
    print("\nПоиск совпадений...")
    
    # Проходим по каждой записи в etalon_df
    for idx, etalon_row in etalon_clean.iterrows():
        etalon_full_name = etalon_row['Полное наименование нормализованное']
        etalon_short_name = etalon_row['Краткое наименование нормализованное']
        etalon_code = etalon_row['Код КССС/id']
        
        # Ищем совпадения по полному наименованию
        full_name_matches = ksss_clean[ksss_clean['FULL_NAME/ru_RU'] == etalon_full_name]
        
        if not full_name_matches.empty:
            # Найдено совпадение по полному наименованию
            for _, ksss_row in full_name_matches.iterrows():
                matched_record = {
                    # Данные из etalon_df
                    'Код КССС/id_etalon': etalon_code,
                    'Полное наименование нормализованное_etalon': etalon_full_name,
                    'Краткое наименование нормализованное_etalon': etalon_short_name,
                    'Статус_etalon': etalon_row['Статус'],
                    'Папка_etalon': etalon_row['Папка'],
                    'Имя файла_etalon': etalon_row['Имя файла'],
                    
                    # Данные из df_ksss_etalon
                    'CSCD_ID_ksss': ksss_row.get('CSCD_ID', ''),
                    'FULL_NAME/ru_RU_ksss': ksss_row.get('FULL_NAME/ru_RU', ''),
                    'SHORT_NAME/ru_RU_ksss': ksss_row.get('SHORT_NAME/ru_RU', ''),
                    'TMC_Stat_ksss': ksss_row.get('TMC_Stat', ''),
                    'TMC_Type_ksss': ksss_row.get('TMC_Type', ''),
                    'COMMENT_ksss': ksss_row.get('COMMENT', ''),
                    'AUTO_SHORT_NAME_ksss': ksss_row.get('AUTO_SHORT_NAME', ''),
                    'AUTO_FULL_NAME_ksss': ksss_row.get('AUTO_FULL_NAME', ''),
                    'Hierarchy_MTR_Class_ksss': ksss_row.get('Hierarchy_MTR_Class', ''),
                    'Hierarchy_MTR_Name_ksss': ksss_row.get('Hierarchy_MTR_Name', ''),
                    'source_file_ksss': ksss_row.get('source_file', ''),
                    
                    # Информация о типе совпадения
                    'Тип_совпадения': 'Полное наименование'
                }
                matched_records.append(matched_record)
        
        else:
            # Если нет совпадения по полному наименованию, ищем по краткому
            short_name_matches = ksss_clean[ksss_clean['SHORT_NAME/ru_RU'] == etalon_short_name]
            
            if not short_name_matches.empty:
                # Найдено совпадение по краткому наименованию
                for _, ksss_row in short_name_matches.iterrows():
                    matched_record = {
                        # Данные из etalon_df
                        'Код КССС/id_etalon': etalon_code,
                        'Полное наименование нормализованное_etalon': etalon_full_name,
                        'Краткое наименование нормализованное_etalon': etalon_short_name,
                        'Статус_etalon': etalon_row['Статус'],
                        'Папка_etalon': etalon_row['Папка'],
                        'Имя файла_etalon': etalon_row['Имя файла'],
                        
                        # Данные из df_ksss_etalon
                        'CSCD_ID_ksss': ksss_row.get('CSCD_ID', ''),
                        'FULL_NAME/ru_RU_ksss': ksss_row.get('FULL_NAME/ru_RU', ''),
                        'SHORT_NAME/ru_RU_ksss': ksss_row.get('SHORT_NAME/ru_RU', ''),
                        'TMC_Stat_ksss': ksss_row.get('TMC_Stat', ''),
                        'TMC_Type_ksss': ksss_row.get('TMC_Type', ''),
                        'COMMENT_ksss': ksss_row.get('COMMENT', ''),
                        'AUTO_SHORT_NAME_ksss': ksss_row.get('AUTO_SHORT_NAME', ''),
                        'AUTO_FULL_NAME_ksss': ksss_row.get('AUTO_FULL_NAME', ''),
                        'Hierarchy_MTR_Class_ksss': ksss_row.get('Hierarchy_MTR_Class', ''),
                        'Hierarchy_MTR_Name_ksss': ksss_row.get('Hierarchy_MTR_Name', ''),
                        'source_file_ksss': ksss_row.get('source_file', ''),
                        
                        # Информация о типе совпадения
                        'Тип_совпадения': 'Краткое наименование'
                    }
                    matched_records.append(matched_record)
    
    # Создаем итоговый датафрейм
    if matched_records:
        df_full_match = pd.DataFrame(matched_records)
        
        print(f"\nРЕЗУЛЬТАТЫ СРАВНЕНИЯ:")
        print(f"Всего записей в etalon_df: {len(etalon_clean)}")
        print(f"Найдено совпадений: {len(df_full_match)}")
        
        # Анализ типов совпадений
        match_types = df_full_match['Тип_совпадения'].value_counts()
        print(f"\nТипы совпадений:")
        for match_type, count in match_types.items():
            print(f"  {match_type}: {count}")
        
        # Уникальные совпадения (по кодам из etalon_df)
        unique_etalon_codes = df_full_match['Код КССС/id_etalon'].nunique()
        print(f"Уникальных кодов из etalon_df с совпадениями: {unique_etalon_codes}")
        
        # Уникальные совпадения (по кодам из ksss)
        if 'CSCD_ID_ksss' in df_full_match.columns:
            unique_ksss_codes = df_full_match['CSCD_ID_ksss'].nunique()
            print(f"Уникальных кодов из df_ksss_etalon с совпадениями: {unique_ksss_codes}")
        
        # Сохраняем в Excel файл
        output_filename = "результат_совпадений.xlsx"
        df_full_match.to_excel(output_filename, index=False)
        print(f"\nРезультат сохранен в файл: {output_filename}")
        
        # Показываем первые строки результата
        print(f"\nПервые 5 строк df_full_match:")
        display(df_full_match.head())
        
        # Дополнительная статистика
        print(f"\nДОПОЛНИТЕЛЬНАЯ СТАТИСТИКА:")
        print(f"Колонки в результате: {list(df_full_match.columns)}")
        
        # Распределение по файлам-источникам
        if 'source_file_ksss' in df_full_match.columns:
            print(f"\nРаспределение совпадений по файлам-источникам:")
            source_stats = df_full_match['source_file_ksss'].value_counts()
            for file, count in source_stats.head(10).items():  # Показываем топ-10
                print(f"  {file}: {count}")
        
    else:
        print("Совпадений не найдено!")
        df_full_match = pd.DataFrame()

else:
    print("Один или оба датафрейма пусты или не загружены!")
    df_full_match = pd.DataFrame()
# Out:
# === СРАВНЕНИЕ ДАТАФРЕЙМОВ ===
# Размер etalon_df: (111371, 7)
# Размер df_ksss_etalon: (105169, 11)
#
# Поиск совпадений...
#
# РЕЗУЛЬТАТЫ СРАВНЕНИЯ:
# Всего записей в etalon_df: 111371
# Найдено совпадений: 66890
#
# Типы совпадений:
#   Полное наименование: 57543
#   Краткое наименование: 9347
# Уникальных кодов из etalon_df с совпадениями: 64759
# Уникальных кодов из df_ksss_etalon с совпадениями: 65465
#
# Результат сохранен в файл: результат_совпадений.xlsx
#
# Первые 5 строк df_full_match:
#   Код КССС/id_etalon         Полное наименование нормализованное_etalon  \
# 0            1829610  Арматура устьевая универсальная ШГН, условный ...
# 1            1829611  Арматура устьевая универсальная ШГН, условный ...
# 2            2298328  Арматура устьевая универсальная ШГН, условный ...
# 3            2298423  Арматура устьевая фонтанная ЭЦН, условный прох...
# 4            2298424  Арматура устьевая фонтанная ЭЦН, условный прох...
#
#   Краткое наименование нормализованное_etalon Статус_etalon  \
# 0    Арматура уст. универсальная ШГН-50x50x14        Эталон
# 1    Арматура уст. универсальная ШГН-65x50x14        Эталон
# 2    Арматура уст. универсальная ШГН-65x65x14        Эталон
# 3        Арматура уст. фонтанная ЭЦН-65x65x21        Эталон
# 4        Арматура уст. фонтанная ЭЦН-60x60x20        Эталон
#
#                    Папка_etalon                             Имя файла_etalon  \
# 0  Арматура трубопроводная, ЗиП  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
# 1  Арматура трубопроводная, ЗиП  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
# 2  Арматура трубопроводная, ЗиП  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
# 3  Арматура трубопроводная, ЗиП  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
# 4  Арматура трубопроводная, ЗиП  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
#
#   CSCD_ID_ksss                               FULL_NAME/ru_RU_ksss  \
# 0      6055151  Арматура устьевая универсальная ШГН, условный ...
# 1      6055152  Арматура устьевая универсальная ШГН, условный ...
# 2      6055153  Арматура устьевая универсальная ШГН, условный ...
# 3      6055154  Арматура устьевая фонтанная ЭЦН, условный прох...
# 4      6055155  Арматура устьевая фонтанная ЭЦН, условный прох...
#
#                       SHORT_NAME/ru_RU_ksss  TMC_Stat_ksss  TMC_Type_ksss  \
# 0  Арматура уст. универсальная ШГН-50-50-14              0              3
# 1  Арматура уст. универсальная ШГН-65-50-14              0              3
# 2  Арматура уст. универсальная ШГН-65-65-14              0              3
# 3      Арматура уст. фонтанная ЭЦН-65-65-21              0              3
# 4      Арматура уст. фонтанная ЭЦН-60-60-20              0              3
#
#        COMMENT_ksss                      AUTO_SHORT_NAME_ksss  \
# 0  Эталонная запись  Арматура уст. универсальная ШГН-50-50-14
# 1  Эталонная запись  Арматура уст. универсальная ШГН-65-50-14
# 2  Эталонная запись  Арматура уст. универсальная ШГН-65-65-14
# 3  Эталонная запись      Арматура уст. фонтанная ЭЦН-65-65-21
# 4  Эталонная запись      Арматура уст. фонтанная ЭЦН-60-60-20
#
#                                  AUTO_FULL_NAME_ksss  \
# 0  Арматура устьевая универсальная ШГН, условный ...
# 1  Арматура устьевая универсальная ШГН, условный ...
# 2  Арматура устьевая универсальная ШГН, условный ...
# 3  Арматура устьевая фонтанная ЭЦН, условный прох...
# 4  Арматура устьевая фонтанная ЭЦН, условный прох...
#
#    Hierarchy_MTR_Class_ksss              Hierarchy_MTR_Name_ksss  \
# 0              2.010020e+15  Арматура уст.фонт.,нагн., д/ШГН,ЭЦН
# 1              2.010020e+15  Арматура уст.фонт.,нагн., д/ШГН,ЭЦН
# 2              2.010020e+15  Арматура уст.фонт.,нагн., д/ШГН,ЭЦН
# 3              2.010020e+15  Арматура уст.фонт.,нагн., д/ШГН,ЭЦН
# 4              2.010020e+15  Арматура уст.фонт.,нагн., д/ШГН,ЭЦН
#
#   source_file_ksss       Тип_совпадения
# 0    TMCclean.xlsx  Полное наименование
# 1    TMCclean.xlsx  Полное наименование
# 2    TMCclean.xlsx  Полное наименование
# 3    TMCclean.xlsx  Полное наименование
# 4    TMCclean.xlsx  Полное наименование
# ДОПОЛНИТЕЛЬНАЯ СТАТИСТИКА:
# Колонки в результате: ['Код КССС/id_etalon', 'Полное наименование нормализованное_etalon', 'Краткое наименование нормализованное_etalon', 'Статус_etalon', 'Папка_etalon', 'Имя файла_etalon', 'CSCD_ID_ksss', 'FULL_NAME/ru_RU_ksss', 'SHORT_NAME/ru_RU_ksss', 'TMC_Stat_ksss', 'TMC_Type_ksss', 'COMMENT_ksss', 'AUTO_SHORT_NAME_ksss', 'AUTO_FULL_NAME_ksss', 'Hierarchy_MTR_Class_ksss', 'Hierarchy_MTR_Name_ksss', 'source_file_ksss', 'Тип_совпадения']
#
# Распределение совпадений по файлам-источникам:
#   TMCclean.xlsx: 66373
#   SUP.xlsx: 517

# %%
# Создание датафреймов с несопоставленными записями
print("=== СОЗДАНИЕ ДАТАФРЕЙМОВ С НЕСОПОСТАВЛЕННЫМИ ЗАПИСЯМИ ===")

# Проверяем, что оба исходных датафрейма загружены
if etalon_df is not None and not etalon_df.empty and df_ksss_etalon is not None and not df_ksss_etalon.empty:
    
    # Создаем копии для безопасной работы
    etalon_clean = etalon_df.copy()
    ksss_clean = df_ksss_etalon.copy()
    
    # Предварительная обработка данных (аналогично предыдущему коду)
    etalon_clean['Полное наименование нормализованное'] = etalon_clean['Полное наименование нормализованное'].astype(str).str.strip()
    etalon_clean['Краткое наименование нормализованное'] = etalon_clean['Краткое наименование нормализованное'].astype(str).str.strip()
    etalon_clean['Код КССС/id'] = etalon_clean['Код КССС/id'].astype(str).str.strip()
    
    ksss_clean['FULL_NAME/ru_RU'] = ksss_clean['FULL_NAME/ru_RU'].astype(str).str.strip()
    ksss_clean['SHORT_NAME/ru_RU'] = ksss_clean['SHORT_NAME/ru_RU'].astype(str).str.strip()
    if 'CSCD_ID' in ksss_clean.columns:
        ksss_clean['CSCD_ID'] = ksss_clean['CSCD_ID'].astype(str).str.strip()
    
    # Создаем множества для быстрого поиска совпавших записей
    matched_etalon_full_names = set()
    matched_etalon_short_names = set()
    matched_ksss_full_names = set()
    matched_ksss_short_names = set()
    
    # Заполняем множества на основе df_full_match
    if 'df_full_match' in globals() and not df_full_match.empty:
        print("Используем информацию из df_full_match для поиска несопоставленных записей...")
        
        # Собираем все совпавшие наименования из etalon_df
        if 'Полное наименование нормализованное_etalon' in df_full_match.columns:
            matched_etalon_full_names = set(df_full_match['Полное наименование нормализованное_etalon'].dropna().unique())
        if 'Краткое наименование нормализованное_etalon' in df_full_match.columns:
            matched_etalon_short_names = set(df_full_match['Краткое наименование нормализованное_etalon'].dropna().unique())
        
        # Собираем все совпавшие наименования из df_ksss_etalon
        if 'FULL_NAME/ru_RU_ksss' in df_full_match.columns:
            matched_ksss_full_names = set(df_full_match['FULL_NAME/ru_RU_ksss'].dropna().unique())
        if 'SHORT_NAME/ru_RU_ksss' in df_full_match.columns:
            matched_ksss_short_names = set(df_full_match['SHORT_NAME/ru_RU_ksss'].dropna().unique())
    
    else:
        print("df_full_match не найден, выполняем поиск совпадений заново...")
        # Если df_full_match не создан, выполняем поиск совпадений
        for idx, etalon_row in etalon_clean.iterrows():
            etalon_full_name = etalon_row['Полное наименование нормализованное']
            etalon_short_name = etalon_row['Краткое наименование нормализованное']
            
            # Проверяем совпадения по полному наименованию
            full_name_matches = ksss_clean[ksss_clean['FULL_NAME/ru_RU'] == etalon_full_name]
            if not full_name_matches.empty:
                matched_etalon_full_names.add(etalon_full_name)
                matched_ksss_full_names.update(full_name_matches['FULL_NAME/ru_RU'].unique())
            
            # Проверяем совпадения по краткому наименованию
            short_name_matches = ksss_clean[ksss_clean['SHORT_NAME/ru_RU'] == etalon_short_name]
            if not short_name_matches.empty:
                matched_etalon_short_names.add(etalon_short_name)
                matched_ksss_short_names.update(short_name_matches['SHORT_NAME/ru_RU'].unique())
    
    # Создаем датафреймы с несопоставленными записями
    
    # 1. Несопоставленные записи из etalon_df
    unmatched_etalon_mask = ~(
        etalon_clean['Полное наименование нормализованное'].isin(matched_etalon_full_names) |
        etalon_clean['Краткое наименование нормализованное'].isin(matched_etalon_short_names)
    )
    
    df_unmatched_etalon = etalon_clean[unmatched_etalon_mask].copy()
    
    # 2. Несопоставленные записи из df_ksss_etalon
    unmatched_ksss_mask = ~(
        ksss_clean['FULL_NAME/ru_RU'].isin(matched_ksss_full_names) |
        ksss_clean['SHORT_NAME/ru_RU'].isin(matched_ksss_short_names)
    )
    
    df_unmatched_ksss = ksss_clean[unmatched_ksss_mask].copy()
    
    # Выводим статистику
    print(f"\nСТАТИСТИКА НЕСОПОСТАВЛЕННЫХ ЗАПИСЕЙ:")
    print(f"Всего записей в etalon_df: {len(etalon_clean)}")
    print(f"Несопоставленных записей из etalon_df: {len(df_unmatched_etalon)}")
    print(f"Всего записей в df_ksss_etalon: {len(ksss_clean)}")
    print(f"Несопоставленных записей из df_ksss_etalon: {len(df_unmatched_ksss)}")
    
    # Сохраняем датафреймы в Excel файлы
    if not df_unmatched_etalon.empty:
        df_unmatched_etalon.to_excel("несопоставленные_записи_etalon.xlsx", index=False)
        print(f"\nНесопоставленные записи из etalon_df сохранены в файл: 'несопоставленные_записи_etalon.xlsx'")
        
        # Показываем первые строки
        print("\nПервые 5 несопоставленных записей из etalon_df:")
        display(df_unmatched_etalon.head())
    else:
        print("\nВсе записи из etalon_df были сопоставлены!")
    
    if not df_unmatched_ksss.empty:
        df_unmatched_ksss.to_excel("несопоставленные_записи_ksss.xlsx", index=False)
        print(f"Несопоставленные записи из df_ksss_etalon сохранены в файл: 'несопоставленные_записи_ksss.xlsx'")
        
        # Показываем первые строки
        print("\nПервые 5 несопоставленных записей из df_ksss_etalon:")
        display(df_unmatched_ksss.head())
    else:
        print("Все записи из df_ksss_etalon были сопоставлены!")
    
    # Дополнительный анализ несопоставленных записей
    print(f"\n=== АНАЛИЗ НЕСОПОСТАВЛЕННЫХ ЗАПИСЕЙ ===")
    
    if not df_unmatched_etalon.empty:
        print("АНАЛИЗ НЕСОПОСТАВЛЕННЫХ ЗАПИСЕЙ ИЗ etalon_df:")
        print(f"Уникальных кодов: {df_unmatched_etalon['Код КССС/id'].nunique()}")
        print(f"Уникальных файлов-источников: {df_unmatched_etalon['Имя файла'].nunique()}")
        
        # Проверяем наличие пустых наименований
        empty_full_names = df_unmatched_etalon['Полное наименование нормализованное'].isin(['', 'nan', 'None'])
        empty_short_names = df_unmatched_etalon['Краткое наименование нормализованное'].isin(['', 'nan', 'None'])
        
        print(f"Записей с пустым полным наименованием: {empty_full_names.sum()}")
        print(f"Записей с пустым кратким наименованием: {empty_short_names.sum()}")
    
    if not df_unmatched_ksss.empty:
        print("\nАНАЛИЗ НЕСОПОСТАВЛЕННЫХ ЗАПИСЕЙ ИЗ df_ksss_etalon:")
        print(f"Уникальных кодов CSCD_ID: {df_unmatched_ksss['CSCD_ID'].nunique() if 'CSCD_ID' in df_unmatched_ksss.columns else 'N/A'}")
        print(f"Уникальных файлов-источников: {df_unmatched_ksss['source_file'].nunique()}")
        
        # Анализ статусов
        if 'TMC_Stat' in df_unmatched_ksss.columns:
            print(f"\nРаспределение статусов в несопоставленных записях:")
            stat_counts = df_unmatched_ksss['TMC_Stat'].value_counts()
            for stat, count in stat_counts.items():
                percentage = (count / len(df_unmatched_ksss)) * 100
                print(f"  {stat}: {count} ({percentage:.1f}%)")
    
    # Визуализация результатов
    import matplotlib.pyplot as plt
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 4))
    
    # График 1: Сопоставленные vs несопоставленные записи
    categories = ['etalon_df', 'df_ksss_etalon']
    matched_counts = [
        len(etalon_clean) - len(df_unmatched_etalon),
        len(ksss_clean) - len(df_unmatched_ksss)
    ]
    unmatched_counts = [
        len(df_unmatched_etalon),
        len(df_unmatched_ksss)
    ]
    
    x = range(len(categories))
    ax1.bar(x, matched_counts, label='Сопоставленные', color='lightgreen', alpha=0.7)
    ax1.bar(x, unmatched_counts, bottom=matched_counts, label='Несопоставленные', color='lightcoral', alpha=0.7)
    
    ax1.set_title('Сопоставленные vs несопоставленные записи')
    ax1.set_xlabel('Датафреймы')
    ax1.set_ylabel('Количество записей')
    ax1.set_xticks(x)
    ax1.set_xticklabels(categories)
    ax1.legend()
    ax1.grid(axis='y', alpha=0.3)
    
    # Добавляем подписи значений
    for i, (matched, unmatched) in enumerate(zip(matched_counts, unmatched_counts)):
        ax1.text(i, matched/2, f'{matched}', ha='center', va='center', fontweight='bold')
        ax1.text(i, matched + unmatched/2, f'{unmatched}', ha='center', va='center', fontweight='bold')
    
    # График 2: Процент несопоставленных записей
    unmatched_percentages = [
        (len(df_unmatched_etalon) / len(etalon_clean)) * 100,
        (len(df_unmatched_ksss) / len(ksss_clean)) * 100
    ]
    
    bars = ax2.bar(categories, unmatched_percentages, color=['lightblue', 'lightcoral'])
    ax2.set_title('Процент несопоставленных записей')
    ax2.set_ylabel('Процент (%)')
    ax2.grid(axis='y', alpha=0.3)
    
    # Добавляем подписи значений на столбцы
    for bar, percentage in zip(bars, unmatched_percentages):
        height = bar.get_height()
        ax2.text(bar.get_x() + bar.get_width()/2., height + 1,
                f'{percentage:.1f}%', ha='center', va='bottom')
    
    plt.tight_layout()
    plt.show()

else:
    print("Один или оба исходных датафрейма пусты или не загружены!")
    df_unmatched_etalon = pd.DataFrame()
    df_unmatched_ksss = pd.DataFrame()
# Out:
# === СОЗДАНИЕ ДАТАФРЕЙМОВ С НЕСОПОСТАВЛЕННЫМИ ЗАПИСЯМИ ===
# Используем информацию из df_full_match для поиска несопоставленных записей...
#
# СТАТИСТИКА НЕСОПОСТАВЛЕННЫХ ЗАПИСЕЙ:
# Всего записей в etalon_df: 111371
# Несопоставленных записей из etalon_df: 35128
# Всего записей в df_ksss_etalon: 105169
# Несопоставленных записей из df_ksss_etalon: 39688
#
# Несопоставленные записи из etalon_df сохранены в файл: 'несопоставленные_записи_etalon.xlsx'
#
# Первые 5 несопоставленных записей из etalon_df:
#     Код КССС/id    Краткое наименование нормализованное  \
# 486     3201379    Блок клапанов 50с03нж3 DN50 PN40 КОФ
# 496     3206188   Блок клапанов 50лс08нж3 DN80 PN63 КОФ
# 497     3202488  Блок клапанов 50нж11нж4 DN100 PN40 КОФ
# 498     3206189  Блок клапанов 50лс36нж4 DN200 PN16 КОФ
# 519     1624898        Блок клапанов 17нж14нж DN25 PN40
#
#                    Полное наименование нормализованное  \
# 486  Блок клапанов предохранительных 50с03нж3 DN50 ...
# 496  Блок клапанов предохранительных 50лс08нж3 DN80...
# 497  Блок клапанов предохранительных 50нж11нж4 DN10...
# 498  Блок клапанов предохранительных 50лс36нж4 DN20...
# 519  Блок клапанов предохранительных 17нж14нж DN25 ...
#
#               Краткое наименование КССС (исх)  Статус  \
# 486  Блок 50с03нж3 DN50 PN40 Pн1,31 пр.№14 У1  Эталон
# 496       Блок БПУ РС 80-63 лс пр.№40 КОФ ХЛ1  Эталон
# 497   Блок 50нж11нж4 DN100 PN40 пр.№57 КОФ У2  Эталон
# 498  Блок БПУ6 200-16 лс пр.№606, 624 КОФ ХЛ1  Эталон
# 519       Блок БПУ 25-40 50нж01нж Рн4,2 пр.№8  Эталон
#
#                             Папка                                 Имя файла
# 486  Арматура трубопроводная, ЗиП  Блоки клапанов предохр. стальные_39.xlsx
# 496  Арматура трубопроводная, ЗиП  Блоки клапанов предохр. стальные_39.xlsx
# 497  Арматура трубопроводная, ЗиП  Блоки клапанов предохр. стальные_39.xlsx
# 498  Арматура трубопроводная, ЗиП  Блоки клапанов предохр. стальные_39.xlsx
# 519  Арматура трубопроводная, ЗиП  Блоки клапанов предохр. стальные_39.xlsx
# Несопоставленные записи из df_ksss_etalon сохранены в файл: 'несопоставленные_записи_ksss.xlsx'
#
# Первые 5 несопоставленных записей из df_ksss_etalon:
#      Hierarchy_MTR_Class                   Hierarchy_MTR_Name  CSCD_ID  \
# 102         2.013050e+15  Трубы полимерные напорные фирменные  6064143
# 103         2.013050e+15  Трубы полимерные напорные фирменные  6064144
# 104         2.013050e+15  Трубы полимерные напорные фирменные  6064145
# 105         2.013050e+15  Трубы полимерные напорные фирменные  6064146
# 106         2.013050e+15  Трубы полимерные напорные фирменные  6064147
#
#                              SHORT_NAME/ru_RU  \
# 102           Труба PPR-C 30х3,4 0-29-0220(м)
# 103            Труба ПЭ100 90х10,6 ТН-90-В(м)
# 104            Труба ПЭ100 110х13 ТН-110-В(м)
# 105  Труба PP-R 100 32х4,4 VTp.700.FB20.32(м)
# 106            Труба Pex-Al-Pex 16х2 V1620(м)
#
#                                        FULL_NAME/ru_RU  TMC_Stat  TMC_Type  \
# 102  Труба PPR-C 30х3,4 артикул 0-29-0220 Aquasfera...         0         3
# 103   Труба ПЭ100 90х10,6 артикул ТН-90-В Anaconda (м)         0         3
# 104   Труба ПЭ100 110х13 артикул ТН-110-В Anaconda (м)         0         3
# 105  Труба PP-R 100 32х4,4 артикул VTp.700.FB20.32 ...         0         3
# 106     Труба Pex-Al-Pex 16х2 артикул V1620 Valtec (м)         0         3
#
#               COMMENT                           AUTO_SHORT_NAME  \
# 102  Эталонная запись           Труба PPR-C 30х3,4 0-29-0220(м)
# 103  Эталонная запись            Труба ПЭ100 90х10,6 ТН-90-В(м)
# 104  Эталонная запись            Труба ПЭ100 110х13 ТН-110-В(м)
# 105  Эталонная запись  Труба PP-R 100 32х4,4 VTp.700.FB20.32(м)
# 106  Эталонная запись            Труба Pex-Al-Pex 16х2 V1620(м)
#
#                                         AUTO_FULL_NAME    source_file
# 102  Труба PPR-C 30х3,4 артикул 0-29-0220 Aquasfera...  TMCclean.xlsx
# 103   Труба ПЭ100 90х10,6 артикул ТН-90-В Anaconda (м)  TMCclean.xlsx
# 104   Труба ПЭ100 110х13 артикул ТН-110-В Anaconda (м)  TMCclean.xlsx
# 105  Труба PP-R 100 32х4,4 артикул VTp.700.FB20.32 ...  TMCclean.xlsx
# 106     Труба Pex-Al-Pex 16х2 артикул V1620 Valtec (м)  TMCclean.xlsx
# === АНАЛИЗ НЕСОПОСТАВЛЕННЫХ ЗАПИСЕЙ ===
# АНАЛИЗ НЕСОПОСТАВЛЕННЫХ ЗАПИСЕЙ ИЗ etalon_df:
# Уникальных кодов: 30277
# Уникальных файлов-источников: 917
# Записей с пустым полным наименованием: 0
# Записей с пустым кратким наименованием: 0
#
# АНАЛИЗ НЕСОПОСТАВЛЕННЫХ ЗАПИСЕЙ ИЗ df_ksss_etalon:
# Уникальных кодов CSCD_ID: 39688
# Уникальных файлов-источников: 2
#
# Распределение статусов в несопоставленных записях:
#   0: 39625 (99.8%)
#   1: 63 (0.2%)

# %%
# Нечеткое сравнение несопоставленных записей
print("=== НЕЧЕТКОЕ СРАВНЕНИЕ НЕСОПОСТАВЛЕННЫХ ЗАПИСЕЙ ===")

# Проверяем, что оба датафрейма с несопоставленными записями не пусты
if df_unmatched_etalon is not None and not df_unmatched_etalon.empty and df_unmatched_ksss is not None and not df_unmatched_ksss.empty:
    
    # Устанавливаем библиотеку для нечеткого сравнения
    try:
        import fuzzywuzzy
        from fuzzywuzzy import fuzz, process
        print("fuzzywuzzy успешно импортирован")
    except ImportError:
        print("Устанавливаем fuzzywuzzy...")
        # !pip install fuzzywuzzy python-Levenshtein
        import fuzzywuzzy
        from fuzzywuzzy import fuzz, process
        print("fuzzywuzzy успешно установлен и импортирован")
    
    # Создаем копии для безопасной работы
    unmatched_etalon = df_unmatched_etalon.copy()
    unmatched_ksss = df_unmatched_ksss.copy()
    
    # Предварительная обработка данных
    unmatched_etalon['Полное наименование нормализованное'] = unmatched_etalon['Полное наименование нормализованное'].astype(str).str.strip()
    unmatched_etalon['Краткое наименование нормализованное'] = unmatched_etalon['Краткое наименование нормализованное'].astype(str).str.strip()
    unmatched_etalon['Код КССС/id'] = unmatched_etalon['Код КССС/id'].astype(str).str.strip()
    
    unmatched_ksss['FULL_NAME/ru_RU'] = unmatched_ksss['FULL_NAME/ru_RU'].astype(str).str.strip()
    unmatched_ksss['SHORT_NAME/ru_RU'] = unmatched_ksss['SHORT_NAME/ru_RU'].astype(str).str.strip()
    if 'CSCD_ID' in unmatched_ksss.columns:
        unmatched_ksss['CSCD_ID'] = unmatched_ksss['CSCD_ID'].astype(str).str.strip()
    
    # Удаляем пустые наименования из рассмотрения
    unmatched_etalon_full = unmatched_etalon[~unmatched_etalon['Полное наименование нормализованное'].isin(['', 'nan', 'None'])]
    unmatched_etalon_short = unmatched_etalon[~unmatched_etalon['Краткое наименование нормализованное'].isin(['', 'nan', 'None'])]
    
    unmatched_ksss_full = unmatched_ksss[~unmatched_ksss['FULL_NAME/ru_RU'].isin(['', 'nan', 'None'])]
    unmatched_ksss_short = unmatched_ksss[~unmatched_ksss['SHORT_NAME/ru_RU'].isin(['', 'nan', 'None'])]
    
    print(f"Записей для нечеткого сравнения:")
    print(f"  etalon_df с полными наименованиями: {len(unmatched_etalon_full)}")
    print(f"  etalon_df с краткими наименованиями: {len(unmatched_etalon_short)}")
    print(f"  ksss с полными наименованиями: {len(unmatched_ksss_full)}")
    print(f"  ksss с краткими наименованиями: {len(unmatched_ksss_short)}")
    
    # Функция для нечеткого сравнения
    def find_fuzzy_matches(source_df, target_df, source_col, target_col, threshold=80, limit_per_source=3):
      """
      Находит нечеткие соответствия между двумя датафреймами
      """
      matches = []
      
      for idx, source_row in source_df.iterrows():
          source_text = source_row[source_col]
          
          # Ищем лучшие соответствия в целевом датафрейме
          target_texts = target_df[target_col].tolist()
          target_indices = target_df.index.tolist()
          
          # Используем process.extract для поиска лучших соответствий
          best_matches = process.extract(
              source_text, 
              target_texts, 
              limit=limit_per_source, 
              scorer=fuzz.token_sort_ratio
          )
          
          # Сохраняем соответствия выше порога
          for match in best_matches:
              match_text, score = match[0], match[1]  # Извлекаем текст и оценку
              if score >= threshold:
                  # Находим индекс совпадения в исходном списке
                  match_idx = target_texts.index(match_text)
                  target_row = target_df.loc[target_indices[match_idx]]
                  
                  match_data = {
                      'source_index': idx,
                      'target_index': target_indices[match_idx],
                      'source_text': source_text,
                      'target_text': match_text,
                      'similarity_score': score,
                      'source_col': source_col,
                      'target_col': target_col
                  }
                  matches.append(match_data)
      
      return matches
    
    # Параметры нечеткого поиска
    SIMILARITY_THRESHOLD = 85  # Порог схожести (можно настроить)
    MAX_MATCHES_PER_RECORD = 3  # Максимальное количество соответствий на одну запись
    
    print(f"\nНачинаем нечеткое сравнение с порогом {SIMILARITY_THRESHOLD}%...")
    
    # Поиск соответствий по полным наименованиям
    print("Поиск соответствий по полным наименованиям...")
    full_name_matches = find_fuzzy_matches(
        unmatched_etalon_full, 
        unmatched_ksss_full, 
        'Полное наименование нормализованное', 
        'FULL_NAME/ru_RU',
        threshold=SIMILARITY_THRESHOLD,
        limit_per_source=MAX_MATCHES_PER_RECORD
    )
    
    # Поиск соответствий по кратким наименованиям
    print("Поиск соответствий по кратким наименованиям...")
    short_name_matches = find_fuzzy_matches(
        unmatched_etalon_short, 
        unmatched_ksss_short, 
        'Краткое наименование нормализованное', 
        'SHORT_NAME/ru_RU',
        threshold=SIMILARITY_THRESHOLD,
        limit_per_source=MAX_MATCHES_PER_RECORD
    )
    
    # Объединяем все найденные соответствия
    all_matches = full_name_matches + short_name_matches
    
    print(f"\nРЕЗУЛЬТАТЫ НЕЧЕТКОГО СРАВНЕНИЯ:")
    print(f"Найдено соответствий по полным наименованиям: {len(full_name_matches)}")
    print(f"Найдено соответствий по кратким наименованиям: {len(short_name_matches)}")
    print(f"Всего потенциальных соответствий: {len(all_matches)}")
    
    # Создаем датафрейм с частичными соответствиями
    if all_matches:
        # Группируем по исходным записям и выбираем лучшее соответствие для каждой
        best_matches = {}
        
        for match in all_matches:
            source_idx = match['source_index']
            target_idx = match['target_index']
            score = match['similarity_score']
            match_type = 'Полное наименование' if 'Полное' in match['source_col'] else 'Краткое наименование'
            
            key = (source_idx, target_idx)
            if key not in best_matches or score > best_matches[key]['similarity_score']:
                best_matches[key] = {
                    'similarity_score': score,
                    'match_type': match_type,
                    'source_text': match['source_text'],
                    'target_text': match['target_text']
                }
        
        # Создаем финальный датафрейм
        partial_match_records = []
        
        for (source_idx, target_idx), match_info in best_matches.items():
            etalon_row = unmatched_etalon.loc[source_idx]
            ksss_row = unmatched_ksss.loc[target_idx]
            
            record = {
                # Данные из etalon_df
                'Код КССС/id_etalon': etalon_row['Код КССС/id'],
                'Полное наименование нормализованное_etalon': etalon_row['Полное наименование нормализованное'],
                'Краткое наименование нормализованное_etalon': etalon_row['Краткое наименование нормализованное'],
                'Статус_etalon': etalon_row['Статус'],
                'Папка_etalon': etalon_row['Папка'],
                'Имя файла_etalon': etalon_row['Имя файла'],
                
                # Данные из df_ksss_etalon
                'CSCD_ID_ksss': ksss_row.get('CSCD_ID', ''),
                'FULL_NAME/ru_RU_ksss': ksss_row.get('FULL_NAME/ru_RU', ''),
                'SHORT_NAME/ru_RU_ksss': ksss_row.get('SHORT_NAME/ru_RU', ''),
                'TMC_Stat_ksss': ksss_row.get('TMC_Stat', ''),
                'TMC_Type_ksss': ksss_row.get('TMC_Type', ''),
                'COMMENT_ksss': ksss_row.get('COMMENT', ''),
                'AUTO_SHORT_NAME_ksss': ksss_row.get('AUTO_SHORT_NAME', ''),
                'AUTO_FULL_NAME_ksss': ksss_row.get('AUTO_FULL_NAME', ''),
                'Hierarchy_MTR_Class_ksss': ksss_row.get('Hierarchy_MTR_Class', ''),
                'Hierarchy_MTR_Name_ksss': ksss_row.get('Hierarchy_MTR_Name', ''),
                'source_file_ksss': ksss_row.get('source_file', ''),
                
                # Информация о нечетком совпадении
                'Тип_совпадения': match_info['match_type'],
                'Процент_совпадения': match_info['similarity_score'],
                'Сопоставленный_текст_etalon': match_info['source_text'],
                'Сопоставленный_текст_ksss': match_info['target_text']
            }
            partial_match_records.append(record)
        
        df_part_match = pd.DataFrame(partial_match_records)
        
        # Сортируем по проценту совпадения (по убыванию)
        df_part_match = df_part_match.sort_values('Процент_совпадения', ascending=False)
        
        print(f"\nСоздан датафрейм df_part_match с {len(df_part_match)} записями")
        
        # Статистика по качеству совпадений
        print(f"\nСТАТИСТИКА НЕЧЕТКИХ СОВПАДЕНИЙ:")
        print(f"Средний процент совпадения: {df_part_match['Процент_совпадения'].mean():.1f}%")
        print(f"Максимальный процент совпадения: {df_part_match['Процент_совпадения'].max():.1f}%")
        print(f"Минимальный процент совпадения: {df_part_match['Процент_совпадения'].min():.1f}%")
        
        # Распределение по типам совпадений
        match_type_stats = df_part_match['Тип_совпадения'].value_counts()
        print(f"\nРаспределение по типам совпадений:")
        for match_type, count in match_type_stats.items():
            print(f"  {match_type}: {count}")
        
        # Распределение по диапазонам схожести
        print(f"\nРаспределение по качеству совпадений:")
        bins = [85, 90, 95, 100]
        labels = ['85-89%', '90-94%', '95-100%']
        df_part_match['score_range'] = pd.cut(df_part_match['Процент_совпадения'], bins=bins, labels=labels, right=False)
        score_stats = df_part_match['score_range'].value_counts().sort_index()
        for score_range, count in score_stats.items():
            print(f"  {score_range}: {count}")
        
        # Сохраняем в Excel файл
        output_filename = "частичные_совпадения.xlsx"
        df_part_match.to_excel(output_filename, index=False)
        print(f"\nРезультат сохранен в файл: {output_filename}")
        
        # Показываем лучшие совпадения
        print(f"\nТоп-10 лучших совпадений:")
        top_matches = df_part_match.head(10)
        for idx, row in top_matches.iterrows():
            print(f"  {row['Процент_совпадения']}% - {row['Сопоставленный_текст_etalon'][:50]}... -> {row['Сопоставленный_текст_ksss'][:50]}...")
        
        # Визуализация результатов
        import matplotlib.pyplot as plt
        import seaborn as sns
        
        plt.figure(figsize=(15, 10))
        
        # График 1: Распределение процентов совпадения
        plt.subplot(2, 2, 1)
        plt.hist(df_part_match['Процент_совпадения'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
        plt.axvline(df_part_match['Процент_совпадения'].mean(), color='red', linestyle='--', label=f'Среднее: {df_part_match["Процент_совпадения"].mean():.1f}%')
        plt.xlabel('Процент совпадения')
        plt.ylabel('Количество записей')
        plt.title('Распределение процентов совпадения')
        plt.legend()
        plt.grid(alpha=0.3)
        
        # График 2: Типы совпадений
        plt.subplot(2, 2, 2)
        match_type_stats.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightcoral'])
        plt.title('Распределение по типам совпадений')
        
        # График 3: Качество совпадений по диапазонам
        plt.subplot(2, 2, 3)
        score_stats.plot(kind='bar', color='lightgreen', edgecolor='black')
        plt.title('Качество совпадений по диапазонам')
        plt.xlabel('Диапазон совпадения')
        plt.ylabel('Количество записей')
        plt.xticks(rotation=45)
        plt.grid(axis='y', alpha=0.3)
        

        
        # Показываем полный датафрейм
        print(f"\nПолный датафрейм df_part_match ({len(df_part_match)} записей):")
        display(df_part_match.head(15))
        
    else:
        print("Нечеткие соответствия не найдены!")
        df_part_match = pd.DataFrame()

else:
    print("Один или оба датафрейма с несопоставленными записями пусты!")
    df_part_match = pd.DataFrame()
# Out:
# === НЕЧЕТКОЕ СРАВНЕНИЕ НЕСОПОСТАВЛЕННЫХ ЗАПИСЕЙ ===
# fuzzywuzzy успешно импортирован
# Записей для нечеткого сравнения:
#   etalon_df с полными наименованиями: 35128
#   etalon_df с краткими наименованиями: 35128
#   ksss с полными наименованиями: 39688
#   ksss с краткими наименованиями: 39688
#
# Начинаем нечеткое сравнение с порогом 85%...
# Поиск соответствий по полным наименованиям...
# Поиск соответствий по кратким наименованиям...
#
# РЕЗУЛЬТАТЫ НЕЧЕТКОГО СРАВНЕНИЯ:
# Найдено соответствий по полным наименованиям: 55397
# Найдено соответствий по кратким наименованиям: 39531
# Всего потенциальных соответствий: 94928
#
# Создан датафрейм df_part_match с 64656 записями
#
# СТАТИСТИКА НЕЧЕТКИХ СОВПАДЕНИЙ:
# Средний процент совпадения: 92.8%
# Максимальный процент совпадения: 100.0%
# Минимальный процент совпадения: 85.0%
#
# Распределение по типам совпадений:
#   Полное наименование: 51414
#   Краткое наименование: 13242
#
# Распределение по качеству совпадений:
#   85-89%: 17481
#   90-94%: 22070
#   95-100%: 19119
#
# Результат сохранен в файл: частичные_совпадения.xlsx
#
# Топ-10 лучших совпадений:
#   100% - Конвектор электрический Neoclima L 2,0... -> Конвектор электрический NeoClima L 2,0...
#   100% - Разрядник защиты от перенапряжений VAL-MS 230/FM а... -> Разрядник защиты от перенапряжений артикул VAL-MS ...
#   100% - Фен технический Denzel HG-2000E... -> Фен технический Denzel HG 2000E...
#   100% - Блок компрессорно-конденсаторный МАКК 330-1202... -> Блок компрессорно-конденсаторный МАКК-330-1202...
#   100% - Металлодетектор арочный Локаторная техника Паутина... -> Металлодетектор арочный Паутина-Н2-2 Локаторная те...
#   100% - Мельница дисковая DM 200... -> Мельница дисковая DM-200...
#   100% - Мельница вибрационная MM 400... -> Мельница вибрационная MM-400...
#   100% - Термопресс плоский Econopress Vert 38... -> Термопресс плоский Vert 38 Econopress...
#   100% - Котел электрический Эван Practic 50... -> Котел электрический Practic 50 ЭВАН...
#   100% - Агрегат холодильный 30-0081-НАС208В... -> Агрегат холодильный-30-0081-НАС208В...
#
# Полный датафрейм df_part_match (64656 записей):
#       Код КССС/id_etalon         Полное наименование нормализованное_etalon  \
# 35937             918265             Конвектор электрический Neoclima L 2,0
# 54845            1779802  Разрядник защиты от перенапряжений VAL-MS 230/...
# 35961            3543601                    Фен технический Denzel HG-2000E
# 36015            3403356     Блок компрессорно-конденсаторный МАКК 330-1202
# 35911            3257082  Металлодетектор арочный Локаторная техника Пау...
# 35910            3385994                           Мельница дисковая DM 200
# 35909            3012755                       Мельница вибрационная MM 400
# 35907            3478239              Термопресс плоский Econopress Vert 38
# 36043            3580451                Котел электрический Эван Practic 50
# 36004            3227948                Агрегат холодильный 30-0081-НАС208В
# 36002            3227947                Агрегат холодильный 30-0081-НАС208А
# 36031            3340051                         Охладитель пара 83-DS-0305
# 36028            3301857                         Охладитель пара 82-DS-1001
# 36025            3167488                         Охладитель пара 82-DS-2001
# 36024            3434090                       Охладитель пара АФТ-ПО-200/4
#
#       Краткое наименование нормализованное_etalon Статус_etalon  \
# 35937                    Конвектор Neoclima L 2,0        Эталон
# 54845        Разрядник VAL-MS 230/FM а.2839130 PC        Эталон
# 35961             Фен технический Denzel HG-2000E        Эталон
# 36015                          Блок МАКК 330-1202        Эталон
# 35911     Металлодетектор Локат.тех. Паутина-Н2-2        Эталон
# 35910                    Мельница дисковая DM 200        Эталон
# 35909                Мельница вибрационная MM 400        Эталон
# 35907               Термопресс Econopress Vert 38        Эталон
# 36043               Котел электр. Эван Practic 50        Эталон
# 36004         Агрегат холодильный 30-0081-НАС208В        Эталон
# 36002         Агрегат холодильный 30-0081-НАС208А        Эталон
# 36031                  Охладитель пара 83-DS-0305        Эталон
# 36028                  Охладитель пара 82-DS-1001        Эталон
# 36025                  Охладитель пара 82-DS-2001        Эталон
# 36024                Охладитель пара АФТ-ПО-200/4        Эталон
#
#                         Папка_etalon  \
# 35937  Оборудование общепромышленное
# 54845            Электрооборудование
# 35961  Оборудование общепромышленное
# 36015  Оборудование общепромышленное
# 35911  Оборудование общепромышленное
# 35910  Оборудование общепромышленное
# 35909  Оборудование общепромышленное
# 35907  Оборудование общепромышленное
# 36043  Оборудование общепромышленное
# 36004  Оборудование общепромышленное
# 36002  Оборудование общепромышленное
# 36031  Оборудование общепромышленное
# 36028  Оборудование общепромышленное
# 36025  Оборудование общепромышленное
# 36024  Оборудование общепромышленное
#
#                                      Имя файла_etalon CSCD_ID_ksss  \
# 35937                Оборуд систем отопления_434.xlsx      6053644
# 54845                              Разрядники_11.xlsx      6219107
# 35961  Оборуд_для нагрева поверхностей тв_тел_38.xlsx      6216704
# 36015             Оборудование для охлаждения_74.xlsx      6216493
# 35911      Металлоискатели (металлодетекторы)_11.xlsx      6057723
# 35910                                 Мельницы_6.xlsx      6042396
# 35909                                 Мельницы_6.xlsx      6042395
# 35907                    Машины маркировальные_9.xlsx      6063462
# 36043                  Оборудование котельное_15.xlsx      6216525
# 36004             Оборудование для охлаждения_74.xlsx      6216478
# 36002             Оборудование для охлаждения_74.xlsx      6216477
# 36031             Оборудование для охлаждения_74.xlsx      6216516
# 36028             Оборудование для охлаждения_74.xlsx      6216515
# 36025             Оборудование для охлаждения_74.xlsx      6216514
# 36024             Оборудование для охлаждения_74.xlsx      6216513
#
#                                     FULL_NAME/ru_RU_ksss  \
# 35937             Конвектор электрический NeoClima L 2,0
# 54845  Разрядник защиты от перенапряжений артикул VAL...
# 35961                    Фен технический Denzel HG 2000E
# 36015     Блок компрессорно-конденсаторный МАКК-330-1202
# 35911  Металлодетектор арочный Паутина-Н2-2 Локаторна...
# 35910                           Мельница дисковая DM-200
# 35909                       Мельница вибрационная MM-400
# 35907              Термопресс плоский Vert 38 Econopress
# 36043                Котел электрический Practic 50 ЭВАН
# 36004                Агрегат холодильный-30-0081-НАС208В
# 36002                Агрегат холодильный-30-0081-НАС208А
# 36031                         Охладитель пара-83-DS-0305
# 36028                         Охладитель пара-82-DS-1001
# 36025                         Охладитель пара-82-DS-2001
# 36024                       Охладитель пара-АФТ-ПО-200/4
#
#                          SHORT_NAME/ru_RU_ksss  TMC_Stat_ksss  ...  \
# 35937                 Конвектор NeoClima L 2,0              0  ...
# 54845   Разрядник арт. VAL-MS 230/FM2839130 PC              0  ...
# 35961          Фен технический Denzel HG 2000E              0  ...
# 36015                            Блок 330-1202              0  ...
# 35911  Металлодетектор Паутина-Н2-2 Локат.тех.              0  ...
# 35910                    Мельница диск. DM-200              0  ...
# 35909                    Мельница вибр. MM-400              0  ...
# 35907            Термопресс Vert 38 Econopress              0  ...
# 36043                Котел эл. Practic 50 ЭВАН              0  ...
# 36004                  Агрегат 30-0081-НАС208В              0  ...
# 36002                  Агрегат 30-0081-НАС208А              0  ...
# 36031                    Охладитель 83-DS-0305              0  ...
# 36028                    Охладитель 82-DS-1001              0  ...
# 36025                    Охладитель 82-DS-2001              0  ...
# 36024                  Охладитель АФТ-ПО-200/4              0  ...
#
#                           AUTO_SHORT_NAME_ksss  \
# 35937                 Конвектор NeoClima L 2,0
# 54845   Разрядник арт. VAL-MS 230/FM2839130 PC
# 35961          Фен технический Denzel HG 2000E
# 36015                            Блок 330-1202
# 35911  Металлодетектор Паутина-Н2-2 Локат.тех.
# 35910                    Мельница диск. DM-200
# 35909                    Мельница вибр. MM-400
# 35907            Термопресс Vert 38 Econopress
# 36043                Котел эл. Practic 50 ЭВАН
# 36004                  Агрегат 30-0081-НАС208В
# 36002                  Агрегат 30-0081-НАС208А
# 36031                    Охладитель 83-DS-0305
# 36028                    Охладитель 82-DS-1001
# 36025                    Охладитель 82-DS-2001
# 36024                  Охладитель АФТ-ПО-200/4
#
#                                      AUTO_FULL_NAME_ksss  \
# 35937             Конвектор электрический NeoClima L 2,0
# 54845  Разрядник защиты от перенапряжений артикул VAL...
# 35961                    Фен технический Denzel HG 2000E
# 36015     Блок компрессорно-конденсаторный МАКК-330-1202
# 35911  Металлодетектор арочный Паутина-Н2-2 Локаторна...
# 35910                           Мельница дисковая DM-200
# 35909                       Мельница вибрационная MM-400
# 35907              Термопресс плоский Vert 38 Econopress
# 36043                Котел электрический Practic 50 ЭВАН
# 36004                Агрегат холодильный-30-0081-НАС208В
# 36002                Агрегат холодильный-30-0081-НАС208А
# 36031                         Охладитель пара-83-DS-0305
# 36028                         Охладитель пара-82-DS-1001
# 36025                         Охладитель пара-82-DS-2001
# 36024                       Охладитель пара-АФТ-ПО-200/4
#
#       Hierarchy_MTR_Class_ksss                 Hierarchy_MTR_Name_ksss  \
# 35937             2.002130e+15           Оборудование систем отопления
# 54845             2.007052e+15                              Разрядники
# 35961             2.002060e+15  Оборуд. д/нагрева поверхностей тв. тел
# 36015             2.002130e+15             Оборудование для охлаждения
# 35911             2.002170e+15      Металлоискатели (металлодетекторы)
# 35910             2.002110e+15                                Мельницы
# 35909             2.002110e+15                                Мельницы
# 35907             2.002100e+15                   Машины маркировальные
# 36043             2.002130e+15                  Оборудование котельное
# 36004             2.002130e+15             Оборудование для охлаждения
# 36002             2.002130e+15             Оборудование для охлаждения
# 36031             2.002130e+15             Оборудование для охлаждения
# 36028             2.002130e+15             Оборудование для охлаждения
# 36025             2.002130e+15             Оборудование для охлаждения
# 36024             2.002130e+15             Оборудование для охлаждения
#
#        source_file_ksss       Тип_совпадения Процент_совпадения  \
# 35937     TMCclean.xlsx  Полное наименование                100
# 54845     TMCclean.xlsx  Полное наименование                100
# 35961     TMCclean.xlsx  Полное наименование                100
# 36015     TMCclean.xlsx  Полное наименование                100
# 35911     TMCclean.xlsx  Полное наименование                100
# 35910     TMCclean.xlsx  Полное наименование                100
# 35909     TMCclean.xlsx  Полное наименование                100
# 35907     TMCclean.xlsx  Полное наименование                100
# 36043     TMCclean.xlsx  Полное наименование                100
# 36004     TMCclean.xlsx  Полное наименование                100
# 36002     TMCclean.xlsx  Полное наименование                100
# 36031     TMCclean.xlsx  Полное наименование                100
# 36028     TMCclean.xlsx  Полное наименование                100
# 36025     TMCclean.xlsx  Полное наименование                100
# 36024     TMCclean.xlsx  Полное наименование                100
#
#                              Сопоставленный_текст_etalon  \
# 35937             Конвектор электрический Neoclima L 2,0
# 54845  Разрядник защиты от перенапряжений VAL-MS 230/...
# 35961                    Фен технический Denzel HG-2000E
# 36015     Блок компрессорно-конденсаторный МАКК 330-1202
# 35911  Металлодетектор арочный Локаторная техника Пау...
# 35910                           Мельница дисковая DM 200
# 35909                       Мельница вибрационная MM 400
# 35907              Термопресс плоский Econopress Vert 38
# 36043                Котел электрический Эван Practic 50
# 36004                Агрегат холодильный 30-0081-НАС208В
# 36002                Агрегат холодильный 30-0081-НАС208А
# 36031                         Охладитель пара 83-DS-0305
# 36028                         Охладитель пара 82-DS-1001
# 36025                         Охладитель пара 82-DS-2001
# 36024                       Охладитель пара АФТ-ПО-200/4
#
#                                Сопоставленный_текст_ksss score_range
# 35937             Конвектор электрический NeoClima L 2,0         NaN
# 54845  Разрядник защиты от перенапряжений артикул VAL...         NaN
# 35961                    Фен технический Denzel HG 2000E         NaN
# 36015     Блок компрессорно-конденсаторный МАКК-330-1202         NaN
# 35911  Металлодетектор арочный Паутина-Н2-2 Локаторна...         NaN
# 35910                           Мельница дисковая DM-200         NaN
# 35909                       Мельница вибрационная MM-400         NaN
# 35907              Термопресс плоский Vert 38 Econopress         NaN
# 36043                Котел электрический Practic 50 ЭВАН         NaN
# 36004                Агрегат холодильный-30-0081-НАС208В         NaN
# 36002                Агрегат холодильный-30-0081-НАС208А         NaN
# 36031                         Охладитель пара-83-DS-0305         NaN
# 36028                         Охладитель пара-82-DS-1001         NaN
# 36025                         Охладитель пара-82-DS-2001         NaN
# 36024                       Охладитель пара-АФТ-ПО-200/4         NaN
#
# [15 rows x 22 columns]

# %%
# Если коды в df_second нужно дополнительно обработать
def add_original_columns_advanced(target_df, source_df, id_column='Код КССС/id_etalon'):
    """
    Расширенная версия для случаев, когда коды требуют дополнительной обработки
    """
    result_df = target_df.copy()
    
    # Создаем обработанные версии кодов для сопоставления
    source_codes = source_df['CSCD_ID'].astype(str).str.strip().tolist()
    source_files = source_df['source_file'].tolist()
    source_full_names = source_df['FULL_NAME/ru_RU'].tolist()
    source_short_names = source_df['SHORT_NAME/ru_RU'].tolist()
    
    # Создаем словари
    code_mapping = {}
    for i, code in enumerate(source_codes):
        code_mapping[code] = {
            'source_file': source_files[i],
            'full_name': source_full_names[i],
            'short_name': source_short_names[i]
        }
    
    # Добавляем колонки
    csss_original = []
    full_name_original = []
    short_name_original = []
    
    for code in result_df[id_column]:
        code_str = str(code).strip()
        if code_str in code_mapping:
            csss_original.append(code_mapping[code_str]['source_file'])
            full_name_original.append(code_mapping[code_str]['full_name'])
            short_name_original.append(code_mapping[code_str]['short_name'])
        else:
            csss_original.append('Нет в КССС')
            full_name_original.append('Нет в КССС')
            short_name_original.append('Нет в КССС')
    
    result_df['CSSS_original'] = csss_original
    result_df['FULL_name_original'] = full_name_original
    result_df['SHORT_name_original'] = short_name_original
    
    # Переупорядочиваем колонки
    new_column_order = ['CSSS_original', 'FULL_name_original', 'SHORT_name_original'] + \
                      [col for col in result_df.columns if col not in ['CSSS_original', 'FULL_name_original', 'SHORT_name_original']]
    
    result_df = result_df[new_column_order]
    
    return result_df
 
# Использование расширенной версии (если нужно)
df_full_match_updated = add_original_columns_advanced(df_full_match, df_second)
df_part_match_updated = add_original_columns_advanced(df_part_match, df_second)

# %%
# Добавление дополнительных колонок из df_second в df_full_match и df_part_match
print("=== ДОБАВЛЕНИЕ ДОПОЛНИТЕЛЬНЫХ КОЛОНОК ===")
 
def add_original_columns(target_df, source_df, id_column='Код КССС/id_etalon'):
    """
    Добавляет колонки из source_df в target_df на основе совпадения кодов
    """
    # Создаем копию датафрейма
    result_df = target_df.copy()
    
    # Создаем словари для быстрого поиска
    code_to_source = dict(zip(source_df['CSCD_ID'], source_df['source_file']))
    code_to_full_name = dict(zip(source_df['CSCD_ID'], source_df['FULL_NAME/ru_RU']))
    code_to_short_name = dict(zip(source_df['CSCD_ID'], source_df['SHORT_NAME/ru_RU']))
    
    # Добавляем новые колонки
    result_df['CSSS_original'] = result_df[id_column].map(code_to_source).fillna('Нет в КССС')
    result_df['FULL_name_original'] = result_df[id_column].map(code_to_full_name).fillna('Нет в КССС')
    result_df['SHORT_name_original'] = result_df[id_column].map(code_to_short_name).fillna('Нет в КССС')
    
    # Переупорядочиваем колонки - новые колонки становятся первыми
    new_column_order = ['CSSS_original', 'FULL_name_original', 'SHORT_name_original'] + \
                      [col for col in result_df.columns if col not in ['CSSS_original', 'FULL_name_original', 'SHORT_name_original']]
    
    result_df = result_df[new_column_order]
    
    return result_df
 
# Обрабатываем df_full_match
if 'df_full_match' in globals() and not df_full_match.empty and 'df_second' in globals() and not df_second.empty:
    print("Обработка df_full_match...")
    
    # Предварительная обработка кодов в df_second
    df_second_clean = df_second.copy()
    if 'CSCD_ID' in df_second_clean.columns:
        df_second_clean['CSCD_ID'] = df_second_clean['CSCD_ID'].astype(str).str.strip()
    
    # Добавляем колонки
    df_full_match_updated = add_original_columns(df_full_match, df_second_clean)
    
    # Сохраняем статистику
    found_count = (df_full_match_updated['CSSS_original'] != 'Нет в КССС').sum()
    not_found_count = (df_full_match_updated['CSSS_original'] == 'Нет в КССС').sum()
    
    print(f"Записей в df_full_match: {len(df_full_match_updated)}")
    print(f"Найдено в КССС: {found_count}")
    print(f"Не найдено в КССС: {not_found_count}")
    
    # Перезаписываем файл
    df_full_match_updated.to_excel("результат_совпадений_fin.xlsx", index=False)
    print("df_full_match обновлен и сохранен в 'результат_совпадений_fin.xlsx'")
    
    # Обновляем оригинальный датафрейм
    df_full_match = df_full_match_updated
    
    # Показываем первые строки
    print("\nПервые 3 строки обновленного df_full_match:")
    display(df_full_match.head(3))
else:
    print("df_full_match или df_second не найдены или пусты")
 
# Обрабатываем df_part_match
if 'df_part_match' in globals() and not df_part_match.empty and 'df_second' in globals() and not df_second.empty:
    print("\nОбработка df_part_match...")
    
    # Предварительная обработка кодов в df_second
    df_second_clean = df_second.copy()
    if 'CSCD_ID' in df_second_clean.columns:
        df_second_clean['CSCD_ID'] = df_second_clean['CSCD_ID'].astype(str).str.strip()
    
    # Добавляем колонки
    df_part_match_updated = add_original_columns(df_part_match, df_second_clean)
    
    # Сохраняем статистику
    found_count = (df_part_match_updated['CSSS_original'] != 'Нет в КССС').sum()
    not_found_count = (df_part_match_updated['CSSS_original'] == 'Нет в КССС').sum()
    
    print(f"Записей в df_part_match: {len(df_part_match_updated)}")
    print(f"Найдено в КССС: {found_count}")
    print(f"Не найдено в КССС: {not_found_count}")
    
    # Перезаписываем файл
    df_part_match_updated.to_excel("частичные_совпадения_fin.xlsx", index=False)
    print("df_part_match обновлен и сохранен в 'частичные_совпадения_fin.xlsx'")
    
    # Обновляем оригинальный датафрейм
    df_part_match = df_part_match_updated
    
    # Показываем первые строки
    print("\nПервые 3 строки обновленного df_part_match:")
    display(df_part_match.head(3))
else:
    print("df_part_match или df_second не найдены или пусты")
 
# Дополнительная статистика
print("\n=== СВОДНАЯ СТАТИСТИКА ===")
 
if 'df_full_match' in globals() and not df_full_match.empty:
    print("df_full_match:")
    print(f"  Всего записей: {len(df_full_match)}")
    print(f"  Колонки: {list(df_full_match.columns)}")
    
    # Анализ источников
    if 'CSSS_original' in df_full_match.columns:
        source_stats = df_full_match['CSSS_original'].value_counts()
        print("  Распределение по источникам:")
        for source, count in source_stats.head(5).items():  # Показываем топ-5
            print(f"    {source}: {count}")
 
if 'df_part_match' in globals() and not df_part_match.empty:
    print("\ndf_part_match:")
    print(f"  Всего записей: {len(df_part_match)}")
    print(f"  Колонки: {list(df_part_match.columns)}")
    
    # Анализ источников
    if 'CSSS_original' in df_part_match.columns:
        source_stats = df_part_match['CSSS_original'].value_counts()
        print("  Распределение по источникам:")
        for source, count in source_stats.head(5).items():  # Показываем топ-5
            print(f"    {source}: {count}")
 
print("\nОбработка завершена!")
# Out:
# === ДОБАВЛЕНИЕ ДОПОЛНИТЕЛЬНЫХ КОЛОНОК ===
# Обработка df_full_match...
# Записей в df_full_match: 66890
# Найдено в КССС: 62970
# Не найдено в КССС: 3920
# df_full_match обновлен и сохранен в 'результат_совпадений_fin.xlsx'
#
# Первые 3 строки обновленного df_full_match:
#   CSSS_original                                 FULL_name_original  \
# 0    Нет в КССС                                         Нет в КССС
# 1    Нет в КССС                                         Нет в КССС
# 2      SUP.xlsx  Клапан предохранительный СППК 32-40 DN32 PN40 ...
#
#                 SHORT_name_original Код КССС/id_etalon  \
# 0                        Нет в КССС            1829610
# 1                        Нет в КССС            1829611
# 2  Клапан СППК 32-40 DN32 PN40 УХЛ1            2298328
#
#           Полное наименование нормализованное_etalon  \
# 0  Арматура устьевая универсальная ШГН, условный ...
# 1  Арматура устьевая универсальная ШГН, условный ...
# 2  Арматура устьевая универсальная ШГН, условный ...
#
#   Краткое наименование нормализованное_etalon Статус_etalon  \
# 0    Арматура уст. универсальная ШГН-50x50x14        Эталон
# 1    Арматура уст. универсальная ШГН-65x50x14        Эталон
# 2    Арматура уст. универсальная ШГН-65x65x14        Эталон
#
#                    Папка_etalon                             Имя файла_etalon  \
# 0  Арматура трубопроводная, ЗиП  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
# 1  Арматура трубопроводная, ЗиП  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
# 2  Арматура трубопроводная, ЗиП  Арматура уст.,фонт.,нагн., дШГН,ЭЦН_15.xlsx
#
#   CSCD_ID_ksss  ...                     SHORT_NAME/ru_RU_ksss TMC_Stat_ksss  \
# 0      6055151  ...  Арматура уст. универсальная ШГН-50-50-14             0
# 1      6055152  ...  Арматура уст. универсальная ШГН-65-50-14             0
# 2      6055153  ...  Арматура уст. универсальная ШГН-65-65-14             0
#
#    TMC_Type_ksss      COMMENT_ksss                      AUTO_SHORT_NAME_ksss  \
# 0              3  Эталонная запись  Арматура уст. универсальная ШГН-50-50-14
# 1              3  Эталонная запись  Арматура уст. универсальная ШГН-65-50-14
# 2              3  Эталонная запись  Арматура уст. универсальная ШГН-65-65-14
#
#                                  AUTO_FULL_NAME_ksss Hierarchy_MTR_Class_ksss  \
# 0  Арматура устьевая универсальная ШГН, условный ...             2.010020e+15
# 1  Арматура устьевая универсальная ШГН, условный ...             2.010020e+15
# 2  Арматура устьевая универсальная ШГН, условный ...             2.010020e+15
#
#                Hierarchy_MTR_Name_ksss source_file_ksss       Тип_совпадения
# 0  Арматура уст.фонт.,нагн., д/ШГН,ЭЦН    TMCclean.xlsx  Полное наименование
# 1  Арматура уст.фонт.,нагн., д/ШГН,ЭЦН    TMCclean.xlsx  Полное наименование
# 2  Арматура уст.фонт.,нагн., д/ШГН,ЭЦН    TMCclean.xlsx  Полное наименование
#
# [3 rows x 21 columns]
# Обработка df_part_match...
# Записей в df_part_match: 64656
# Найдено в КССС: 63654
# Не найдено в КССС: 1002
# df_part_match обновлен и сохранен в 'частичные_совпадения_fin.xlsx'
#
# Первые 3 строки обновленного df_part_match:
#       CSSS_original                                 FULL_name_original  \
# 35937      SUP.xlsx  Конвектор электрический настенный Neoclima Com...
# 54845      SUP.xlsx    Разрядник Phoenix Contact VAL-MS 230/FM 2839130
# 35961      SUP.xlsx                    Фен технический Denzel HG-2000E
#
#                      SHORT_name_original Код КССС/id_etalon  \
# 35937  Конвектор Neoclima Comforte L 2,0             918265
# 54845    Разрядник VAL-MS 230/FM 2839130            1779802
# 35961    Фен технический Denzel HG-2000E            3543601
#
#               Полное наименование нормализованное_etalon  \
# 35937             Конвектор электрический Neoclima L 2,0
# 54845  Разрядник защиты от перенапряжений VAL-MS 230/...
# 35961                    Фен технический Denzel HG-2000E
#
#       Краткое наименование нормализованное_etalon Статус_etalon  \
# 35937                    Конвектор Neoclima L 2,0        Эталон
# 54845        Разрядник VAL-MS 230/FM а.2839130 PC        Эталон
# 35961             Фен технический Denzel HG-2000E        Эталон
#
#                         Папка_etalon  \
# 35937  Оборудование общепромышленное
# 54845            Электрооборудование
# 35961  Оборудование общепромышленное
#
#                                      Имя файла_etalon CSCD_ID_ksss  ...  \
# 35937                Оборуд систем отопления_434.xlsx      6053644  ...
# 54845                              Разрядники_11.xlsx      6219107  ...
# 35961  Оборуд_для нагрева поверхностей тв_тел_38.xlsx      6216704  ...
#
#                          AUTO_SHORT_NAME_ksss  \
# 35937                Конвектор NeoClima L 2,0
# 54845  Разрядник арт. VAL-MS 230/FM2839130 PC
# 35961         Фен технический Denzel HG 2000E
#
#                                      AUTO_FULL_NAME_ksss  \
# 35937             Конвектор электрический NeoClima L 2,0
# 54845  Разрядник защиты от перенапряжений артикул VAL...
# 35961                    Фен технический Denzel HG 2000E
#
#        Hierarchy_MTR_Class_ksss                 Hierarchy_MTR_Name_ksss  \
# 35937              2.002130e+15           Оборудование систем отопления
# 54845              2.007052e+15                              Разрядники
# 35961              2.002060e+15  Оборуд. д/нагрева поверхностей тв. тел
#
#       source_file_ksss       Тип_совпадения Процент_совпадения  \
# 35937    TMCclean.xlsx  Полное наименование                100
# 54845    TMCclean.xlsx  Полное наименование                100
# 35961    TMCclean.xlsx  Полное наименование                100
#
#                              Сопоставленный_текст_etalon  \
# 35937             Конвектор электрический Neoclima L 2,0
# 54845  Разрядник защиты от перенапряжений VAL-MS 230/...
# 35961                    Фен технический Denzel HG-2000E
#
#                                Сопоставленный_текст_ksss score_range
# 35937             Конвектор электрический NeoClima L 2,0         NaN
# 54845  Разрядник защиты от перенапряжений артикул VAL...         NaN
# 35961                    Фен технический Denzel HG 2000E         NaN
#
# [3 rows x 25 columns]
# === СВОДНАЯ СТАТИСТИКА ===
# df_full_match:
#   Всего записей: 66890
#   Колонки: ['CSSS_original', 'FULL_name_original', 'SHORT_name_original', 'Код КССС/id_etalon', 'Полное наименование нормализованное_etalon', 'Краткое наименование нормализованное_etalon', 'Статус_etalon', 'Папка_etalon', 'Имя файла_etalon', 'CSCD_ID_ksss', 'FULL_NAME/ru_RU_ksss', 'SHORT_NAME/ru_RU_ksss', 'TMC_Stat_ksss', 'TMC_Type_ksss', 'COMMENT_ksss', 'AUTO_SHORT_NAME_ksss', 'AUTO_FULL_NAME_ksss', 'Hierarchy_MTR_Class_ksss', 'Hierarchy_MTR_Name_ksss', 'source_file_ksss', 'Тип_совпадения']
#   Распределение по источникам:
#     SUP.xlsx: 59920
#     Нет в КССС: 3920
#     TMCclean.xlsx: 3050
#
# df_part_match:
#   Всего записей: 64656
#   Колонки: ['CSSS_original', 'FULL_name_original', 'SHORT_name_original', 'Код КССС/id_etalon', 'Полное наименование нормализованное_etalon', 'Краткое наименование нормализованное_etalon', 'Статус_etalon', 'Папка_etalon', 'Имя файла_etalon', 'CSCD_ID_ksss', 'FULL_NAME/ru_RU_ksss', 'SHORT_NAME/ru_RU_ksss', 'TMC_Stat_ksss', 'TMC_Type_ksss', 'COMMENT_ksss', 'AUTO_SHORT_NAME_ksss', 'AUTO_FULL_NAME_ksss', 'Hierarchy_MTR_Class_ksss', 'Hierarchy_MTR_Name_ksss', 'source_file_ksss', 'Тип_совпадения', 'Процент_совпадения', 'Сопоставленный_текст_etalon', 'Сопоставленный_текст_ksss', 'score_range']
#   Распределение по источникам:
#     SUP.xlsx: 53082
#     TMCclean.xlsx: 10572
#     Нет в КССС: 1002
#
# Обработка завершена!
